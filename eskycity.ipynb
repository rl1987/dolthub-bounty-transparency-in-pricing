# %%
import pandas as pd

# %%
TARGET_COLUMNS = [ 
    'hospital_id',
    #'row_id',
    'line_type',
    'description',
    'rev_code',
    'local_code',
    'code',
    'ms_drg',
    'apr_drg',
    'eapg',
    'hcpcs_cpt',
    'modifiers',
    'thru',
    'apc',
    'icd',
    'ndc',
    'drug_hcpcs_multiplier',
    'drug_quantity',
    'drug_unit_of_measurement',
    'drug_type_of_measurement',
    'billing_class',
    'setting',
    'payer_category',
    'payer_name',
    'plan_name',
    'standard_charge',
    'standard_charge_percent',
    'contracting_method',
    'additional_generic_notes',
    'additional_payer_specific_notes'
]

# %%
ccn = "450825"
url = "https://uhsfilecdn.eskycity.net/ac/742829611_cornerstone-regional-hospital_standard-charges.csv"
filename = url.split("/")[-1]
ein = filename.split("_")[0]
ein = ein[:2] + "-" + ein[2:]

# %%
import subprocess
subprocess.run(["wget", "--no-clobber", url, "-O", filename])
# Out:
# File ‘742829611_cornerstone-regional-hospital_standard-charges.csv’ already there; not retrieving.
# CompletedProcess(args=['wget', '--no-clobber', 'https://uhsfilecdn.eskycity.net/ac/742829611_cornerstone-regional-hospital_standard-charges.csv', '-O', '742829611_cornerstone-regional-hospital_standard-charges.csv'], returncode=1)

# %%
df_in = pd.read_csv(filename, skiprows=3, dtype=str, low_memory=True)
df_in
# Out:
#                             Facility
# 0      Cornerstone Regional Hospital  \
# 1      Cornerstone Regional Hospital
# 2      Cornerstone Regional Hospital
# 3      Cornerstone Regional Hospital
# 4      Cornerstone Regional Hospital
# ...                              ...
# 12115  Cornerstone Regional Hospital
# 12116  Cornerstone Regional Hospital
# 12117  Cornerstone Regional Hospital
# 12118  Cornerstone Regional Hospital
# 12119  Cornerstone Regional Hospital
#
#                                              Description CDM (If Applicable)
# 0      SPINAL PROCEDURES W CC OR SPINAL NEUROSTIMULATORS                 NaN  \
# 1                           SPINAL PROCEDURES W/O CC/MCC                 NaN
# 2      Cardiac valve and other major cardiothoracic p...                 NaN
# 3              MAJOR SMALL & LARGE BOWEL PROCEDURES W CC                 NaN
# 4      SPINAL FUS EXC CERV W SPINAL CURV/MALIG/INFEC ...                 NaN
# ...                                                  ...                 ...
# 12115                     ADD'L SEQUENTIAL INF UP TO 1HR           940505504
# 12116                     IV INFUSION FOR THERAPY 1ST HR           940505505
# 12117                                CONCURRENT INFUSION           940505506
# 12118                      HYDRATION IV INFUSION, 1ST HR           940505507
# 12119                      THERP.PROPHYLACTIC OR DX INJ.           940505508
#
#       DRG (If Applicable) CPT/HCPCS (If Applicable)     Gross Charge
# 0                      29                       NaN            $155,356   \
# 1                      30                       NaN             $75,085
# 2                     216                       NaN                 $(1)
# 3                     330                       NaN             $48,961
# 4                     457                       NaN            $186,653
# ...                   ...                       ...                  ...
# 12115                 NaN                       NaN               320.50
# 12116                 NaN                       NaN               320.50
# 12117                 NaN                       NaN               320.50
# 12118                 NaN                       NaN               320.50
# 12119                 NaN                       NaN               320.50
#
#           Cash Price        Minimum       Maximum                 AETNA   ...
# 0               $23,815      $155,356     $155,356    $1653.00 per diem   ...  \
# 1               $16,337       $50,208      $92,493    $1653.00 per diem   ...
# 2                   $(1)          $(1)         $(1)                 $(1)  ...
# 3               $17,131       $36,645      $61,277    $1653.00 per diem   ...
# 4               $42,012      $186,653     $186,653    $1653.00 per diem   ...
# ...                  ...           ...          ...                  ...  ...
# 12115              $128           $(1)         $(1)                 $(1)  ...
# 12116              $128           $(1)         $(1)                 $(1)  ...
# 12117              $128           $(1)         $(1)                 $(1)  ...
# 12118              $128           $(1)         $(1)                 $(1)  ...
# 12119              $128           $(1)         $(1)                 $(1)  ...
#
#             TRC    TRIWEST     TXHLSP   TXHLSTAR     UNITED   UNITEDMCR
# 0       $21,650    $21,650    $21,650    $20,667    $25,380     $21,650   \
# 1       $14,852    $14,852    $14,852     $7,237    $30,996     $14,852
# 2           $(1)       $(1)       $(1)       $(1)       $(1)        $(1)
# 3       $15,573    $15,573    $15,573     $6,993    $20,920     $15,573
# 4       $38,193    $38,193    $38,193    $20,667    $79,752     $38,193
# ...          ...        ...        ...        ...        ...         ...
# 12115       $(1)       $(1)       $(1)       $(1)       $(1)        $(1)
# 12116       $(1)       $(1)       $(1)       $(1)       $(1)        $(1)
# 12117       $(1)       $(1)       $(1)       $(1)       $(1)        $(1)
# 12118       $(1)       $(1)       $(1)       $(1)       $(1)        $(1)
# 12119       $(1)       $(1)       $(1)       $(1)       $(1)        $(1)
#
#        UNITEDSTAR      VAFEE         WC    WELLMED
# 0         $20,667    $21,650    $18,143    $21,650
# 1          $7,237    $14,852    $22,158    $14,852
# 2             $(1)       $(1)       $(1)       $(1)
# 3          $6,993    $15,573    $14,955    $15,573
# 4         $20,667    $38,193    $57,011    $38,193
# ...            ...        ...        ...        ...
# 12115         $(1)       $(1)       $(1)       $(1)
# 12116         $(1)       $(1)       $(1)       $(1)
# 12117         $(1)       $(1)       $(1)       $(1)
# 12118         $(1)       $(1)       $(1)       $(1)
# 12119         $(1)       $(1)       $(1)       $(1)
#
# [12120 rows x 38 columns]

# %%
df_mid = pd.DataFrame(df_in)
df_mid = df_mid.rename(columns={
    'Description': 'description',
    'CDM': 'local_code',
    'CDM (If Applicable)': 'local_code',
    'Code Type': 'line_type',
    'DRG (If Applicable)': 'drg',
    'CPT/HCPCS (If Applicable)': 'hcpcs_cpt',
    'EAPG (If Applicable)': 'eapg',
    'APC (If Applicable)': 'apc',
    'Rev Code (If Applicable)': 'rev_code',
    'DRG (If applicable)': 'drg',
    'CPT/HCPCS (If applicable)': 'hcpcs_cpt',
    'EAPG (If applicable)': 'eapg',
    'APC (If applicable)': 'apc',
    'Rev Code (If applicable)': 'rev_code'
})
del df_mid['Facility']
df_mid = df_mid[df_mid.columns.drop(list(df_mid.filter(regex='Unnamed')))]
df_mid.columns = df_mid.columns.str.strip()
df_mid
# Out:
#                                              description local_code  drg
# 0      SPINAL PROCEDURES W CC OR SPINAL NEUROSTIMULATORS        NaN   29  \
# 1                           SPINAL PROCEDURES W/O CC/MCC        NaN   30
# 2      Cardiac valve and other major cardiothoracic p...        NaN  216
# 3              MAJOR SMALL & LARGE BOWEL PROCEDURES W CC        NaN  330
# 4      SPINAL FUS EXC CERV W SPINAL CURV/MALIG/INFEC ...        NaN  457
# ...                                                  ...        ...  ...
# 12115                     ADD'L SEQUENTIAL INF UP TO 1HR  940505504  NaN
# 12116                     IV INFUSION FOR THERAPY 1ST HR  940505505  NaN
# 12117                                CONCURRENT INFUSION  940505506  NaN
# 12118                      HYDRATION IV INFUSION, 1ST HR  940505507  NaN
# 12119                      THERP.PROPHYLACTIC OR DX INJ.  940505508  NaN
#
#       hcpcs_cpt Gross Charge Cash Price     Minimum     Maximum
# 0           NaN    $155,356    $23,815    $155,356    $155,356   \
# 1           NaN     $75,085    $16,337     $50,208     $92,493
# 2           NaN         $(1)       $(1)        $(1)        $(1)
# 3           NaN     $48,961    $17,131     $36,645     $61,277
# 4           NaN    $186,653    $42,012    $186,653    $186,653
# ...         ...          ...        ...         ...         ...
# 12115       NaN       320.50      $128         $(1)        $(1)
# 12116       NaN       320.50      $128         $(1)        $(1)
# 12117       NaN       320.50      $128         $(1)        $(1)
# 12118       NaN       320.50      $128         $(1)        $(1)
# 12119       NaN       320.50      $128         $(1)        $(1)
#
#                      AETNA   AETNAMCR  ...        TRC    TRIWEST     TXHLSP
# 0       $1653.00 per diem    $21,650   ...   $21,650    $21,650    $21,650   \
# 1       $1653.00 per diem    $14,852   ...   $14,852    $14,852    $14,852
# 2                     $(1)       $(1)  ...       $(1)       $(1)       $(1)
# 3       $1653.00 per diem    $15,573   ...   $15,573    $15,573    $15,573
# 4       $1653.00 per diem    $38,193   ...   $38,193    $38,193    $38,193
# ...                    ...        ...  ...        ...        ...        ...
# 12115                 $(1)       $(1)  ...       $(1)       $(1)       $(1)
# 12116                 $(1)       $(1)  ...       $(1)       $(1)       $(1)
# 12117                 $(1)       $(1)  ...       $(1)       $(1)       $(1)
# 12118                 $(1)       $(1)  ...       $(1)       $(1)       $(1)
# 12119                 $(1)       $(1)  ...       $(1)       $(1)       $(1)
#
#         TXHLSTAR     UNITED  UNITEDMCR UNITEDSTAR      VAFEE         WC
# 0       $20,667    $25,380    $21,650    $20,667    $21,650    $18,143   \
# 1        $7,237    $30,996    $14,852     $7,237    $14,852    $22,158
# 2           $(1)       $(1)       $(1)       $(1)       $(1)       $(1)
# 3        $6,993    $20,920    $15,573     $6,993    $15,573    $14,955
# 4       $20,667    $79,752    $38,193    $20,667    $38,193    $57,011
# ...          ...        ...        ...        ...        ...        ...
# 12115       $(1)       $(1)       $(1)       $(1)       $(1)       $(1)
# 12116       $(1)       $(1)       $(1)       $(1)       $(1)       $(1)
# 12117       $(1)       $(1)       $(1)       $(1)       $(1)       $(1)
# 12118       $(1)       $(1)       $(1)       $(1)       $(1)       $(1)
# 12119       $(1)       $(1)       $(1)       $(1)       $(1)       $(1)
#
#          WELLMED
# 0       $21,650
# 1       $14,852
# 2           $(1)
# 3       $15,573
# 4       $38,193
# ...          ...
# 12115       $(1)
# 12116       $(1)
# 12117       $(1)
# 12118       $(1)
# 12119       $(1)
#
# [12120 rows x 37 columns]

# %%
money_idx = df_mid.columns.to_list().index('Gross Charge')
money_columns = df_mid.columns.to_list()[money_idx:]
print(money_columns)
remaining_columns = df_mid.columns.to_list()[:money_idx]
df_mid = pd.melt(df_mid, id_vars=remaining_columns, var_name='payer_name', value_name='standard_charge')
df_mid
# Out:
# ['Gross Charge', 'Cash Price', 'Minimum', 'Maximum', 'AETNA', 'AETNAMCR', 'ALLWELL', 'AMBETTER', 'BCTX', 'BCTXMCR', 'CH', 'CIGNA', 'DISCROLL', 'HUMANA', 'HUMANAMCR', 'MCD', 'MCR', 'MOLINA', 'MOLINAMCR', 'MOLINAMMP', 'PROMINENCE', 'SUPERIOR', 'SUPERMMP', 'TRC', 'TRIWEST', 'TXHLSP', 'TXHLSTAR', 'UNITED', 'UNITEDMCR', 'UNITEDSTAR', 'VAFEE', 'WC', 'WELLMED']
#                                               description local_code  drg
# 0       SPINAL PROCEDURES W CC OR SPINAL NEUROSTIMULATORS        NaN   29  \
# 1                            SPINAL PROCEDURES W/O CC/MCC        NaN   30
# 2       Cardiac valve and other major cardiothoracic p...        NaN  216
# 3               MAJOR SMALL & LARGE BOWEL PROCEDURES W CC        NaN  330
# 4       SPINAL FUS EXC CERV W SPINAL CURV/MALIG/INFEC ...        NaN  457
# ...                                                   ...        ...  ...
# 399955                     ADD'L SEQUENTIAL INF UP TO 1HR  940505504  NaN
# 399956                     IV INFUSION FOR THERAPY 1ST HR  940505505  NaN
# 399957                                CONCURRENT INFUSION  940505506  NaN
# 399958                      HYDRATION IV INFUSION, 1ST HR  940505507  NaN
# 399959                      THERP.PROPHYLACTIC OR DX INJ.  940505508  NaN
#
#        hcpcs_cpt    payer_name standard_charge
# 0            NaN  Gross Charge       $155,356
# 1            NaN  Gross Charge        $75,085
# 2            NaN  Gross Charge            $(1)
# 3            NaN  Gross Charge        $48,961
# 4            NaN  Gross Charge       $186,653
# ...          ...           ...             ...
# 399955       NaN       WELLMED            $(1)
# 399956       NaN       WELLMED            $(1)
# 399957       NaN       WELLMED            $(1)
# 399958       NaN       WELLMED            $(1)
# 399959       NaN       WELLMED            $(1)
#
# [399960 rows x 6 columns]

# %%
df_mid.dropna(subset=['standard_charge'], inplace=True)
df_mid['standard_charge'] = df_mid['standard_charge'].astype(str)
df_mid['standard_charge'] = df_mid['standard_charge'].str.strip()
df_mid['standard_charge'] = df_mid['standard_charge'].apply(lambda rate: rate.replace("$", "").replace(",", "").strip())
df_mid = df_mid[~df_mid['standard_charge'].str.contains("\(1\)")]
df_mid = df_mid[df_mid['standard_charge'] != "-"]
df_mid = df_mid[df_mid['standard_charge'] != "v"]
df_mid = df_mid[df_mid['standard_charge'] != 'Not Reimb']
df_mid = pd.DataFrame(df_mid)
df_mid
# Out:
#                                               description local_code  drg
# 0       SPINAL PROCEDURES W CC OR SPINAL NEUROSTIMULATORS        NaN   29  \
# 1                            SPINAL PROCEDURES W/O CC/MCC        NaN   30
# 3               MAJOR SMALL & LARGE BOWEL PROCEDURES W CC        NaN  330
# 4       SPINAL FUS EXC CERV W SPINAL CURV/MALIG/INFEC ...        NaN  457
# 5       SPINAL FUS EXC CERV W SPINAL CURV/MALIG/INFEC ...        NaN  458
# ...                                                   ...        ...  ...
# 388145                 Coagulation assessment blood test         NaN  NaN
# 388152                           New eye exam & treatment        NaN  NaN
# 388164                       Colorectal scrn; hi risk ind        NaN  NaN
# 388165                       Colon ca scrn not hi rsk ind        NaN  NaN
# 388166                       Inj for sacroiliac jt anesth        NaN  NaN
#
#        hcpcs_cpt    payer_name standard_charge
# 0            NaN  Gross Charge          155356
# 1            NaN  Gross Charge           75085
# 3            NaN  Gross Charge           48961
# 4            NaN  Gross Charge          186653
# 5            NaN  Gross Charge          180380
# ...          ...           ...             ...
# 388145     85730       WELLMED               6
# 388152     92018       WELLMED            2114
# 388164     G0105       WELLMED             831
# 388165     G0121       WELLMED             831
# 388166     G0260       WELLMED             644
#
# [33121 rows x 6 columns]

# %%
df_mid.loc[df_mid['standard_charge'].str.contains("  Per diem"), 'contracting_method'] = "per diem"
df_mid.loc[df_mid['standard_charge'].str.contains("  Per diem"), 'standard_charge'] = df_mid[df_mid['standard_charge'].str.contains("  Per diem")]['standard_charge'].str.replace(" Per diem", "")
df_mid['standard_charge'] = df_mid['standard_charge'].str.strip()

df_mid.loc[df_mid['standard_charge'].str.contains(" per diem"), 'contracting_method'] = "per diem"
df_mid.loc[df_mid['standard_charge'].str.contains(" per diem"), 'standard_charge'] = df_mid[df_mid['standard_charge'].str.contains(" per diem")]['standard_charge'].str.replace(" per diem", "")
df_mid.loc[df_mid['standard_charge'].str.contains(" Per Diem"), 'contracting_method'] = "per diem"
df_mid.loc[df_mid['standard_charge'].str.contains(" Per Diem"), 'standard_charge'] = df_mid[df_mid['standard_charge'].str.contains(" Per Diem")]['standard_charge'].str.replace(" Per Diem", "")
df_mid.loc[df_mid['standard_charge'].str.contains(" Per Deim"), 'contracting_method'] = "per diem"
df_mid.loc[df_mid['standard_charge'].str.contains(" Per Deim"), 'standard_charge'] = df_mid[df_mid['standard_charge'].str.contains(" Per Deim")]['standard_charge'].str.replace(" Per Deim", "")
df_mid.loc[df_mid['standard_charge'].str.contains(" Per Deiem"), 'contracting_method'] = "per diem"
df_mid.loc[df_mid['standard_charge'].str.contains(" Per Deiem"), 'standard_charge'] = df_mid[df_mid['standard_charge'].str.contains(" Per Deiem")]['standard_charge'].str.replace(" Per Deiem", "")

df_mid.loc[df_mid['standard_charge'].str.contains("% of Charges"), 'contracting_method'] = "percent of total billed charge"
df_mid.loc[df_mid['standard_charge'].str.contains("% of Charges"), 'standard_charge_percent'] = df_mid[df_mid['standard_charge'].str.contains("% of Charges")]['standard_charge'].str.replace("% of Charges", "")
df_mid.loc[df_mid['standard_charge'].str.contains("% of covered Charges"), 'contracting_method'] = "percent of total billed charge"
df_mid.loc[df_mid['standard_charge'].str.contains("% of covered Charges"), 'standard_charge_percent'] = df_mid[df_mid['standard_charge'].str.contains("% of covered Charges")]['standard_charge'].str.replace("% of covered Charges", "")
df_mid.loc[df_mid['standard_charge'].str.contains("Charges"), 'standard_charge'] = None

df_mid
# Out:
#                                               description local_code  drg
# 0       SPINAL PROCEDURES W CC OR SPINAL NEUROSTIMULATORS        NaN   29  \
# 1                            SPINAL PROCEDURES W/O CC/MCC        NaN   30
# 3               MAJOR SMALL & LARGE BOWEL PROCEDURES W CC        NaN  330
# 4       SPINAL FUS EXC CERV W SPINAL CURV/MALIG/INFEC ...        NaN  457
# 5       SPINAL FUS EXC CERV W SPINAL CURV/MALIG/INFEC ...        NaN  458
# ...                                                   ...        ...  ...
# 388145                 Coagulation assessment blood test         NaN  NaN
# 388152                           New eye exam & treatment        NaN  NaN
# 388164                       Colorectal scrn; hi risk ind        NaN  NaN
# 388165                       Colon ca scrn not hi rsk ind        NaN  NaN
# 388166                       Inj for sacroiliac jt anesth        NaN  NaN
#
#        hcpcs_cpt    payer_name standard_charge contracting_method
# 0            NaN  Gross Charge          155356                NaN  \
# 1            NaN  Gross Charge           75085                NaN
# 3            NaN  Gross Charge           48961                NaN
# 4            NaN  Gross Charge          186653                NaN
# 5            NaN  Gross Charge          180380                NaN
# ...          ...           ...             ...                ...
# 388145     85730       WELLMED               6                NaN
# 388152     92018       WELLMED            2114                NaN
# 388164     G0105       WELLMED             831                NaN
# 388165     G0121       WELLMED             831                NaN
# 388166     G0260       WELLMED             644                NaN
#
#        standard_charge_percent
# 0                          NaN
# 1                          NaN
# 3                          NaN
# 4                          NaN
# 5                          NaN
# ...                        ...
# 388145                     NaN
# 388152                     NaN
# 388164                     NaN
# 388165                     NaN
# 388166                     NaN
#
# [33121 rows x 8 columns]

# %%
df_mid['drg'] = df_mid['drg'].fillna('na')

def pad_drg_if_needed(drg):
    if drg == 'na':
        return drg
    
    if len(drg) == 1:
        return '00' + drg
    elif len(drg) == 2:
        return '0' + drg
    
    return drg

df_mid['drg'] = df_mid['drg'].apply(pad_drg_if_needed)
df_mid.loc[df_mid['drg'] == 'na', 'drg'] = None
df_mid
# Out:
#                                               description local_code   drg
# 0       SPINAL PROCEDURES W CC OR SPINAL NEUROSTIMULATORS        NaN   029  \
# 1                            SPINAL PROCEDURES W/O CC/MCC        NaN   030
# 3               MAJOR SMALL & LARGE BOWEL PROCEDURES W CC        NaN   330
# 4       SPINAL FUS EXC CERV W SPINAL CURV/MALIG/INFEC ...        NaN   457
# 5       SPINAL FUS EXC CERV W SPINAL CURV/MALIG/INFEC ...        NaN   458
# ...                                                   ...        ...   ...
# 388145                 Coagulation assessment blood test         NaN  None
# 388152                           New eye exam & treatment        NaN  None
# 388164                       Colorectal scrn; hi risk ind        NaN  None
# 388165                       Colon ca scrn not hi rsk ind        NaN  None
# 388166                       Inj for sacroiliac jt anesth        NaN  None
#
#        hcpcs_cpt    payer_name standard_charge contracting_method
# 0            NaN  Gross Charge          155356                NaN  \
# 1            NaN  Gross Charge           75085                NaN
# 3            NaN  Gross Charge           48961                NaN
# 4            NaN  Gross Charge          186653                NaN
# 5            NaN  Gross Charge          180380                NaN
# ...          ...           ...             ...                ...
# 388145     85730       WELLMED               6                NaN
# 388152     92018       WELLMED            2114                NaN
# 388164     G0105       WELLMED             831                NaN
# 388165     G0121       WELLMED             831                NaN
# 388166     G0260       WELLMED             644                NaN
#
#        standard_charge_percent
# 0                          NaN
# 1                          NaN
# 3                          NaN
# 4                          NaN
# 5                          NaN
# ...                        ...
# 388145                     NaN
# 388152                     NaN
# 388164                     NaN
# 388165                     NaN
# 388166                     NaN
#
# [33121 rows x 8 columns]

# %%
if 'line_type' in df_mid.columns:
    df_mid.loc[df_mid['line_type'] == 'APR-DRG', 'apr_drg'] = df_mid[df_mid['line_type'] == 'APR-DRG']['drg']
    df_mid.loc[df_mid['line_type'] == 'APR-DRG', 'code'] = df_mid[df_mid['line_type'] == 'APR-DRG']['drg']
    df_mid.loc[df_mid['line_type'] == 'MS-DRG', 'ms_drg'] = df_mid[df_mid['line_type'] == 'MS-DRG']['drg']
    df_mid.loc[df_mid['line_type'] == 'MS-DRG', 'code'] = df_mid[df_mid['line_type'] == 'MS-DRG']['drg']
    del df_mid['drg']
    df_mid.loc[df_mid['line_type'] == 'Chargemaster', 'code'] = df_mid[df_mid['line_type'] == 'Chargemaster']['local_code']
    df_mid.loc[df_mid['line_type'] == 'EAPG', 'code'] = df_mid[df_mid['line_type'] == 'EAPG']['eapg']
    df_mid.loc[df_mid['line_type'] == 'Other CPT/HCPCS', 'code'] = df_mid[df_mid['line_type'] == 'Other CPT/HCPCS']['hcpcs_cpt']
else:
    df_mid = df_mid.rename(columns={'drg': 'ms_drg'})

df_mid['thru'] = None
df_mid['icd'] = None
df_mid['ndc'] = None
df_mid['drug_hcpcs_multiplier'] = None
df_mid['drug_quantity'] = None
df_mid['drug_unit_of_measurement'] = None
df_mid['drug_type_of_measurement'] = None
df_mid['additional_generic_notes'] = None
df_mid['additional_payer_specific_notes'] = None

# %%
if 'line_type' in df_mid.columns:
    set(df_mid['line_type'].tolist())
else:
    df_mid['line_type'] = None
    
if not 'code' in df_mid.columns:
    df_mid['code'] = None
    
if not 'apr_drg' in df_mid.columns:
    df_mid['apr_drg'] = None
    
if not 'eapg' in df_mid.columns:
    df_mid['eapg'] = None

# %%
def pad_apc_if_needed(apc):
    if type(apc) != str:
        return apc
    
    apc = apc.zfill(4)
    return apc

if 'apc' in df_mid.columns:
    df_mid['apc'] = df_mid['apc'].apply(pad_apc_if_needed)
else:
    df_mid['apc'] = None

# %%
df_mid['modifiers'] = None

df_mid['hcpcs_cpt'] = df_mid['hcpcs_cpt'].fillna('')
df_mid.loc[df_mid['hcpcs_cpt'].str.len() == 7, 'modifiers'] = df_mid[df_mid['hcpcs_cpt'].str.len() == 7]['hcpcs_cpt'].str[-2:]
df_mid.loc[df_mid['hcpcs_cpt'].str.len() == 7, 'hcpcs_cpt'] = df_mid[df_mid['hcpcs_cpt'].str.len() == 7]['hcpcs_cpt'].str[:5]
df_mid.loc[df_mid['hcpcs_cpt'] == '', 'hcpcs_cpt'] = None
df_mid.loc[df_mid['hcpcs_cpt'] == 'XXXXX', 'hcpcs_cpt'] = None
df_mid.loc[df_mid['hcpcs_cpt'] == 'C1C13', 'hcpcs_cpt'] = None

df_mid['modifiers'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df_mid['payer_name'] = df_mid['payer_name'].apply(lambda payer_orig: payer_orig.strip())

def payer_category_from_payer_orig(payer_orig):
    if payer_orig == "Cash Price":
        return 'cash'
    elif payer_orig == "Gross Charge":
        return 'gross'
    elif payer_orig == "Minimum":
        return 'min'
    elif payer_orig == "Maximum":
        return 'max'
    
    return 'payer'

df_mid['payer_category'] = df_mid['payer_name'].apply(payer_category_from_payer_orig)
df_mid
# Out:
#                                               description local_code ms_drg
# 0       SPINAL PROCEDURES W CC OR SPINAL NEUROSTIMULATORS        NaN    029  \
# 1                            SPINAL PROCEDURES W/O CC/MCC        NaN    030
# 3               MAJOR SMALL & LARGE BOWEL PROCEDURES W CC        NaN    330
# 4       SPINAL FUS EXC CERV W SPINAL CURV/MALIG/INFEC ...        NaN    457
# 5       SPINAL FUS EXC CERV W SPINAL CURV/MALIG/INFEC ...        NaN    458
# ...                                                   ...        ...    ...
# 388145                 Coagulation assessment blood test         NaN   None
# 388152                           New eye exam & treatment        NaN   None
# 388164                       Colorectal scrn; hi risk ind        NaN   None
# 388165                       Colon ca scrn not hi rsk ind        NaN   None
# 388166                       Inj for sacroiliac jt anesth        NaN   None
#
#        hcpcs_cpt    payer_name standard_charge contracting_method
# 0           None  Gross Charge          155356                NaN  \
# 1           None  Gross Charge           75085                NaN
# 3           None  Gross Charge           48961                NaN
# 4           None  Gross Charge          186653                NaN
# 5           None  Gross Charge          180380                NaN
# ...          ...           ...             ...                ...
# 388145     85730       WELLMED               6                NaN
# 388152     92018       WELLMED            2114                NaN
# 388164     G0105       WELLMED             831                NaN
# 388165     G0121       WELLMED             831                NaN
# 388166     G0260       WELLMED             644                NaN
#
#        standard_charge_percent  thru   icd  ... drug_type_of_measurement
# 0                          NaN  None  None  ...                     None  \
# 1                          NaN  None  None  ...                     None
# 3                          NaN  None  None  ...                     None
# 4                          NaN  None  None  ...                     None
# 5                          NaN  None  None  ...                     None
# ...                        ...   ...   ...  ...                      ...
# 388145                     NaN  None  None  ...                     None
# 388152                     NaN  None  None  ...                     None
# 388164                     NaN  None  None  ...                     None
# 388165                     NaN  None  None  ...                     None
# 388166                     NaN  None  None  ...                     None
#
#        additional_generic_notes additional_payer_specific_notes line_type
# 0                          None                            None      None  \
# 1                          None                            None      None
# 3                          None                            None      None
# 4                          None                            None      None
# 5                          None                            None      None
# ...                         ...                             ...       ...
# 388145                     None                            None      None
# 388152                     None                            None      None
# 388164                     None                            None      None
# 388165                     None                            None      None
# 388166                     None                            None      None
#
#         code apr_drg  eapg   apc modifiers payer_category
# 0       None    None  None  None      None          gross
# 1       None    None  None  None      None          gross
# 3       None    None  None  None      None          gross
# 4       None    None  None  None      None          gross
# 5       None    None  None  None      None          gross
# ...      ...     ...   ...   ...       ...            ...
# 388145  None    None  None  None      None          payer
# 388152  None    None  None  None      None          payer
# 388164  None    None  None  None      None          payer
# 388165  None    None  None  None      None          payer
# 388166  None    None  None  None      None          payer
#
# [33121 rows x 24 columns]

# %%
from helpers import pad_rev_code_if_needed
if 'rev_code' in df_mid.columns:
    df_mid['rev_code'] = df_mid['rev_code'].apply(pad_rev_code_if_needed)
else:
    df_mid['rev_code'] = None
df_mid['billing_class'] = None
df_mid['setting'] = None
df_mid['plan_name'] = None
df_mid
# Out:
#                                               description local_code ms_drg
# 0       SPINAL PROCEDURES W CC OR SPINAL NEUROSTIMULATORS        NaN    029  \
# 1                            SPINAL PROCEDURES W/O CC/MCC        NaN    030
# 3               MAJOR SMALL & LARGE BOWEL PROCEDURES W CC        NaN    330
# 4       SPINAL FUS EXC CERV W SPINAL CURV/MALIG/INFEC ...        NaN    457
# 5       SPINAL FUS EXC CERV W SPINAL CURV/MALIG/INFEC ...        NaN    458
# ...                                                   ...        ...    ...
# 388145                 Coagulation assessment blood test         NaN   None
# 388152                           New eye exam & treatment        NaN   None
# 388164                       Colorectal scrn; hi risk ind        NaN   None
# 388165                       Colon ca scrn not hi rsk ind        NaN   None
# 388166                       Inj for sacroiliac jt anesth        NaN   None
#
#        hcpcs_cpt    payer_name standard_charge contracting_method
# 0           None  Gross Charge          155356                NaN  \
# 1           None  Gross Charge           75085                NaN
# 3           None  Gross Charge           48961                NaN
# 4           None  Gross Charge          186653                NaN
# 5           None  Gross Charge          180380                NaN
# ...          ...           ...             ...                ...
# 388145     85730       WELLMED               6                NaN
# 388152     92018       WELLMED            2114                NaN
# 388164     G0105       WELLMED             831                NaN
# 388165     G0121       WELLMED             831                NaN
# 388166     G0260       WELLMED             644                NaN
#
#        standard_charge_percent  thru   icd  ...  code apr_drg  eapg   apc
# 0                          NaN  None  None  ...  None    None  None  None  \
# 1                          NaN  None  None  ...  None    None  None  None
# 3                          NaN  None  None  ...  None    None  None  None
# 4                          NaN  None  None  ...  None    None  None  None
# 5                          NaN  None  None  ...  None    None  None  None
# ...                        ...   ...   ...  ...   ...     ...   ...   ...
# 388145                     NaN  None  None  ...  None    None  None  None
# 388152                     NaN  None  None  ...  None    None  None  None
# 388164                     NaN  None  None  ...  None    None  None  None
# 388165                     NaN  None  None  ...  None    None  None  None
# 388166                     NaN  None  None  ...  None    None  None  None
#
#        modifiers payer_category rev_code billing_class setting plan_name
# 0           None          gross     None          None    None      None
# 1           None          gross     None          None    None      None
# 3           None          gross     None          None    None      None
# 4           None          gross     None          None    None      None
# 5           None          gross     None          None    None      None
# ...          ...            ...      ...           ...     ...       ...
# 388145      None          payer     None          None    None      None
# 388152      None          payer     None          None    None      None
# 388164      None          payer     None          None    None      None
# 388165      None          payer     None          None    None      None
# 388166      None          payer     None          None    None      None
#
# [33121 rows x 28 columns]

# %%
df_mid['hospital_id'] = ccn

# %%
df_out = pd.DataFrame(df_mid[TARGET_COLUMNS])
df_out
# Out:
#        hospital_id line_type
# 0           450825      None  \
# 1           450825      None
# 3           450825      None
# 4           450825      None
# 5           450825      None
# ...            ...       ...
# 388145      450825      None
# 388152      450825      None
# 388164      450825      None
# 388165      450825      None
# 388166      450825      None
#
#                                               description rev_code local_code
# 0       SPINAL PROCEDURES W CC OR SPINAL NEUROSTIMULATORS     None        NaN  \
# 1                            SPINAL PROCEDURES W/O CC/MCC     None        NaN
# 3               MAJOR SMALL & LARGE BOWEL PROCEDURES W CC     None        NaN
# 4       SPINAL FUS EXC CERV W SPINAL CURV/MALIG/INFEC ...     None        NaN
# 5       SPINAL FUS EXC CERV W SPINAL CURV/MALIG/INFEC ...     None        NaN
# ...                                                   ...      ...        ...
# 388145                 Coagulation assessment blood test      None        NaN
# 388152                           New eye exam & treatment     None        NaN
# 388164                       Colorectal scrn; hi risk ind     None        NaN
# 388165                       Colon ca scrn not hi rsk ind     None        NaN
# 388166                       Inj for sacroiliac jt anesth     None        NaN
#
#         code ms_drg apr_drg  eapg hcpcs_cpt  ... billing_class setting
# 0       None    029    None  None      None  ...          None    None  \
# 1       None    030    None  None      None  ...          None    None
# 3       None    330    None  None      None  ...          None    None
# 4       None    457    None  None      None  ...          None    None
# 5       None    458    None  None      None  ...          None    None
# ...      ...    ...     ...   ...       ...  ...           ...     ...
# 388145  None   None    None  None     85730  ...          None    None
# 388152  None   None    None  None     92018  ...          None    None
# 388164  None   None    None  None     G0105  ...          None    None
# 388165  None   None    None  None     G0121  ...          None    None
# 388166  None   None    None  None     G0260  ...          None    None
#
#        payer_category    payer_name plan_name standard_charge
# 0               gross  Gross Charge      None          155356  \
# 1               gross  Gross Charge      None           75085
# 3               gross  Gross Charge      None           48961
# 4               gross  Gross Charge      None          186653
# 5               gross  Gross Charge      None          180380
# ...               ...           ...       ...             ...
# 388145          payer       WELLMED      None               6
# 388152          payer       WELLMED      None            2114
# 388164          payer       WELLMED      None             831
# 388165          payer       WELLMED      None             831
# 388166          payer       WELLMED      None             644
#
#        standard_charge_percent contracting_method additional_generic_notes
# 0                          NaN                NaN                     None  \
# 1                          NaN                NaN                     None
# 3                          NaN                NaN                     None
# 4                          NaN                NaN                     None
# 5                          NaN                NaN                     None
# ...                        ...                ...                      ...
# 388145                     NaN                NaN                     None
# 388152                     NaN                NaN                     None
# 388164                     NaN                NaN                     None
# 388165                     NaN                NaN                     None
# 388166                     NaN                NaN                     None
#
#        additional_payer_specific_notes
# 0                                 None
# 1                                 None
# 3                                 None
# 4                                 None
# 5                                 None
# ...                                ...
# 388145                            None
# 388152                            None
# 388164                            None
# 388165                            None
# 388166                            None
#
# [33121 rows x 29 columns]

# %%
df_out.to_csv("eskycity_" + ccn + ".csv", index=False)
