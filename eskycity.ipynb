# %%
import pandas as pd

# %%
TARGET_COLUMNS = [ 
    'hospital_id',
    #'row_id',
    'line_type',
    'description',
    'rev_code',
    'local_code',
    'code',
    'ms_drg',
    'apr_drg',
    'eapg',
    'hcpcs_cpt',
    'modifiers',
    'thru',
    'apc',
    'icd',
    'ndc',
    'drug_hcpcs_multiplier',
    'drug_quantity',
    'drug_unit_of_measurement',
    'drug_type_of_measurement',
    'billing_class',
    'setting',
    'payer_category',
    'payer_name',
    'plan_name',
    'standard_charge',
    'standard_charge_percent',
    'contracting_method',
    'additional_generic_notes',
    'additional_payer_specific_notes'
]

# %%
ccn = "450811"
url = "https://uhsfilecdn.eskycity.net/ac/233069260_south-texas-health-system-heart_standardcharges.csv"
filename = url.split("/")[-1]
ein = filename.split("_")[0]
ein = ein[:2] + "-" + ein[2:]

# %%
import subprocess
subprocess.run(["wget", "--no-clobber", url, "-O", filename])
# Out:
# --2023-05-08 15:18:50--  https://uhsfilecdn.eskycity.net/ac/233069260_south-texas-health-system-heart_standardcharges.csv
# Resolving uhsfilecdn.eskycity.net (uhsfilecdn.eskycity.net)... 151.139.128.10
# Connecting to uhsfilecdn.eskycity.net (uhsfilecdn.eskycity.net)|151.139.128.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27482529 (26M) [application/octet-stream]
# Saving to: ‘233069260_south-texas-health-system-heart_standardcharges.csv’
#
#      0K .......... .......... .......... .......... ..........  0%  352K 76s
#     50K .......... .......... .......... .......... ..........  0%  629K 59s
#    100K .......... .......... .......... .......... ..........  0% 44.0M 40s
#    150K .......... .......... .......... .......... ..........  0%  632K 40s
#    200K .......... .......... .......... .......... ..........  0%  113M 32s
#    250K .......... .......... .......... .......... ..........  1% 61.5M 27s
#    300K .......... .......... .......... .......... ..........  1%  104M 23s
#    350K .......... .......... .......... .......... ..........  1%  106M 20s
#    400K .......... .......... .......... .......... ..........  1% 90.7M 18s
#    450K .......... .......... .......... .......... ..........  1%  641K 20s
#    500K .......... .......... .......... .......... ..........  2%  143M 18s
#    550K .......... .......... .......... .......... ..........  2%  136M 17s
#    600K .......... .......... .......... .......... ..........  2%  118M 15s
#    650K .......... .......... .......... .......... ..........  2%  153M 14s
#    700K .......... .......... .......... .......... ..........  2% 76.3M 13s
#    750K .......... .......... .......... .......... ..........  2%  111M 13s
#    800K .......... .......... .......... .......... ..........  3%  143M 12s
#    850K .......... .......... .......... .......... ..........  3%  145M 11s
#    900K .......... .......... .......... .......... ..........  3%  141M 11s
#    950K .......... .......... .......... .......... ..........  3%  101M 10s
#   1000K .......... .......... .......... .......... ..........  3%  120M 10s
#   1050K .......... .......... .......... .......... ..........  4%  653K 11s
#   1100K .......... .......... .......... .......... ..........  4%  130M 10s
#   1150K .......... .......... .......... .......... ..........  4%  166M 10s
#   1200K .......... .......... .......... .......... ..........  4%  157M 10s
#   1250K .......... .......... .......... .......... ..........  4%  111M 9s
#   1300K .......... .......... .......... .......... ..........  5% 95.6M 9s
#   1350K .......... .......... .......... .......... ..........  5% 95.8M 8s
#   1400K .......... .......... .......... .......... ..........  5%  141M 8s
#  26550K .......... .......... .......... .......... .......... 99%  108M 0s
#  26600K .......... .......... .......... .......... .......... 99%  127M 0s
#  26650K .......... .......... .......... .......... .......... 99%  224M 0s
#  26700K .......... .......... .......... .......... .......... 99%  217M 0s
#  26750K .......... .......... .......... .......... .......... 99% 78.3M 0s
#  26800K .......... .......... .......... ........             100% 61.4M=1.4s
#
# 2023-05-08 15:18:52 (18.5 MB/s) - ‘233069260_south-texas-health-system-heart_standardcharges.csv’ saved [27482529/27482529]
# CompletedProcess(args=['wget', '--no-clobber', 'https://uhsfilecdn.eskycity.net/ac/233069260_south-texas-health-system-heart_standardcharges.csv', '-O', '233069260_south-texas-health-system-heart_standardcharges.csv'], returncode=0)

# %%
df_in = pd.read_csv(filename, skiprows=3, dtype=str, low_memory=True)
df_in
# Out:
#                               Facility                    Description
# 0      South Texas Health System Heart                 SCREW 4.7X45MM  \
# 1      South Texas Health System Heart          SCREW LOCKING 1.5X9MM
# 2      South Texas Health System Heart    SHELL G7 3H NOCEMENT 60MM G
# 3      South Texas Health System Heart      OPTIFIX ABSORABLE FIX SYS
# 4      South Texas Health System Heart  PIPELINE FLEX EMBOL 2.75X10MM
# ...                                ...                            ...
# 67030  South Texas Health System Heart   Insj/rplc nstim apnea pls gn
# 67031  South Texas Health System Heart   Rmvl/rplc nstim apnea pls gn
# 67032  South Texas Health System Heart        Transplt allo hct/donor
# 67033  South Texas Health System Heart        Sipuleucel-t auto cd54+
# 67034  South Texas Health System Heart      Prosth retina receive&gen
#
#             CDM        Code Type DRG (If Applicable)
# 0      38000154     Chargemaster                 NaN  \
# 1      38000204     Chargemaster                 NaN
# 2      38000261     Chargemaster                 NaN
# 3      38000279     Chargemaster                 NaN
# 4      38000394     Chargemaster                 NaN
# ...         ...              ...                 ...
# 67030       NaN  Other CPT/HCPCS                 NaN
# 67031       NaN  Other CPT/HCPCS                 NaN
# 67032       NaN  Other CPT/HCPCS                 NaN
# 67033       NaN  Other CPT/HCPCS                 NaN
# 67034       NaN  Other CPT/HCPCS                 NaN
#
#       CPT/HCPCS (If Applicable) EAPG (If Applicable) APC (If Applicable)
# 0                         C1713                  NaN                 NaN  \
# 1                         C1713                  NaN                 NaN
# 2                         C1776                  NaN                 NaN
# 3                           NaN                  NaN                 NaN
# 4                         C1889                  NaN                 NaN
# ...                         ...                  ...                 ...
# 67030                     0427T                  NaN                5465
# 67031                     0431T                  NaN                5465
# 67032                     38240                  NaN                5244
# 67033                     Q2043                  NaN                9273
# 67034                     0100T                  NaN                1908
#
#       Rev Code (If Applicable)    Gross Charge     ...
# 0                          278            $2,852   ...  \
# 1                          278              $294   ...
# 2                          278            $3,592   ...
# 3                          272           $19,104   ...
# 4                          278           $53,268   ...
# ...                        ...                ...  ...
# 67030                      NaN               ($1)  ...
# 67031                      NaN               ($1)  ...
# 67032                      NaN               ($1)  ...
# 67033                      NaN               ($1)  ...
# 67034                      NaN               ($1)  ...
#
#         Prominence Medicare HMO       Sharyland ISD     Superior Health
# 0                            ($1)             $1,055                 ($1)  \
# 1                            ($1)               $109                 ($1)
# 2                            ($1)             $1,329                 ($1)
# 3                            ($1)             $7,068                 ($1)
# 4                            ($1)             $3,500                 ($1)
# ...                           ...                 ...                 ...
# 67030                    $29,445     40% of Charges                  ($1)
# 67031                    $29,445     40% of Charges                  ($1)
# 67032                    $31,838     40% of Charges                  ($1)
# 67033                    $49,672     40% of Charges                  ($1)
# 67034                   $152,501     40% of Charges                  ($1)
#
#         Texas HealthSpring     Texas Star Medicaid                UMTB
# 0                       ($1)                    ($1)             $2,139   \
# 1                       ($1)                    ($1)               $221
# 2                       ($1)                    ($1)             $2,694
# 3                       ($1)                    ($1)            $14,328
# 4                       ($1)                    ($1)            $39,951
# ...                      ...                     ...                 ...
# 67030               $29,445                     ($1)    75% of Charges
# 67031               $29,445                     ($1)    75% of Charges
# 67032               $31,838                     ($1)    75% of Charges
# 67033               $49,672                     ($1)    75% of Charges
# 67034              $152,501                     ($1)    75% of Charges
#
#         United Healthcare     United Healthcare Medicare     Wellmed
# 0                      ($1)                           ($1)        ($1)  \
# 1                      ($1)                           ($1)        ($1)
# 2                      ($1)                           ($1)        ($1)
# 3                      ($1)                           ($1)        ($1)
# 4                      ($1)                           ($1)        ($1)
# ...                     ...                            ...         ...
# 67030                  ($1)                       $30,045     $29,445
# 67031                  ($1)                       $30,045     $29,445
# 67032                  ($1)                       $32,488     $31,838
# 67033                  ($1)                       $50,685     $49,672
# 67034                  ($1)                      $155,612    $152,501
#
#            Westlaco ISD
# 0                 $1,340
# 1                   $138
# 2                 $1,688
# 3                 $7,642
# 4                 $3,500
# ...                   ...
# 67030    40% of Charges
# 67031    40% of Charges
# 67032    40% of Charges
# 67033    40% of Charges
# 67034    40% of Charges
#
# [67035 rows x 52 columns]

# %%
df_mid = pd.DataFrame(df_in)
df_mid = df_mid.rename(columns={
    'Description': 'description',
    'CDM': 'local_code',
    'CDM (If Applicable)': 'local_code',
    'Code Type': 'line_type',
    'DRG (If Applicable)': 'drg',
    'CPT/HCPCS (If Applicable)': 'hcpcs_cpt',
    'EAPG (If Applicable)': 'eapg',
    'APC (If Applicable)': 'apc',
    'Rev Code (If Applicable)': 'rev_code',
    'DRG (If applicable)': 'drg',
    'CPT/HCPCS (If applicable)': 'hcpcs_cpt',
    'EAPG (If applicable)': 'eapg',
    'APC (If applicable)': 'apc',
    'Rev Code (If applicable)': 'rev_code'
})
del df_mid['Facility']
df_mid = df_mid[df_mid.columns.drop(list(df_mid.filter(regex='Unnamed')))]
df_mid.columns = df_mid.columns.str.strip()
df_mid
# Out:
#                          description local_code        line_type  drg
# 0                     SCREW 4.7X45MM   38000154     Chargemaster  NaN  \
# 1              SCREW LOCKING 1.5X9MM   38000204     Chargemaster  NaN
# 2        SHELL G7 3H NOCEMENT 60MM G   38000261     Chargemaster  NaN
# 3          OPTIFIX ABSORABLE FIX SYS   38000279     Chargemaster  NaN
# 4      PIPELINE FLEX EMBOL 2.75X10MM   38000394     Chargemaster  NaN
# ...                              ...        ...              ...  ...
# 67030   Insj/rplc nstim apnea pls gn        NaN  Other CPT/HCPCS  NaN
# 67031   Rmvl/rplc nstim apnea pls gn        NaN  Other CPT/HCPCS  NaN
# 67032        Transplt allo hct/donor        NaN  Other CPT/HCPCS  NaN
# 67033        Sipuleucel-t auto cd54+        NaN  Other CPT/HCPCS  NaN
# 67034      Prosth retina receive&gen        NaN  Other CPT/HCPCS  NaN
#
#       hcpcs_cpt eapg   apc rev_code Gross Charge Cash Price  ...
# 0         C1713  NaN   NaN      278      $2,852     $1,141   ...  \
# 1         C1713  NaN   NaN      278        $294       $118   ...
# 2         C1776  NaN   NaN      278      $3,592     $1,437   ...
# 3           NaN  NaN   NaN      272     $19,104     $7,642   ...
# 4         C1889  NaN   NaN      278     $53,268    $21,307   ...
# ...         ...  ...   ...      ...          ...        ...  ...
# 67030     0427T  NaN  5465      NaN         ($1)       ($1)  ...
# 67031     0431T  NaN  5465      NaN         ($1)       ($1)  ...
# 67032     38240  NaN  5244      NaN         ($1)       ($1)  ...
# 67033     Q2043  NaN  9273      NaN         ($1)       ($1)  ...
# 67034     0100T  NaN  1908      NaN         ($1)       ($1)  ...
#
#       Prominence Medicare HMO       Sharyland ISD Superior Health
# 0                        ($1)             $1,055             ($1)  \
# 1                        ($1)               $109             ($1)
# 2                        ($1)             $1,329             ($1)
# 3                        ($1)             $7,068             ($1)
# 4                        ($1)             $3,500             ($1)
# ...                       ...                 ...             ...
# 67030                $29,445     40% of Charges              ($1)
# 67031                $29,445     40% of Charges              ($1)
# 67032                $31,838     40% of Charges              ($1)
# 67033                $49,672     40% of Charges              ($1)
# 67034               $152,501     40% of Charges              ($1)
#
#       Texas HealthSpring Texas Star Medicaid                UMTB
# 0                   ($1)                ($1)             $2,139   \
# 1                   ($1)                ($1)               $221
# 2                   ($1)                ($1)             $2,694
# 3                   ($1)                ($1)            $14,328
# 4                   ($1)                ($1)            $39,951
# ...                  ...                 ...                 ...
# 67030           $29,445                 ($1)    75% of Charges
# 67031           $29,445                 ($1)    75% of Charges
# 67032           $31,838                 ($1)    75% of Charges
# 67033           $49,672                 ($1)    75% of Charges
# 67034          $152,501                 ($1)    75% of Charges
#
#       United Healthcare United Healthcare Medicare    Wellmed
# 0                  ($1)                       ($1)       ($1)  \
# 1                  ($1)                       ($1)       ($1)
# 2                  ($1)                       ($1)       ($1)
# 3                  ($1)                       ($1)       ($1)
# 4                  ($1)                       ($1)       ($1)
# ...                 ...                        ...        ...
# 67030              ($1)                   $30,045    $29,445
# 67031              ($1)                   $30,045    $29,445
# 67032              ($1)                   $32,488    $31,838
# 67033              ($1)                   $50,685    $49,672
# 67034              ($1)                  $155,612   $152,501
#
#              Westlaco ISD
# 0                 $1,340
# 1                   $138
# 2                 $1,688
# 3                 $7,642
# 4                 $3,500
# ...                   ...
# 67030    40% of Charges
# 67031    40% of Charges
# 67032    40% of Charges
# 67033    40% of Charges
# 67034    40% of Charges
#
# [67035 rows x 51 columns]

# %%
money_idx = df_mid.columns.to_list().index('Gross Charge')
money_columns = df_mid.columns.to_list()[money_idx:]
print(money_columns)
remaining_columns = df_mid.columns.to_list()[:money_idx]
df_mid = pd.melt(df_mid, id_vars=remaining_columns, var_name='payer_name', value_name='standard_charge')
df_mid
# Out:
# ['Gross Charge', 'Cash Price', 'Minimum', 'Maximum', 'Aetna', 'Aetna Hidalgo County', 'Aetna Medicare', 'Aetna NBD', 'Allegian Health', 'Ambetter', 'Blue Advantage', 'Blue Cross of Texas', 'Blue Essentials HMO', 'Blue Cross Medicare HMO', 'Blue Cross Medicare PPO', 'Care Improvement', 'Cigna HMO', 'Cigna PPO', 'Coventry', 'Driscoll Medicaid', 'Edinburg', 'First Health / Coventry', 'Friday Health', 'Healthcare Highways', 'HealthSmart', 'Humana', 'Humana Medicare', 'IMS City of Hidalgo', 'Molina Health Exchange', 'Molina Medicaid', 'Molina Medicare', 'Multiplan', 'PHCS', 'Prominence Medicare HMO', 'Sharyland ISD', 'Superior Health', 'Texas HealthSpring', 'Texas Star Medicaid', 'UMTB', 'United Healthcare', 'United Healthcare Medicare', 'Wellmed', 'Westlaco ISD']
#                            description local_code        line_type  drg
# 0                       SCREW 4.7X45MM   38000154     Chargemaster  NaN  \
# 1                SCREW LOCKING 1.5X9MM   38000204     Chargemaster  NaN
# 2          SHELL G7 3H NOCEMENT 60MM G   38000261     Chargemaster  NaN
# 3            OPTIFIX ABSORABLE FIX SYS   38000279     Chargemaster  NaN
# 4        PIPELINE FLEX EMBOL 2.75X10MM   38000394     Chargemaster  NaN
# ...                                ...        ...              ...  ...
# 2882500   Insj/rplc nstim apnea pls gn        NaN  Other CPT/HCPCS  NaN
# 2882501   Rmvl/rplc nstim apnea pls gn        NaN  Other CPT/HCPCS  NaN
# 2882502        Transplt allo hct/donor        NaN  Other CPT/HCPCS  NaN
# 2882503        Sipuleucel-t auto cd54+        NaN  Other CPT/HCPCS  NaN
# 2882504      Prosth retina receive&gen        NaN  Other CPT/HCPCS  NaN
#
#         hcpcs_cpt eapg   apc rev_code    payer_name     standard_charge
# 0           C1713  NaN   NaN      278  Gross Charge             $2,852
# 1           C1713  NaN   NaN      278  Gross Charge               $294
# 2           C1776  NaN   NaN      278  Gross Charge             $3,592
# 3             NaN  NaN   NaN      272  Gross Charge            $19,104
# 4           C1889  NaN   NaN      278  Gross Charge            $53,268
# ...           ...  ...   ...      ...           ...                 ...
# 2882500     0427T  NaN  5465      NaN  Westlaco ISD    40% of Charges
# 2882501     0431T  NaN  5465      NaN  Westlaco ISD    40% of Charges
# 2882502     38240  NaN  5244      NaN  Westlaco ISD    40% of Charges
# 2882503     Q2043  NaN  9273      NaN  Westlaco ISD    40% of Charges
# 2882504     0100T  NaN  1908      NaN  Westlaco ISD    40% of Charges
#
# [2882505 rows x 10 columns]

# %%
df_mid.dropna(subset=['standard_charge'], inplace=True)
df_mid['standard_charge'] = df_mid['standard_charge'].astype(str)
df_mid['standard_charge'] = df_mid['standard_charge'].str.strip()
df_mid['standard_charge'] = df_mid['standard_charge'].apply(lambda rate: rate.replace("$", "").replace(",", "").strip())
df_mid = df_mid[~df_mid['standard_charge'].str.contains("\(1\)")]
df_mid = df_mid[df_mid['standard_charge'] != "-"]
df_mid = df_mid[df_mid['standard_charge'] != "v"]
df_mid = df_mid[df_mid['standard_charge'] != 'Not Reimb']
df_mid = pd.DataFrame(df_mid)
df_mid
# Out:
#                            description local_code        line_type  drg
# 0                       SCREW 4.7X45MM   38000154     Chargemaster  NaN  \
# 1                SCREW LOCKING 1.5X9MM   38000204     Chargemaster  NaN
# 2          SHELL G7 3H NOCEMENT 60MM G   38000261     Chargemaster  NaN
# 3            OPTIFIX ABSORABLE FIX SYS   38000279     Chargemaster  NaN
# 4        PIPELINE FLEX EMBOL 2.75X10MM   38000394     Chargemaster  NaN
# ...                                ...        ...              ...  ...
# 2882500   Insj/rplc nstim apnea pls gn        NaN  Other CPT/HCPCS  NaN
# 2882501   Rmvl/rplc nstim apnea pls gn        NaN  Other CPT/HCPCS  NaN
# 2882502        Transplt allo hct/donor        NaN  Other CPT/HCPCS  NaN
# 2882503        Sipuleucel-t auto cd54+        NaN  Other CPT/HCPCS  NaN
# 2882504      Prosth retina receive&gen        NaN  Other CPT/HCPCS  NaN
#
#         hcpcs_cpt eapg   apc rev_code    payer_name standard_charge
# 0           C1713  NaN   NaN      278  Gross Charge            2852
# 1           C1713  NaN   NaN      278  Gross Charge             294
# 2           C1776  NaN   NaN      278  Gross Charge            3592
# 3             NaN  NaN   NaN      272  Gross Charge           19104
# 4           C1889  NaN   NaN      278  Gross Charge           53268
# ...           ...  ...   ...      ...           ...             ...
# 2882500     0427T  NaN  5465      NaN  Westlaco ISD  40% of Charges
# 2882501     0431T  NaN  5465      NaN  Westlaco ISD  40% of Charges
# 2882502     38240  NaN  5244      NaN  Westlaco ISD  40% of Charges
# 2882503     Q2043  NaN  9273      NaN  Westlaco ISD  40% of Charges
# 2882504     0100T  NaN  1908      NaN  Westlaco ISD  40% of Charges
#
# [1679399 rows x 10 columns]

# %%
df_mid.loc[df_mid['standard_charge'].str.contains("  Per diem"), 'contracting_method'] = "per diem"
df_mid.loc[df_mid['standard_charge'].str.contains("  Per diem"), 'standard_charge'] = df_mid[df_mid['standard_charge'].str.contains("  Per diem")]['standard_charge'].str.replace(" Per diem", "")
df_mid['standard_charge'] = df_mid['standard_charge'].str.strip()

df_mid.loc[df_mid['standard_charge'].str.contains(" per diem"), 'contracting_method'] = "per diem"
df_mid.loc[df_mid['standard_charge'].str.contains(" per diem"), 'standard_charge'] = df_mid[df_mid['standard_charge'].str.contains(" per diem")]['standard_charge'].str.replace(" per diem", "")
df_mid.loc[df_mid['standard_charge'].str.contains(" Per Diem"), 'contracting_method'] = "per diem"
df_mid.loc[df_mid['standard_charge'].str.contains(" Per Diem"), 'standard_charge'] = df_mid[df_mid['standard_charge'].str.contains(" Per Diem")]['standard_charge'].str.replace(" Per Diem", "")
df_mid.loc[df_mid['standard_charge'].str.contains(" Per Deim"), 'contracting_method'] = "per diem"
df_mid.loc[df_mid['standard_charge'].str.contains(" Per Deim"), 'standard_charge'] = df_mid[df_mid['standard_charge'].str.contains(" Per Deim")]['standard_charge'].str.replace(" Per Deim", "")
df_mid.loc[df_mid['standard_charge'].str.contains(" Per Deiem"), 'contracting_method'] = "per diem"
df_mid.loc[df_mid['standard_charge'].str.contains(" Per Deiem"), 'standard_charge'] = df_mid[df_mid['standard_charge'].str.contains(" Per Deiem")]['standard_charge'].str.replace(" Per Deiem", "")

df_mid.loc[df_mid['standard_charge'].str.contains("% of Charges"), 'contracting_method'] = "percent of total billed charge"
df_mid.loc[df_mid['standard_charge'].str.contains("% of Charges"), 'standard_charge_percent'] = df_mid[df_mid['standard_charge'].str.contains("% of Charges")]['standard_charge'].str.replace("% of Charges", "")
df_mid.loc[df_mid['standard_charge'].str.contains("% of covered Charges"), 'contracting_method'] = "percent of total billed charge"
df_mid.loc[df_mid['standard_charge'].str.contains("% of covered Charges"), 'standard_charge_percent'] = df_mid[df_mid['standard_charge'].str.contains("% of covered Charges")]['standard_charge'].str.replace("% of covered Charges", "")
df_mid.loc[df_mid['standard_charge'].str.contains("Charges"), 'standard_charge'] = None

df_mid
# Out:
#                            description local_code        line_type  drg
# 0                       SCREW 4.7X45MM   38000154     Chargemaster  NaN  \
# 1                SCREW LOCKING 1.5X9MM   38000204     Chargemaster  NaN
# 2          SHELL G7 3H NOCEMENT 60MM G   38000261     Chargemaster  NaN
# 3            OPTIFIX ABSORABLE FIX SYS   38000279     Chargemaster  NaN
# 4        PIPELINE FLEX EMBOL 2.75X10MM   38000394     Chargemaster  NaN
# ...                                ...        ...              ...  ...
# 2882500   Insj/rplc nstim apnea pls gn        NaN  Other CPT/HCPCS  NaN
# 2882501   Rmvl/rplc nstim apnea pls gn        NaN  Other CPT/HCPCS  NaN
# 2882502        Transplt allo hct/donor        NaN  Other CPT/HCPCS  NaN
# 2882503        Sipuleucel-t auto cd54+        NaN  Other CPT/HCPCS  NaN
# 2882504      Prosth retina receive&gen        NaN  Other CPT/HCPCS  NaN
#
#         hcpcs_cpt eapg   apc rev_code    payer_name standard_charge
# 0           C1713  NaN   NaN      278  Gross Charge            2852  \
# 1           C1713  NaN   NaN      278  Gross Charge             294
# 2           C1776  NaN   NaN      278  Gross Charge            3592
# 3             NaN  NaN   NaN      272  Gross Charge           19104
# 4           C1889  NaN   NaN      278  Gross Charge           53268
# ...           ...  ...   ...      ...           ...             ...
# 2882500     0427T  NaN  5465      NaN  Westlaco ISD            None
# 2882501     0431T  NaN  5465      NaN  Westlaco ISD            None
# 2882502     38240  NaN  5244      NaN  Westlaco ISD            None
# 2882503     Q2043  NaN  9273      NaN  Westlaco ISD            None
# 2882504     0100T  NaN  1908      NaN  Westlaco ISD            None
#
#                      contracting_method standard_charge_percent
# 0                                   NaN                     NaN
# 1                                   NaN                     NaN
# 2                                   NaN                     NaN
# 3                                   NaN                     NaN
# 4                                   NaN                     NaN
# ...                                 ...                     ...
# 2882500  percent of total billed charge                      40
# 2882501  percent of total billed charge                      40
# 2882502  percent of total billed charge                      40
# 2882503  percent of total billed charge                      40
# 2882504  percent of total billed charge                      40
#
# [1679399 rows x 12 columns]

# %%
df_mid['drg'] = df_mid['drg'].fillna('na')

def pad_drg_if_needed(drg):
    if drg == 'na':
        return drg
    
    if len(drg) == 1:
        return '00' + drg
    elif len(drg) == 2:
        return '0' + drg
    
    return drg

df_mid['drg'] = df_mid['drg'].apply(pad_drg_if_needed)
df_mid.loc[df_mid['drg'] == 'na', 'drg'] = None
df_mid
# Out:
#                            description local_code        line_type   drg
# 0                       SCREW 4.7X45MM   38000154     Chargemaster  None  \
# 1                SCREW LOCKING 1.5X9MM   38000204     Chargemaster  None
# 2          SHELL G7 3H NOCEMENT 60MM G   38000261     Chargemaster  None
# 3            OPTIFIX ABSORABLE FIX SYS   38000279     Chargemaster  None
# 4        PIPELINE FLEX EMBOL 2.75X10MM   38000394     Chargemaster  None
# ...                                ...        ...              ...   ...
# 2882500   Insj/rplc nstim apnea pls gn        NaN  Other CPT/HCPCS  None
# 2882501   Rmvl/rplc nstim apnea pls gn        NaN  Other CPT/HCPCS  None
# 2882502        Transplt allo hct/donor        NaN  Other CPT/HCPCS  None
# 2882503        Sipuleucel-t auto cd54+        NaN  Other CPT/HCPCS  None
# 2882504      Prosth retina receive&gen        NaN  Other CPT/HCPCS  None
#
#         hcpcs_cpt eapg   apc rev_code    payer_name standard_charge
# 0           C1713  NaN   NaN      278  Gross Charge            2852  \
# 1           C1713  NaN   NaN      278  Gross Charge             294
# 2           C1776  NaN   NaN      278  Gross Charge            3592
# 3             NaN  NaN   NaN      272  Gross Charge           19104
# 4           C1889  NaN   NaN      278  Gross Charge           53268
# ...           ...  ...   ...      ...           ...             ...
# 2882500     0427T  NaN  5465      NaN  Westlaco ISD            None
# 2882501     0431T  NaN  5465      NaN  Westlaco ISD            None
# 2882502     38240  NaN  5244      NaN  Westlaco ISD            None
# 2882503     Q2043  NaN  9273      NaN  Westlaco ISD            None
# 2882504     0100T  NaN  1908      NaN  Westlaco ISD            None
#
#                      contracting_method standard_charge_percent
# 0                                   NaN                     NaN
# 1                                   NaN                     NaN
# 2                                   NaN                     NaN
# 3                                   NaN                     NaN
# 4                                   NaN                     NaN
# ...                                 ...                     ...
# 2882500  percent of total billed charge                      40
# 2882501  percent of total billed charge                      40
# 2882502  percent of total billed charge                      40
# 2882503  percent of total billed charge                      40
# 2882504  percent of total billed charge                      40
#
# [1679399 rows x 12 columns]

# %%
if 'line_type' in df_mid.columns:
    df_mid.loc[df_mid['line_type'] == 'APR-DRG', 'apr_drg'] = df_mid[df_mid['line_type'] == 'APR-DRG']['drg']
    df_mid.loc[df_mid['line_type'] == 'APR-DRG', 'code'] = df_mid[df_mid['line_type'] == 'APR-DRG']['drg']
    df_mid.loc[df_mid['line_type'] == 'MS-DRG', 'ms_drg'] = df_mid[df_mid['line_type'] == 'MS-DRG']['drg']
    df_mid.loc[df_mid['line_type'] == 'MS-DRG', 'code'] = df_mid[df_mid['line_type'] == 'MS-DRG']['drg']
    del df_mid['drg']
    df_mid.loc[df_mid['line_type'] == 'Chargemaster', 'code'] = df_mid[df_mid['line_type'] == 'Chargemaster']['local_code']
    df_mid.loc[df_mid['line_type'] == 'EAPG', 'code'] = df_mid[df_mid['line_type'] == 'EAPG']['eapg']
    df_mid.loc[df_mid['line_type'] == 'Other CPT/HCPCS', 'code'] = df_mid[df_mid['line_type'] == 'Other CPT/HCPCS']['hcpcs_cpt']
else:
    df_mid = df_mid.rename(columns={'drg': 'ms_drg'})

df_mid['thru'] = None
df_mid['icd'] = None
df_mid['ndc'] = None
df_mid['drug_hcpcs_multiplier'] = None
df_mid['drug_quantity'] = None
df_mid['drug_unit_of_measurement'] = None
df_mid['drug_type_of_measurement'] = None
df_mid['additional_generic_notes'] = None
df_mid['additional_payer_specific_notes'] = None

# %%
if 'line_type' in df_mid.columns:
    set(df_mid['line_type'].tolist())
else:
    df_mid['line_type'] = None
    
if not 'code' in df_mid.columns:
    df_mid['code'] = None
    
if not 'apr_drg' in df_mid.columns:
    df_mid['apr_drg'] = None
    
if not 'eapg' in df_mid.columns:
    df_mid['eapg'] = None

# %%
def pad_apc_if_needed(apc):
    if type(apc) != str:
        return apc
    
    apc = apc.zfill(4)
    return apc

df_mid['apc'] = df_mid['apc'].apply(pad_apc_if_needed)

# %%
set(df_mid['apc'].to_list()) # TODO: make sure the APCs fit the format.
# Out:
# {'0726',
#  '0731',
#  '0736',
#  '0738',
#  '0752',
#  '0759',
#  '0800',
#  '0802',
#  '0810',
#  '0812',
#  '0820',
#  '0825',
#  '0836',
#  '0840',
#  '0843',
#  '0844',
#  '0850',
#  '0851',
#  '0858',
#  '0864',
#  '0874',
#  '0875',
#  '0887',
#  '0890',
#  '0901',
#  '0902',
#  '0903',
#  '0910',
#  '0925',
#  '0927',
#  '0928',
#  '0929',
#  '0931',
#  '0932',
#  '0943',
#  '0944',
#  '0946',
#  '0947',
#  '0948',
#  '0961',
#  '0963',
#  '0964',
#  '0965',
#  '1015',
#  '1064',
#  '1083',
#  '1139',
#  '1142',
#  '1168',
#  '1178',
#  '1203',
#  '1207',
#  '1213',
#  '1214',
#  '1232',
#  '1235',
#  '1237',
#  '1263',
#  '1268',
#  '1274',
#  '1281',
#  '1289',
#  '1296',
#  '1297',
#  '1311',
#  '1312',
#  '1327',
#  '1331',
#  '1340',
#  '1341',
#  '1352',
#  '1353',
#  '1408',
#  '1415',
#  '1416',
#  '1420',
#  '1426',
#  '1431',
#  '1433',
#  '1440',
#  '1446',
#  '1458',
#  '1466',
#  '1467',
#  '1468',
#  '1469',
#  '1471',
#  '1472',
#  '1474',
#  '1475',
#  '1478',
#  '1480',
#  '1482',
#  '1485',
#  '1486',
#  '1488',
#  '1489',
#  '1490',
#  '1506',
#  '1522',
#  '1523',
#  '1562',
#  '1608',
#  '1609',
#  '1613',
#  '1630',
#  '1656',
#  '1658',
#  '1660',
#  '1662',
#  '1669',
#  '1670',
#  '1683',
#  '1684',
#  '1685',
#  '1686',
#  '1687',
#  '1688',
#  '1689',
#  '1690',
#  '1694',
#  '1696',
#  '1700',
#  '1701',
#  '1704',
#  '1705',
#  '1709',
#  '1710',
#  '1711',
#  '1712',
#  '1739',
#  '1746',
#  '1748',
#  '1761',
#  '1809',
#  '1823',
#  '1824',
#  '1825',
#  '1826',
#  '1827',
#  '1829',
#  '1832',
#  '1844',
#  '1846',
#  '1847',
#  '1849',
#  '1850',
#  '1851',
#  '1853',
#  '1854',
#  '1856',
#  '1857',
#  '1859',
#  '1861',
#  '1908',
#  '2026',
#  '2031',
#  '2033',
#  '2034',
#  '2616',
#  '2639',
#  '2731',
#  '2770',
#  '5012',
#  '5021',
#  '5022',
#  '5023',
#  '5024',
#  '5025',
#  '5031',
#  '5032',
#  '5033',
#  '5034',
#  '5035',
#  '5041',
#  '5045',
#  '5051',
#  '5052',
#  '5053',
#  '5054',
#  '9253',
#  '9255',
#  '9256',
#  '9257',
#  '9258',
#  '9259',
#  '9261',
#  '9263',
#  '9264',
#  '9270',
#  '9272',
#  '9273',
#  '9274',
#  '9276',
#  '9278',
#  '9281',
#  '9284',
#  '9287',
#  '9289',
#  '9294',
#  '9295',
#  '9296',
#  '9297',
#  '9298',
#  '9299',
#  '9300',
#  '9301',
#  '9302',
#  '9306',
#  '9307',
#  '9313',
#  '9314',
#  '9319',
#  '9320',
#  '9336',
#  '9349',
#  '9393',
#  '9397',
#  '9398',
#  '9441',
#  '9445',
#  '9448',
#  '9450',
#  '9451',
#  '9452',
#  '9453',
#  '9455',
#  '9456',
#  '9460',
#  '9463',
#  '9466',
#  '9467',
#  '9469',
#  '9472',
#  '9473',
#  '9474',
#  '9475',
#  '9476',
#  '9477',
#  '9480',
#  '9481',
#  '9483',
#  '9485',
#  '9487',
#  '9488',
#  '9490',
#  '9491',
#  '9492',
#  '9493',
#  '9494',
#  '9500',
#  '9501',
#  '9504',
#  '9505',
#  '9507',
#  '9508',
#  '9510',
#  '9511',
#  '9512',
#  '9513',
#  '9514',
#  '9515',
#  '9517',
#  '9518',
#  '9519',
#  '9520',
#  '9521',
#  '9522',
#  '9524',
#  '9526',
#  '9528',
#  '9529',
#  '9530',
#  '9532',
#  '9533',
#  nan}

# %%
df_mid['modifiers'] = None

df_mid['hcpcs_cpt'] = df_mid['hcpcs_cpt'].fillna('')
df_mid.loc[df_mid['hcpcs_cpt'].str.len() == 7, 'modifiers'] = df_mid[df_mid['hcpcs_cpt'].str.len() == 7]['hcpcs_cpt'].str[-2:]
df_mid.loc[df_mid['hcpcs_cpt'].str.len() == 7, 'hcpcs_cpt'] = df_mid[df_mid['hcpcs_cpt'].str.len() == 7]['hcpcs_cpt'].str[:5]
df_mid.loc[df_mid['hcpcs_cpt'] == '', 'hcpcs_cpt'] = None
df_mid.loc[df_mid['hcpcs_cpt'] == 'XXXXX', 'hcpcs_cpt'] = None
df_mid.loc[df_mid['hcpcs_cpt'] == 'C1C13', 'hcpcs_cpt'] = None

df_mid['modifiers'].value_counts()
# Out:
# modifiers
# RT    5845
# LT    5813
# 50    3609
# 52    2640
# GP    1038
# GO     840
# LD     506
# LC     506
# 59     494
# RC     483
# 25     451
# GN     264
# 74     115
# 73     115
# CS      69
# F6      30
# FA      30
# F9      30
# F8      30
# F7      30
# F3      30
# F2      30
# F1      30
# F4      30
# F5      24
# T8      24
# CQ      24
# PS      24
# GG      24
# TA      24
# T9      24
# T7      24
# T6      24
# T5      24
# T4      24
# T3      24
# T1      24
# T2      24
# LM      23
# RI      23
# Name: count, dtype: int64

# %%
df_mid['payer_name'] = df_mid['payer_name'].apply(lambda payer_orig: payer_orig.strip())

def payer_category_from_payer_orig(payer_orig):
    if payer_orig == "Cash Price":
        return 'cash'
    elif payer_orig == "Gross Charge":
        return 'gross'
    elif payer_orig == "Minimum":
        return 'min'
    elif payer_orig == "Maximum":
        return 'max'
    
    return 'payer'

df_mid['payer_category'] = df_mid['payer_name'].apply(payer_category_from_payer_orig)
df_mid
# Out:
#                            description local_code        line_type hcpcs_cpt
# 0                       SCREW 4.7X45MM   38000154     Chargemaster     C1713  \
# 1                SCREW LOCKING 1.5X9MM   38000204     Chargemaster     C1713
# 2          SHELL G7 3H NOCEMENT 60MM G   38000261     Chargemaster     C1776
# 3            OPTIFIX ABSORABLE FIX SYS   38000279     Chargemaster      None
# 4        PIPELINE FLEX EMBOL 2.75X10MM   38000394     Chargemaster     C1889
# ...                                ...        ...              ...       ...
# 2882500   Insj/rplc nstim apnea pls gn        NaN  Other CPT/HCPCS     0427T
# 2882501   Rmvl/rplc nstim apnea pls gn        NaN  Other CPT/HCPCS     0431T
# 2882502        Transplt allo hct/donor        NaN  Other CPT/HCPCS     38240
# 2882503        Sipuleucel-t auto cd54+        NaN  Other CPT/HCPCS     Q2043
# 2882504      Prosth retina receive&gen        NaN  Other CPT/HCPCS     0100T
#
#         eapg   apc rev_code    payer_name standard_charge
# 0        NaN   NaN      278  Gross Charge            2852  \
# 1        NaN   NaN      278  Gross Charge             294
# 2        NaN   NaN      278  Gross Charge            3592
# 3        NaN   NaN      272  Gross Charge           19104
# 4        NaN   NaN      278  Gross Charge           53268
# ...      ...   ...      ...           ...             ...
# 2882500  NaN  5465      NaN  Westlaco ISD            None
# 2882501  NaN  5465      NaN  Westlaco ISD            None
# 2882502  NaN  5244      NaN  Westlaco ISD            None
# 2882503  NaN  9273      NaN  Westlaco ISD            None
# 2882504  NaN  1908      NaN  Westlaco ISD            None
#
#                      contracting_method  ...   icd   ndc
# 0                                   NaN  ...  None  None  \
# 1                                   NaN  ...  None  None
# 2                                   NaN  ...  None  None
# 3                                   NaN  ...  None  None
# 4                                   NaN  ...  None  None
# ...                                 ...  ...   ...   ...
# 2882500  percent of total billed charge  ...  None  None
# 2882501  percent of total billed charge  ...  None  None
# 2882502  percent of total billed charge  ...  None  None
# 2882503  percent of total billed charge  ...  None  None
# 2882504  percent of total billed charge  ...  None  None
#
#         drug_hcpcs_multiplier drug_quantity drug_unit_of_measurement
# 0                        None          None                     None  \
# 1                        None          None                     None
# 2                        None          None                     None
# 3                        None          None                     None
# 4                        None          None                     None
# ...                       ...           ...                      ...
# 2882500                  None          None                     None
# 2882501                  None          None                     None
# 2882502                  None          None                     None
# 2882503                  None          None                     None
# 2882504                  None          None                     None
#
#         drug_type_of_measurement additional_generic_notes
# 0                           None                     None  \
# 1                           None                     None
# 2                           None                     None
# 3                           None                     None
# 4                           None                     None
# ...                          ...                      ...
# 2882500                     None                     None
# 2882501                     None                     None
# 2882502                     None                     None
# 2882503                     None                     None
# 2882504                     None                     None
#
#         additional_payer_specific_notes modifiers payer_category
# 0                                  None      None          gross
# 1                                  None      None          gross
# 2                                  None      None          gross
# 3                                  None      None          gross
# 4                                  None      None          gross
# ...                                 ...       ...            ...
# 2882500                            None      None          payer
# 2882501                            None      None          payer
# 2882502                            None      None          payer
# 2882503                            None      None          payer
# 2882504                            None      None          payer
#
# [1679399 rows x 25 columns]

# %%
from helpers import pad_rev_code_if_needed
if 'rev_code' in df_mid.columns:
    df_mid['rev_code'] = df_mid['rev_code'].apply(pad_rev_code_if_needed)
else:
    df_mid['rev_code'] = None
df_mid['billing_class'] = None
df_mid['setting'] = None
df_mid['plan_name'] = None
df_mid
# Out:
#                            description local_code        line_type hcpcs_cpt
# 0                       SCREW 4.7X45MM   38000154     Chargemaster     C1713  \
# 1                SCREW LOCKING 1.5X9MM   38000204     Chargemaster     C1713
# 2          SHELL G7 3H NOCEMENT 60MM G   38000261     Chargemaster     C1776
# 3            OPTIFIX ABSORABLE FIX SYS   38000279     Chargemaster      None
# 4        PIPELINE FLEX EMBOL 2.75X10MM   38000394     Chargemaster     C1889
# ...                                ...        ...              ...       ...
# 2882500   Insj/rplc nstim apnea pls gn        NaN  Other CPT/HCPCS     0427T
# 2882501   Rmvl/rplc nstim apnea pls gn        NaN  Other CPT/HCPCS     0431T
# 2882502        Transplt allo hct/donor        NaN  Other CPT/HCPCS     38240
# 2882503        Sipuleucel-t auto cd54+        NaN  Other CPT/HCPCS     Q2043
# 2882504      Prosth retina receive&gen        NaN  Other CPT/HCPCS     0100T
#
#         eapg   apc rev_code    payer_name standard_charge
# 0        NaN   NaN     0278  Gross Charge            2852  \
# 1        NaN   NaN     0278  Gross Charge             294
# 2        NaN   NaN     0278  Gross Charge            3592
# 3        NaN   NaN     0272  Gross Charge           19104
# 4        NaN   NaN     0278  Gross Charge           53268
# ...      ...   ...      ...           ...             ...
# 2882500  NaN  5465      NaN  Westlaco ISD            None
# 2882501  NaN  5465      NaN  Westlaco ISD            None
# 2882502  NaN  5244      NaN  Westlaco ISD            None
# 2882503  NaN  9273      NaN  Westlaco ISD            None
# 2882504  NaN  1908      NaN  Westlaco ISD            None
#
#                      contracting_method  ... drug_quantity
# 0                                   NaN  ...          None  \
# 1                                   NaN  ...          None
# 2                                   NaN  ...          None
# 3                                   NaN  ...          None
# 4                                   NaN  ...          None
# ...                                 ...  ...           ...
# 2882500  percent of total billed charge  ...          None
# 2882501  percent of total billed charge  ...          None
# 2882502  percent of total billed charge  ...          None
# 2882503  percent of total billed charge  ...          None
# 2882504  percent of total billed charge  ...          None
#
#         drug_unit_of_measurement drug_type_of_measurement
# 0                           None                     None  \
# 1                           None                     None
# 2                           None                     None
# 3                           None                     None
# 4                           None                     None
# ...                          ...                      ...
# 2882500                     None                     None
# 2882501                     None                     None
# 2882502                     None                     None
# 2882503                     None                     None
# 2882504                     None                     None
#
#         additional_generic_notes additional_payer_specific_notes modifiers
# 0                           None                            None      None  \
# 1                           None                            None      None
# 2                           None                            None      None
# 3                           None                            None      None
# 4                           None                            None      None
# ...                          ...                             ...       ...
# 2882500                     None                            None      None
# 2882501                     None                            None      None
# 2882502                     None                            None      None
# 2882503                     None                            None      None
# 2882504                     None                            None      None
#
#         payer_category billing_class setting plan_name
# 0                gross          None    None      None
# 1                gross          None    None      None
# 2                gross          None    None      None
# 3                gross          None    None      None
# 4                gross          None    None      None
# ...                ...           ...     ...       ...
# 2882500          payer          None    None      None
# 2882501          payer          None    None      None
# 2882502          payer          None    None      None
# 2882503          payer          None    None      None
# 2882504          payer          None    None      None
#
# [1679399 rows x 28 columns]

# %%
df_mid['hospital_id'] = ccn

# %%
df_out = pd.DataFrame(df_mid[TARGET_COLUMNS])
df_out
# Out:
#         hospital_id        line_type                    description rev_code
# 0            450811     Chargemaster                 SCREW 4.7X45MM     0278  \
# 1            450811     Chargemaster          SCREW LOCKING 1.5X9MM     0278
# 2            450811     Chargemaster    SHELL G7 3H NOCEMENT 60MM G     0278
# 3            450811     Chargemaster      OPTIFIX ABSORABLE FIX SYS     0272
# 4            450811     Chargemaster  PIPELINE FLEX EMBOL 2.75X10MM     0278
# ...             ...              ...                            ...      ...
# 2882500      450811  Other CPT/HCPCS   Insj/rplc nstim apnea pls gn      NaN
# 2882501      450811  Other CPT/HCPCS   Rmvl/rplc nstim apnea pls gn      NaN
# 2882502      450811  Other CPT/HCPCS        Transplt allo hct/donor      NaN
# 2882503      450811  Other CPT/HCPCS        Sipuleucel-t auto cd54+      NaN
# 2882504      450811  Other CPT/HCPCS      Prosth retina receive&gen      NaN
#
#         local_code      code ms_drg apr_drg eapg hcpcs_cpt  ... billing_class
# 0         38000154  38000154    NaN     NaN  NaN     C1713  ...          None  \
# 1         38000204  38000204    NaN     NaN  NaN     C1713  ...          None
# 2         38000261  38000261    NaN     NaN  NaN     C1776  ...          None
# 3         38000279  38000279    NaN     NaN  NaN      None  ...          None
# 4         38000394  38000394    NaN     NaN  NaN     C1889  ...          None
# ...            ...       ...    ...     ...  ...       ...  ...           ...
# 2882500        NaN     0427T    NaN     NaN  NaN     0427T  ...          None
# 2882501        NaN     0431T    NaN     NaN  NaN     0431T  ...          None
# 2882502        NaN     38240    NaN     NaN  NaN     38240  ...          None
# 2882503        NaN     Q2043    NaN     NaN  NaN     Q2043  ...          None
# 2882504        NaN     0100T    NaN     NaN  NaN     0100T  ...          None
#
#         setting payer_category    payer_name plan_name standard_charge
# 0          None          gross  Gross Charge      None            2852  \
# 1          None          gross  Gross Charge      None             294
# 2          None          gross  Gross Charge      None            3592
# 3          None          gross  Gross Charge      None           19104
# 4          None          gross  Gross Charge      None           53268
# ...         ...            ...           ...       ...             ...
# 2882500    None          payer  Westlaco ISD      None            None
# 2882501    None          payer  Westlaco ISD      None            None
# 2882502    None          payer  Westlaco ISD      None            None
# 2882503    None          payer  Westlaco ISD      None            None
# 2882504    None          payer  Westlaco ISD      None            None
#
#         standard_charge_percent              contracting_method
# 0                           NaN                             NaN  \
# 1                           NaN                             NaN
# 2                           NaN                             NaN
# 3                           NaN                             NaN
# 4                           NaN                             NaN
# ...                         ...                             ...
# 2882500                      40  percent of total billed charge
# 2882501                      40  percent of total billed charge
# 2882502                      40  percent of total billed charge
# 2882503                      40  percent of total billed charge
# 2882504                      40  percent of total billed charge
#
#         additional_generic_notes additional_payer_specific_notes
# 0                           None                            None
# 1                           None                            None
# 2                           None                            None
# 3                           None                            None
# 4                           None                            None
# ...                          ...                             ...
# 2882500                     None                            None
# 2882501                     None                            None
# 2882502                     None                            None
# 2882503                     None                            None
# 2882504                     None                            None
#
# [1679399 rows x 29 columns]

# %%
df_out.to_csv("eskycity_" + ccn + ".csv", index=False)
