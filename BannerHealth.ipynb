# %%
import base64
from io import BytesIO
from dateutil.parser import parse as parse_datetime

import pandas as pd
import requests
from lxml import html

from helpers import *

# %%
TARGET_COLUMNS = [
    'hospital_id',
    #'row_id',
    'line_type',
    'description',
    'rev_code',
    'local_code',
    'code',
    'ms_drg',
    'apr_drg',
    'eapg',
    'hcpcs_cpt',
    'modifiers',
    'alt_hcpcs_cpt',
    'thru',
    'apc',
    'icd',
    'ndc',
    'drug_hcpcs_multiplier',
    'drug_quantity',
    'drug_unit_of_measurement',
    'drug_type_of_measurement',
    'billing_class',
    'setting',
    'payer_category',
    'payer_name',
    'plan_name',
    'standard_charge',
    'standard_charge_percent',
    'contracting_method',
    'additional_generic_notes',
    'additional_payer_specific_notes'
]

# %%
transparency_page = "https://www.bannerhealth.com/patients/billing/pricing-resources/hospital-price-transparency"
mrf_url = "https://www.cdmpricing.com/37cdb181c73f9a24e83a4b98eaac3589/standard-charges"
ccn = "060126"

# %%
hospital_id = mrf_url.split("/")[-2]
api_url = "https://apim.services.craneware.com/api-pricing-transparency/api/public/{}/metadata/cdmFile".format(hospital_id)
api_url
# Out:
# 'https://apim.services.craneware.com/api-pricing-transparency/api/public/37cdb181c73f9a24e83a4b98eaac3589/metadata/cdmFile'

# %%
resp = requests.get(api_url)

# %%
base64_str = resp.json().get("contentBytes")
content_type = resp.json().get("contentType")
filename = resp.json().get("fileDownloadName")
content_type, filename
# Out:
# ('text/csv', '450233470BANNER-FORT-COLLINS-MEDICAL-CENTERstandardcharges.xlsx')

# %%
ein = derive_ein_from_filename(filename)
ein
# Out:
# '45-0233470BANNER-FORT-COLLINS-MEDICAL-CENTERstandardcharges.xlsx'

# %%
content = base64.b64decode(base64_str)
out_f = open(filename, 'wb')
out_f.write(content)
out_f.close()

# %%
b_f = BytesIO(content)
df_in = pd.read_excel(b_f)

if df_in.columns[0] != 'Code':
    first_line = df_in.columns[0]
    date_str = first_line.replace('Updated on ', '').replace('Updated on: ', '')
    last_updated = parse_datetime(date_str).isoformat().split('T')[0]
    df_in = pd.read_excel(b_f, header=1)
else:
    last_updated = '2021-01-01'

# %%
df_in
# Out:
#                               Code  \
# 0                            10005
# 1                            10006
# 2                            10060
# 3                            10120
# 4                            10140
# ...                            ...
# 13107      WIRE PACING TEMP LVL 02
# 13108      WIRE PACING TEMP LVL 03
# 13109      WIRE PACING TEMP LVL 04
# 13110      WIRE PACING TEMP LVL 05
# 13111  ZINC OXIDE 16% 60GM PST TOP
#
#                                              Description        Type  \
# 0      Fine needle aspiration of first lesion using u...  Outpatient
# 1      Fine needle aspiration of additional lesion us...  Outpatient
# 2                                    Drainage of abscess  Outpatient
# 3      Removal of foreign body from tissue, accessed ...  Outpatient
# 4                Drainage of blood or fluid accumulation  Outpatient
# ...                                                  ...         ...
# 13107                                                NaN         521
# 13108                                                NaN         741
# 13109                                                NaN         987
# 13110                                                NaN        1232
# 13111                                                NaN         6.6
#
#        Gross Charge  De-identified min contracted rate  \
# 0           1764.18                             592.46
# 1           1213.00                             691.41
# 2            431.15                             179.96
# 3            314.25                             346.63
# 4           3131.10                                NaN
# ...             ...                                ...
# 13107           NaN                                NaN
# 13108           NaN                                NaN
# 13109           NaN                                NaN
# 13110           NaN                                NaN
# 13111           NaN                                NaN
#
#        De-identified max contracted rate  Discounted Cash Price  \
# 0                                2021.85                1764.18
# 1                                4174.65                1213.00
# 2                                1670.61                 431.15
# 3                                3389.03                 314.25
# 4                                3131.10                3131.10
# ...                                  ...                    ...
# 13107                                NaN                    NaN
# 13108                                NaN                    NaN
# 13109                                NaN                    NaN
# 13110                                NaN                    NaN
# 13111                                NaN                    NaN
#
#        United HealthCare-Commercial HMO  Aetna-Commercial HMO  \
# 0                               1784.00               2021.85
# 1                                   NaN               4174.65
# 2                               1670.61                357.38
# 3                                   NaN                   NaN
# 4                                   NaN                   NaN
# ...                                 ...                   ...
# 13107                               NaN                   NaN
# 13108                               NaN                   NaN
# 13109                               NaN                   NaN
# 13110                               NaN                   NaN
# 13111                               NaN                   NaN
#
#        Aetna-Medicare Advantage HMO  Cigna-Commercial HMO  \
# 0                               NaN                   NaN
# 1                               NaN                   NaN
# 2                               NaN                   NaN
# 3                               NaN                   NaN
# 4                               NaN                   NaN
# ...                             ...                   ...
# 13107                           NaN                   NaN
# 13108                           NaN                   NaN
# 13109                           NaN                   NaN
# 13110                           NaN                   NaN
# 13111                           NaN                   NaN
#
#        BCBS-Commercial HMO  United HealthCare-Medicare Advantage HMO  \
# 0                      NaN                                    592.46
# 1                      NaN                                       NaN
# 2                      NaN                                       NaN
# 3                      NaN                                       NaN
# 4                      NaN                                       NaN
# ...                    ...                                       ...
# 13107                  NaN                                       NaN
# 13108                  NaN                                       NaN
# 13109                  NaN                                       NaN
# 13110                  NaN                                       NaN
# 13111                  NaN                                       NaN
#
#        Cigna-Commercial PPO/Open Access  Humana-Commercial HMO  \
# 0                               1939.23                    NaN
# 1                                   NaN                    NaN
# 2                                   NaN                    NaN
# 3                                   NaN                3389.03
# 4                                   NaN                    NaN
# ...                                 ...                    ...
# 13107                               NaN                    NaN
# 13108                               NaN                    NaN
# 13109                               NaN                    NaN
# 13110                               NaN                    NaN
# 13111                               NaN                    NaN
#
#        Humana-Medicare Advantage HMO  Kaiser Permanaente-Commercial HMO  \
# 0                             621.29                             867.75
# 1                                NaN                             691.41
# 2                                NaN                             179.96
# 3                             346.63                                NaN
# 4                                NaN                                NaN
# ...                              ...                                ...
# 13107                            NaN                                NaN
# 13108                            NaN                                NaN
# 13109                            NaN                                NaN
# 13110                            NaN                                NaN
# 13111                            NaN                                NaN
#
#        Rocky Mountain HMO-Commercial HMO
# 0                                    NaN
# 1                                    NaN
# 2                                 201.34
# 3                                    NaN
# 4                                    NaN
# ...                                  ...
# 13107                                NaN
# 13108                                NaN
# 13109                                NaN
# 13110                                NaN
# 13111                                NaN
#
# [13112 rows x 18 columns]

# %%
df_mid = pd.DataFrame(df_in)
df_mid = df_mid.rename(columns={
    'Code': 'code',
    'Description': 'description',
    'Type': 'line_type',
})
df_mid
# Out:
#                               code  \
# 0                            10005
# 1                            10006
# 2                            10060
# 3                            10120
# 4                            10140
# ...                            ...
# 13107      WIRE PACING TEMP LVL 02
# 13108      WIRE PACING TEMP LVL 03
# 13109      WIRE PACING TEMP LVL 04
# 13110      WIRE PACING TEMP LVL 05
# 13111  ZINC OXIDE 16% 60GM PST TOP
#
#                                              description   line_type  \
# 0      Fine needle aspiration of first lesion using u...  Outpatient
# 1      Fine needle aspiration of additional lesion us...  Outpatient
# 2                                    Drainage of abscess  Outpatient
# 3      Removal of foreign body from tissue, accessed ...  Outpatient
# 4                Drainage of blood or fluid accumulation  Outpatient
# ...                                                  ...         ...
# 13107                                                NaN         521
# 13108                                                NaN         741
# 13109                                                NaN         987
# 13110                                                NaN        1232
# 13111                                                NaN         6.6
#
#        Gross Charge  De-identified min contracted rate  \
# 0           1764.18                             592.46
# 1           1213.00                             691.41
# 2            431.15                             179.96
# 3            314.25                             346.63
# 4           3131.10                                NaN
# ...             ...                                ...
# 13107           NaN                                NaN
# 13108           NaN                                NaN
# 13109           NaN                                NaN
# 13110           NaN                                NaN
# 13111           NaN                                NaN
#
#        De-identified max contracted rate  Discounted Cash Price  \
# 0                                2021.85                1764.18
# 1                                4174.65                1213.00
# 2                                1670.61                 431.15
# 3                                3389.03                 314.25
# 4                                3131.10                3131.10
# ...                                  ...                    ...
# 13107                                NaN                    NaN
# 13108                                NaN                    NaN
# 13109                                NaN                    NaN
# 13110                                NaN                    NaN
# 13111                                NaN                    NaN
#
#        United HealthCare-Commercial HMO  Aetna-Commercial HMO  \
# 0                               1784.00               2021.85
# 1                                   NaN               4174.65
# 2                               1670.61                357.38
# 3                                   NaN                   NaN
# 4                                   NaN                   NaN
# ...                                 ...                   ...
# 13107                               NaN                   NaN
# 13108                               NaN                   NaN
# 13109                               NaN                   NaN
# 13110                               NaN                   NaN
# 13111                               NaN                   NaN
#
#        Aetna-Medicare Advantage HMO  Cigna-Commercial HMO  \
# 0                               NaN                   NaN
# 1                               NaN                   NaN
# 2                               NaN                   NaN
# 3                               NaN                   NaN
# 4                               NaN                   NaN
# ...                             ...                   ...
# 13107                           NaN                   NaN
# 13108                           NaN                   NaN
# 13109                           NaN                   NaN
# 13110                           NaN                   NaN
# 13111                           NaN                   NaN
#
#        BCBS-Commercial HMO  United HealthCare-Medicare Advantage HMO  \
# 0                      NaN                                    592.46
# 1                      NaN                                       NaN
# 2                      NaN                                       NaN
# 3                      NaN                                       NaN
# 4                      NaN                                       NaN
# ...                    ...                                       ...
# 13107                  NaN                                       NaN
# 13108                  NaN                                       NaN
# 13109                  NaN                                       NaN
# 13110                  NaN                                       NaN
# 13111                  NaN                                       NaN
#
#        Cigna-Commercial PPO/Open Access  Humana-Commercial HMO  \
# 0                               1939.23                    NaN
# 1                                   NaN                    NaN
# 2                                   NaN                    NaN
# 3                                   NaN                3389.03
# 4                                   NaN                    NaN
# ...                                 ...                    ...
# 13107                               NaN                    NaN
# 13108                               NaN                    NaN
# 13109                               NaN                    NaN
# 13110                               NaN                    NaN
# 13111                               NaN                    NaN
#
#        Humana-Medicare Advantage HMO  Kaiser Permanaente-Commercial HMO  \
# 0                             621.29                             867.75
# 1                                NaN                             691.41
# 2                                NaN                             179.96
# 3                             346.63                                NaN
# 4                                NaN                                NaN
# ...                              ...                                ...
# 13107                            NaN                                NaN
# 13108                            NaN                                NaN
# 13109                            NaN                                NaN
# 13110                            NaN                                NaN
# 13111                            NaN                                NaN
#
#        Rocky Mountain HMO-Commercial HMO
# 0                                    NaN
# 1                                    NaN
# 2                                 201.34
# 3                                    NaN
# 4                                    NaN
# ...                                  ...
# 13107                                NaN
# 13108                                NaN
# 13109                                NaN
# 13110                                NaN
# 13111                                NaN
#
# [13112 rows x 18 columns]

# %%
money_columns = df_mid.columns[3:]
remaining_columns = df_mid.columns[:3]
df_mid = pd.melt(df_mid, id_vars=remaining_columns, var_name='payer_name', value_name='standard_charge')
df_mid
# Out:
#                                code  \
# 0                             10005
# 1                             10006
# 2                             10060
# 3                             10120
# 4                             10140
# ...                             ...
# 196675      WIRE PACING TEMP LVL 02
# 196676      WIRE PACING TEMP LVL 03
# 196677      WIRE PACING TEMP LVL 04
# 196678      WIRE PACING TEMP LVL 05
# 196679  ZINC OXIDE 16% 60GM PST TOP
#
#                                               description   line_type  \
# 0       Fine needle aspiration of first lesion using u...  Outpatient
# 1       Fine needle aspiration of additional lesion us...  Outpatient
# 2                                     Drainage of abscess  Outpatient
# 3       Removal of foreign body from tissue, accessed ...  Outpatient
# 4                 Drainage of blood or fluid accumulation  Outpatient
# ...                                                   ...         ...
# 196675                                                NaN         521
# 196676                                                NaN         741
# 196677                                                NaN         987
# 196678                                                NaN        1232
# 196679                                                NaN         6.6
#
#                                payer_name  standard_charge
# 0                            Gross Charge          1764.18
# 1                            Gross Charge          1213.00
# 2                            Gross Charge           431.15
# 3                            Gross Charge           314.25
# 4                            Gross Charge          3131.10
# ...                                   ...              ...
# 196675  Rocky Mountain HMO-Commercial HMO              NaN
# 196676  Rocky Mountain HMO-Commercial HMO              NaN
# 196677  Rocky Mountain HMO-Commercial HMO              NaN
# 196678  Rocky Mountain HMO-Commercial HMO              NaN
# 196679  Rocky Mountain HMO-Commercial HMO              NaN
#
# [196680 rows x 5 columns]

# %%
df_mid.loc[df_mid['line_type'] == 'Outpatient', 'setting'] = 'outpatient'
df_mid.loc[df_mid['line_type'] == 'Inpatient', 'setting'] = 'outpatient'
df_mid.loc[df_mid['line_type'] == 'Inpatient', 'line_type'] = None
df_mid.loc[df_mid['line_type'] == 'Outpatient', 'line_type'] = None

df_mid
# Out:
#                                code  \
# 0                             10005
# 1                             10006
# 2                             10060
# 3                             10120
# 4                             10140
# ...                             ...
# 196675      WIRE PACING TEMP LVL 02
# 196676      WIRE PACING TEMP LVL 03
# 196677      WIRE PACING TEMP LVL 04
# 196678      WIRE PACING TEMP LVL 05
# 196679  ZINC OXIDE 16% 60GM PST TOP
#
#                                               description line_type  \
# 0       Fine needle aspiration of first lesion using u...      None
# 1       Fine needle aspiration of additional lesion us...      None
# 2                                     Drainage of abscess      None
# 3       Removal of foreign body from tissue, accessed ...      None
# 4                 Drainage of blood or fluid accumulation      None
# ...                                                   ...       ...
# 196675                                                NaN       521
# 196676                                                NaN       741
# 196677                                                NaN       987
# 196678                                                NaN      1232
# 196679                                                NaN       6.6
#
#                                payer_name  standard_charge     setting
# 0                            Gross Charge          1764.18  outpatient
# 1                            Gross Charge          1213.00  outpatient
# 2                            Gross Charge           431.15  outpatient
# 3                            Gross Charge           314.25  outpatient
# 4                            Gross Charge          3131.10  outpatient
# ...                                   ...              ...         ...
# 196675  Rocky Mountain HMO-Commercial HMO              NaN         NaN
# 196676  Rocky Mountain HMO-Commercial HMO              NaN         NaN
# 196677  Rocky Mountain HMO-Commercial HMO              NaN         NaN
# 196678  Rocky Mountain HMO-Commercial HMO              NaN         NaN
# 196679  Rocky Mountain HMO-Commercial HMO              NaN         NaN
#
# [196680 rows x 6 columns]

# %%
df_mid['hcpcs_cpt'] = None
df_mid['ms_drg'] = None

def recognise_codes(row):
    line_type = row['line_type']
    code = row['code']
    
    if line_type == 'Charge Code':
        row['local_code'] = code
    elif line_type == 'HCPCS/CPT' or code_is_cpt(code) or code_is_hcpcs(code):
        row['hcpcs_cpt'] = code

    return row

df_mid = df_mid.apply(recognise_codes, axis=1)
df_mid
# Out:
#                                code  \
# 0                             10005
# 1                             10006
# 2                             10060
# 3                             10120
# 4                             10140
# ...                             ...
# 196675      WIRE PACING TEMP LVL 02
# 196676      WIRE PACING TEMP LVL 03
# 196677      WIRE PACING TEMP LVL 04
# 196678      WIRE PACING TEMP LVL 05
# 196679  ZINC OXIDE 16% 60GM PST TOP
#
#                                               description line_type  \
# 0       Fine needle aspiration of first lesion using u...      None
# 1       Fine needle aspiration of additional lesion us...      None
# 2                                     Drainage of abscess      None
# 3       Removal of foreign body from tissue, accessed ...      None
# 4                 Drainage of blood or fluid accumulation      None
# ...                                                   ...       ...
# 196675                                                NaN       521
# 196676                                                NaN       741
# 196677                                                NaN       987
# 196678                                                NaN      1232
# 196679                                                NaN       6.6
#
#                                payer_name  standard_charge     setting  \
# 0                            Gross Charge          1764.18  outpatient
# 1                            Gross Charge          1213.00  outpatient
# 2                            Gross Charge           431.15  outpatient
# 3                            Gross Charge           314.25  outpatient
# 4                            Gross Charge          3131.10  outpatient
# ...                                   ...              ...         ...
# 196675  Rocky Mountain HMO-Commercial HMO              NaN         NaN
# 196676  Rocky Mountain HMO-Commercial HMO              NaN         NaN
# 196677  Rocky Mountain HMO-Commercial HMO              NaN         NaN
# 196678  Rocky Mountain HMO-Commercial HMO              NaN         NaN
# 196679  Rocky Mountain HMO-Commercial HMO              NaN         NaN
#
#        hcpcs_cpt ms_drg
# 0           None   None
# 1           None   None
# 2           None   None
# 3           None   None
# 4           None   None
# ...          ...    ...
# 196675      None   None
# 196676      None   None
# 196677      None   None
# 196678      None   None
# 196679      None   None
#
# [196680 rows x 8 columns]

# %%
df_mid['standard_charge'] = df_mid['standard_charge'].apply(lambda rate: str(rate).replace(',', '.').strip())
df_mid = df_mid[df_mid['standard_charge'] != "N/A"]
df_mid = df_mid[df_mid['standard_charge'] != "nan"]
df_mid = df_mid[df_mid['standard_charge'].notnull()]
df_mid
# Out:
#          code                                        description line_type  \
# 0       10005  Fine needle aspiration of first lesion using u...      None
# 1       10006  Fine needle aspiration of additional lesion us...      None
# 2       10060                                Drainage of abscess      None
# 3       10120  Removal of foreign body from tissue, accessed ...      None
# 4       10140            Drainage of blood or fluid accumulation      None
# ...       ...                                                ...       ...
# 184407  99283  Emergency department visit, moderately severe ...      None
# 184408  99284  Emergency department visit, problem of high se...      None
# 184409  99285  Emergency department visit, problem with signi...      None
# 184498  G0480  Drug test(s), definitive, utilizing (1) drug i...      None
# 184546  J1885       Injection, ketorolac tromethamine, per 15 mg      None
#
#                                payer_name standard_charge     setting  \
# 0                            Gross Charge         1764.18  outpatient
# 1                            Gross Charge          1213.0  outpatient
# 2                            Gross Charge          431.15  outpatient
# 3                            Gross Charge          314.25  outpatient
# 4                            Gross Charge          3131.1  outpatient
# ...                                   ...             ...         ...
# 184407  Rocky Mountain HMO-Commercial HMO          293.33  outpatient
# 184408  Rocky Mountain HMO-Commercial HMO          162.22  outpatient
# 184409  Rocky Mountain HMO-Commercial HMO          222.28  outpatient
# 184498  Rocky Mountain HMO-Commercial HMO          122.95  outpatient
# 184546  Rocky Mountain HMO-Commercial HMO           43.35  outpatient
#
#        hcpcs_cpt ms_drg
# 0           None   None
# 1           None   None
# 2           None   None
# 3           None   None
# 4           None   None
# ...          ...    ...
# 184407      None   None
# 184408      None   None
# 184409      None   None
# 184498     G0480   None
# 184546     J1885   None
#
# [9710 rows x 8 columns]

# %%
def payer_category_from_payer_name(payer_name):
    payer_name = payer_name.strip()
    if payer_name == "Gross Charge":
        return 'gross'
    elif payer_name == "Discounted Cash Price":
        return 'cash'
    elif payer_name == "De-identified min contracted rate":
        return 'min'
    elif payer_name == "De-identified max contracted rate":
        return 'max'

    return 'payer'

df_mid['payer_category'] = df_mid['payer_name'].apply(payer_category_from_payer_name)
df_mid
# Out:
#          code                                        description line_type  \
# 0       10005  Fine needle aspiration of first lesion using u...      None
# 1       10006  Fine needle aspiration of additional lesion us...      None
# 2       10060                                Drainage of abscess      None
# 3       10120  Removal of foreign body from tissue, accessed ...      None
# 4       10140            Drainage of blood or fluid accumulation      None
# ...       ...                                                ...       ...
# 184407  99283  Emergency department visit, moderately severe ...      None
# 184408  99284  Emergency department visit, problem of high se...      None
# 184409  99285  Emergency department visit, problem with signi...      None
# 184498  G0480  Drug test(s), definitive, utilizing (1) drug i...      None
# 184546  J1885       Injection, ketorolac tromethamine, per 15 mg      None
#
#                                payer_name standard_charge     setting  \
# 0                            Gross Charge         1764.18  outpatient
# 1                            Gross Charge          1213.0  outpatient
# 2                            Gross Charge          431.15  outpatient
# 3                            Gross Charge          314.25  outpatient
# 4                            Gross Charge          3131.1  outpatient
# ...                                   ...             ...         ...
# 184407  Rocky Mountain HMO-Commercial HMO          293.33  outpatient
# 184408  Rocky Mountain HMO-Commercial HMO          162.22  outpatient
# 184409  Rocky Mountain HMO-Commercial HMO          222.28  outpatient
# 184498  Rocky Mountain HMO-Commercial HMO          122.95  outpatient
# 184546  Rocky Mountain HMO-Commercial HMO           43.35  outpatient
#
#        hcpcs_cpt ms_drg payer_category
# 0           None   None          gross
# 1           None   None          gross
# 2           None   None          gross
# 3           None   None          gross
# 4           None   None          gross
# ...          ...    ...            ...
# 184407      None   None          payer
# 184408      None   None          payer
# 184409      None   None          payer
# 184498     G0480   None          payer
# 184546     J1885   None          payer
#
# [9710 rows x 9 columns]

# %%
if not 'local_code' in df_mid.columns:
    df_mid['local_code'] = None

df_mid['hospital_id'] = ccn
df_mid['rev_code'] = None
df_mid['apr_drg'] = None
df_mid['eapg'] = None
df_mid['modifiers'] = None
df_mid['alt_hcpcs_cpt'] = None
df_mid['thru'] = None
df_mid['apc'] = None
df_mid['icd'] = None
df_mid['ndc'] = None
df_mid['drug_hcpcs_multiplier'] = None
df_mid['drug_quantity'] = None
df_mid['drug_unit_of_measurement'] = None
df_mid['drug_type_of_measurement'] = None
df_mid['billing_class'] = None
df_mid['plan_name'] = None
df_mid['standard_charge_percent'] = None
df_mid['contracting_method'] = None
df_mid['additional_generic_notes'] = None
df_mid['additional_payer_specific_notes'] = None

df_mid
# Out:
#          code                                        description line_type  \
# 0       10005  Fine needle aspiration of first lesion using u...      None
# 1       10006  Fine needle aspiration of additional lesion us...      None
# 2       10060                                Drainage of abscess      None
# 3       10120  Removal of foreign body from tissue, accessed ...      None
# 4       10140            Drainage of blood or fluid accumulation      None
# ...       ...                                                ...       ...
# 184407  99283  Emergency department visit, moderately severe ...      None
# 184408  99284  Emergency department visit, problem of high se...      None
# 184409  99285  Emergency department visit, problem with signi...      None
# 184498  G0480  Drug test(s), definitive, utilizing (1) drug i...      None
# 184546  J1885       Injection, ketorolac tromethamine, per 15 mg      None
#
#                                payer_name standard_charge     setting  \
# 0                            Gross Charge         1764.18  outpatient
# 1                            Gross Charge          1213.0  outpatient
# 2                            Gross Charge          431.15  outpatient
# 3                            Gross Charge          314.25  outpatient
# 4                            Gross Charge          3131.1  outpatient
# ...                                   ...             ...         ...
# 184407  Rocky Mountain HMO-Commercial HMO          293.33  outpatient
# 184408  Rocky Mountain HMO-Commercial HMO          162.22  outpatient
# 184409  Rocky Mountain HMO-Commercial HMO          222.28  outpatient
# 184498  Rocky Mountain HMO-Commercial HMO          122.95  outpatient
# 184546  Rocky Mountain HMO-Commercial HMO           43.35  outpatient
#
#        hcpcs_cpt ms_drg payer_category local_code  ... drug_hcpcs_multiplier  \
# 0           None   None          gross       None  ...                  None
# 1           None   None          gross       None  ...                  None
# 2           None   None          gross       None  ...                  None
# 3           None   None          gross       None  ...                  None
# 4           None   None          gross       None  ...                  None
# ...          ...    ...            ...        ...  ...                   ...
# 184407      None   None          payer       None  ...                  None
# 184408      None   None          payer       None  ...                  None
# 184409      None   None          payer       None  ...                  None
# 184498     G0480   None          payer       None  ...                  None
# 184546     J1885   None          payer       None  ...                  None
#
#        drug_quantity drug_unit_of_measurement drug_type_of_measurement  \
# 0               None                     None                     None
# 1               None                     None                     None
# 2               None                     None                     None
# 3               None                     None                     None
# 4               None                     None                     None
# ...              ...                      ...                      ...
# 184407          None                     None                     None
# 184408          None                     None                     None
# 184409          None                     None                     None
# 184498          None                     None                     None
# 184546          None                     None                     None
#
#        billing_class plan_name standard_charge_percent contracting_method  \
# 0               None      None                    None               None
# 1               None      None                    None               None
# 2               None      None                    None               None
# 3               None      None                    None               None
# 4               None      None                    None               None
# ...              ...       ...                     ...                ...
# 184407          None      None                    None               None
# 184408          None      None                    None               None
# 184409          None      None                    None               None
# 184498          None      None                    None               None
# 184546          None      None                    None               None
#
#        additional_generic_notes additional_payer_specific_notes
# 0                          None                            None
# 1                          None                            None
# 2                          None                            None
# 3                          None                            None
# 4                          None                            None
# ...                         ...                             ...
# 184407                     None                            None
# 184408                     None                            None
# 184409                     None                            None
# 184498                     None                            None
# 184546                     None                            None
#
# [9710 rows x 30 columns]

# %%
df_out = pd.DataFrame(df_mid[TARGET_COLUMNS])
df_out
# Out:
#        hospital_id line_type  \
# 0           060126      None
# 1           060126      None
# 2           060126      None
# 3           060126      None
# 4           060126      None
# ...            ...       ...
# 184407      060126      None
# 184408      060126      None
# 184409      060126      None
# 184498      060126      None
# 184546      060126      None
#
#                                               description rev_code local_code  \
# 0       Fine needle aspiration of first lesion using u...     None       None
# 1       Fine needle aspiration of additional lesion us...     None       None
# 2                                     Drainage of abscess     None       None
# 3       Removal of foreign body from tissue, accessed ...     None       None
# 4                 Drainage of blood or fluid accumulation     None       None
# ...                                                   ...      ...        ...
# 184407  Emergency department visit, moderately severe ...     None       None
# 184408  Emergency department visit, problem of high se...     None       None
# 184409  Emergency department visit, problem with signi...     None       None
# 184498  Drug test(s), definitive, utilizing (1) drug i...     None       None
# 184546       Injection, ketorolac tromethamine, per 15 mg     None       None
#
#          code ms_drg apr_drg  eapg hcpcs_cpt  ... billing_class     setting  \
# 0       10005   None    None  None      None  ...          None  outpatient
# 1       10006   None    None  None      None  ...          None  outpatient
# 2       10060   None    None  None      None  ...          None  outpatient
# 3       10120   None    None  None      None  ...          None  outpatient
# 4       10140   None    None  None      None  ...          None  outpatient
# ...       ...    ...     ...   ...       ...  ...           ...         ...
# 184407  99283   None    None  None      None  ...          None  outpatient
# 184408  99284   None    None  None      None  ...          None  outpatient
# 184409  99285   None    None  None      None  ...          None  outpatient
# 184498  G0480   None    None  None     G0480  ...          None  outpatient
# 184546  J1885   None    None  None     J1885  ...          None  outpatient
#
#        payer_category                         payer_name plan_name  \
# 0               gross                       Gross Charge      None
# 1               gross                       Gross Charge      None
# 2               gross                       Gross Charge      None
# 3               gross                       Gross Charge      None
# 4               gross                       Gross Charge      None
# ...               ...                                ...       ...
# 184407          payer  Rocky Mountain HMO-Commercial HMO      None
# 184408          payer  Rocky Mountain HMO-Commercial HMO      None
# 184409          payer  Rocky Mountain HMO-Commercial HMO      None
# 184498          payer  Rocky Mountain HMO-Commercial HMO      None
# 184546          payer  Rocky Mountain HMO-Commercial HMO      None
#
#        standard_charge standard_charge_percent contracting_method  \
# 0              1764.18                    None               None
# 1               1213.0                    None               None
# 2               431.15                    None               None
# 3               314.25                    None               None
# 4               3131.1                    None               None
# ...                ...                     ...                ...
# 184407          293.33                    None               None
# 184408          162.22                    None               None
# 184409          222.28                    None               None
# 184498          122.95                    None               None
# 184546           43.35                    None               None
#
#        additional_generic_notes additional_payer_specific_notes
# 0                          None                            None
# 1                          None                            None
# 2                          None                            None
# 3                          None                            None
# 4                          None                            None
# ...                         ...                             ...
# 184407                     None                            None
# 184408                     None                            None
# 184409                     None                            None
# 184498                     None                            None
# 184546                     None                            None
#
# [9710 rows x 30 columns]

# %%
df_out.to_csv('rate_' + ccn + '.csv', index=False)

# %%
df_out[df_out['hcpcs_cpt'].notnull()]
# Out:
#        hospital_id line_type  \
# 844         060126      None
# 845         060126      None
# 846         060126      None
# 847         060126      None
# 848         060126      None
# ...            ...       ...
# 171544      060126      None
# 171549      060126      None
# 171550      060126      None
# 184498      060126      None
# 184546      060126      None
#
#                                               description rev_code local_code  \
# 844     Harvest and injections of platelet rich plasma...     None       None
# 845     Analysis of data from CT study of heart blood ...     None       None
# 846     Analysis of data from CT study of heart blood ...     None       None
# 847     Noncontact real-time fluorescence wound imagin...     None       None
# 848     Noncontact real-time fluorescence wound imagin...     None       None
# ...                                                   ...      ...        ...
# 171544  High osmolar contrast material, 350-399 mg/ml ...     None       None
# 171549  Infectious agent detection by nucleic acid (DN...     None       None
# 171550  Infectious agent detection by nucleic acid (dn...     None       None
# 184498  Drug test(s), definitive, utilizing (1) drug i...     None       None
# 184546       Injection, ketorolac tromethamine, per 15 mg     None       None
#
#          code ms_drg apr_drg  eapg hcpcs_cpt  ... billing_class     setting  \
# 844     0232T   None    None  None     0232T  ...          None  outpatient
# 845     0502T   None    None  None     0502T  ...          None  outpatient
# 846     0503T   None    None  None     0503T  ...          None  outpatient
# 847     0598T   None    None  None     0598T  ...          None  outpatient
# 848     0599T   None    None  None     0599T  ...          None  outpatient
# ...       ...    ...     ...   ...       ...  ...           ...         ...
# 171544  Q9963   None    None  None     Q9963  ...          None  outpatient
# 171549  U0003   None    None  None     U0003  ...          None  outpatient
# 171550  U0005   None    None  None     U0005  ...          None  outpatient
# 184498  G0480   None    None  None     G0480  ...          None  outpatient
# 184546  J1885   None    None  None     J1885  ...          None  outpatient
#
#        payer_category                         payer_name plan_name  \
# 844             gross                       Gross Charge      None
# 845             gross                       Gross Charge      None
# 846             gross                       Gross Charge      None
# 847             gross                       Gross Charge      None
# 848             gross                       Gross Charge      None
# ...               ...                                ...       ...
# 171544          payer  Kaiser Permanaente-Commercial HMO      None
# 171549          payer  Kaiser Permanaente-Commercial HMO      None
# 171550          payer  Kaiser Permanaente-Commercial HMO      None
# 184498          payer  Rocky Mountain HMO-Commercial HMO      None
# 184546          payer  Rocky Mountain HMO-Commercial HMO      None
#
#        standard_charge standard_charge_percent contracting_method  \
# 844            7226.61                    None               None
# 845             3208.0                    None               None
# 846             3208.0                    None               None
# 847             1459.0                    None               None
# 848             813.18                    None               None
# ...                ...                     ...                ...
# 171544            0.74                    None               None
# 171549           135.5                    None               None
# 171550           42.75                    None               None
# 184498          122.95                    None               None
# 184546           43.35                    None               None
#
#        additional_generic_notes additional_payer_specific_notes
# 844                        None                            None
# 845                        None                            None
# 846                        None                            None
# 847                        None                            None
# 848                        None                            None
# ...                         ...                             ...
# 171544                     None                            None
# 171549                     None                            None
# 171550                     None                            None
# 184498                     None                            None
# 184546                     None                            None
#
# [1806 rows x 30 columns]
