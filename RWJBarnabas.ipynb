# %%
import subprocess

import pandas as pd

# %%
TARGET_COLUMNS = [
    'hospital_id',
    #'row_id',
    'line_type',
    'description',
    'rev_code',
    'local_code',
    'code',
    'ms_drg',
    'apr_drg',
    'eapg',
    'hcpcs_cpt',
    'modifiers',
    'alt_hcpcs_cpt',
    'thru',
    'apc',
    'icd',
    'ndc',
    'drug_hcpcs_multiplier',
    'drug_quantity',
    'drug_unit_of_measurement',
    'drug_type_of_measurement',
    'billing_class',
    'setting',
    'payer_category',
    'payer_name',
    'plan_name',
    'standard_charge',
    'standard_charge_percent',
    'contracting_method',
    'additional_generic_notes',
    'additional_payer_specific_notes'
]

# %%
ccn = "310041"
url = "https://www.rwjbh.org/documents/billing/mrf/223452306_community-medical-center_standardcharges.csv"
filename = url.split("/")[-1]
ein = filename.split("_")[0]
ein = ein[:2] + "-" + ein[2:]
ein
# Out:
# '22-3452306'

# %%
subprocess.run(["wget", "--no-clobber", url, "-O", filename])
# Out:
# File ‘223452306_community-medical-center_standardcharges.csv’ already there; not retrieving.
# CompletedProcess(args=['wget', '--no-clobber', 'https://www.rwjbh.org/documents/billing/mrf/223452306_community-medical-center_standardcharges.csv', '-O', '223452306_community-medical-center_standardcharges.csv'], returncode=1)

# %%
df_in = pd.read_csv(filename, skiprows=[1,2,3], encoding='latin-1')
df_in.columns = df_in.iloc[0]
df_in = df_in.iloc[1:]
df_in
# Out:
# 0                                          Hospital Name Hospital Code
# 1                               Community Medical Center           CMC  \
# 2                               Community Medical Center           CMC
# 3                               Community Medical Center           CMC
# 4                               Community Medical Center           CMC
# 5                               Community Medical Center           CMC
# ...                                                  ...           ...
# 67593                           Community Medical Center           CMC
# 67594                           Community Medical Center           CMC
# 67595                           Community Medical Center           CMC
# 67596                                                NaN           NaN
# 67597  * The Discounted Cash Price represents the ave...           NaN
#
# 0                Service Type Billing Code
# 1      Inpatient / Outpatient        C1887  \
# 2      Inpatient / Outpatient        C1713
# 3      Inpatient / Outpatient       344527
# 4      Inpatient / Outpatient       357561
# 5      Inpatient / Outpatient       357558
# ...                       ...          ...
# 67593  Inpatient / Outpatient        C1776
# 67594  Inpatient / Outpatient       208357
# 67595  Inpatient / Outpatient        52989
# 67596                     NaN          NaN
# 67597                     NaN          NaN
#
# 0                                    Service Description  Gross Charge
# 1      1.2 F X 12 Cm Olive-Shaped Distal Tip 165Cm Hy...     $1,992.50   \
# 2                           1-Level 16 Mm Cervical Plate     $3,125.00
# 3                           22Mm Silicone Orbital Sphere       $125.00
# 4              3D Printed Cage 30Mm X 11Mm X 11Mm Convex    $12,500.00
# 5               3D Printed Cage 30Mm X 11Mm X 7Mm Convex    $12,500.00
# ...                                                  ...            ...
# 67593                     Yoke Tibial Oss Knee Reinforce     $2,832.50
# 67594                                       Zipper Child        $70.85
# 67595                  Zipper Each Opening Adult Jobskin        $78.73
# 67596                                                NaN            NaN
# 67597                                                NaN            NaN
#
# 0      Aetna - Commercial HMO Negotiated Charge
# 1                                       $996.25   \
# 2                                     $1,562.50
# 3                                        $62.50
# 4                                     $6,250.00
# 5                                     $6,250.00
# ...                                          ...
# 67593                                 $1,416.25
# 67594                                    $35.43
# 67595                                    $39.36
# 67596                                        NaN
# 67597                                        NaN
#
# 0      Aetna - Commercial PPO Negotiated Charge
# 1                                       $996.25   \
# 2                                     $1,562.50
# 3                                        $62.50
# 4                                     $6,250.00
# 5                                     $6,250.00
# ...                                          ...
# 67593                                 $1,416.25
# 67594                                    $35.43
# 67595                                    $39.36
# 67596                                        NaN
# 67597                                        NaN
#
# 0      Aetna - Aetna Better Health Negotiated Charge
# 1                                            $996.25   \
# 2                                          $1,562.50
# 3                                             $62.50
# 4                                          $6,250.00
# 5                                          $6,250.00
# ...                                               ...
# 67593                                      $1,416.25
# 67594                                         $35.43
# 67595                                         $39.36
# 67596                                             NaN
# 67597                                             NaN
#
# 0      Amerigroup - NJ FamilyCare Negotiated Charge   ...
# 1                                           $996.25   ...  \
# 2                                         $1,562.50   ...
# 3                                            $62.50   ...
# 4                                         $6,250.00   ...
# 5                                         $6,250.00   ...
# ...                                              ...  ...
# 67593                                     $1,416.25   ...
# 67594                                        $35.43   ...
# 67595                                        $39.36   ...
# 67596                                            NaN  ...
# 67597                                            NaN  ...
#
# 0      United - Community & State Negotiated Charge
# 1                                           $996.25   \
# 2                                         $1,562.50
# 3                                            $62.50
# 4                                         $6,250.00
# 5                                         $6,250.00
# ...                                              ...
# 67593                                     $1,416.25
# 67594                                        $35.43
# 67595                                        $39.36
# 67596                                            NaN
# 67597                                            NaN
#
# 0      Horizon - Commercial HMO Negotiated Charge
# 1                                         $996.25   \
# 2                                       $1,562.50
# 3                                          $62.50
# 4                                       $6,250.00
# 5                                       $6,250.00
# ...                                            ...
# 67593                                   $1,416.25
# 67594                                      $35.43
# 67595                                      $39.36
# 67596                                          NaN
# 67597                                          NaN
#
# 0      Horizon - Commercial PPO Negotiated Charge
# 1                                         $996.25   \
# 2                                       $1,562.50
# 3                                          $62.50
# 4                                       $6,250.00
# 5                                       $6,250.00
# ...                                            ...
# 67593                                   $1,416.25
# 67594                                      $35.43
# 67595                                      $39.36
# 67596                                          NaN
# 67597                                          NaN
#
# 0      Amerihealth - Commercial Local Value Negotiated Charge
# 1                                               $996.25         \
# 2                                             $1,562.50
# 3                                                $62.50
# 4                                             $6,250.00
# 5                                             $6,250.00
# ...                                                  ...
# 67593                                         $1,416.25
# 67594                                            $35.43
# 67595                                            $39.36
# 67596                                                NaN
# 67597                                                NaN
#
# 0      Amerihealth - Commercial Regional Preferred Negotiated Charge
# 1                                               $996.25                \
# 2                                             $1,562.50
# 3                                                $62.50
# 4                                             $6,250.00
# 5                                             $6,250.00
# ...                                                  ...
# 67593                                         $1,416.25
# 67594                                            $35.43
# 67595                                            $39.36
# 67596                                                NaN
# 67597                                                NaN
#
# 0      Horizon - NJ Health Negotiated Charge
# 1                                    $996.25   \
# 2                                  $1,562.50
# 3                                     $62.50
# 4                                  $6,250.00
# 5                                  $6,250.00
# ...                                       ...
# 67593                              $1,416.25
# 67594                                 $35.43
# 67595                                 $39.36
# 67596                                     NaN
# 67597                                     NaN
#
# 0      Wellcare - NJ FamilyCare Negotiated Charge
# 1                                         $996.25   \
# 2                                       $1,562.50
# 3                                          $62.50
# 4                                       $6,250.00
# 5                                       $6,250.00
# ...                                            ...
# 67593                                   $1,416.25
# 67594                                      $35.43
# 67595                                      $39.36
# 67596                                          NaN
# 67597                                          NaN
#
# 0      De-identified Minimum Negotiated Charge
# 1                                      $996.25   \
# 2                                    $1,562.50
# 3                                       $62.50
# 4                                    $6,250.00
# 5                                    $6,250.00
# ...                                         ...
# 67593                                $1,416.25
# 67594                                   $35.43
# 67595                                   $39.36
# 67596                                       NaN
# 67597                                       NaN
#
# 0      De-identified Maximum Negotiated Charge
# 1                                      $996.25   \
# 2                                    $1,562.50
# 3                                       $62.50
# 4                                    $6,250.00
# 5                                    $6,250.00
# ...                                         ...
# 67593                                $1,416.25
# 67594                                   $35.43
# 67595                                   $39.36
# 67596                                       NaN
# 67597                                       NaN
#
# 0      Discounted Cash Price * (See Below)
# 1                                $1,992.50
# 2                                $3,125.00
# 3                                  $125.00
# 4                               $12,500.00
# 5                               $12,500.00
# ...                                     ...
# 67593                            $2,832.50
# 67594                               $70.85
# 67595                               $78.73
# 67596                                   NaN
# 67597                                   NaN
#
# [67597 rows x 25 columns]

# %%
df_mid = pd.DataFrame(df_in)
df_mid = df_mid.rename(columns={
    'Service Type': 'setting',
    'Billing Code': 'code',
    'Service Description': 'description',
})

del df_mid['Hospital Name']
del df_mid['Hospital Code']

df_mid
# Out:
# 0                     setting    code
# 1      Inpatient / Outpatient   C1887  \
# 2      Inpatient / Outpatient   C1713
# 3      Inpatient / Outpatient  344527
# 4      Inpatient / Outpatient  357561
# 5      Inpatient / Outpatient  357558
# ...                       ...     ...
# 67593  Inpatient / Outpatient   C1776
# 67594  Inpatient / Outpatient  208357
# 67595  Inpatient / Outpatient   52989
# 67596                     NaN     NaN
# 67597                     NaN     NaN
#
# 0                                            description  Gross Charge
# 1      1.2 F X 12 Cm Olive-Shaped Distal Tip 165Cm Hy...     $1,992.50   \
# 2                           1-Level 16 Mm Cervical Plate     $3,125.00
# 3                           22Mm Silicone Orbital Sphere       $125.00
# 4              3D Printed Cage 30Mm X 11Mm X 11Mm Convex    $12,500.00
# 5               3D Printed Cage 30Mm X 11Mm X 7Mm Convex    $12,500.00
# ...                                                  ...            ...
# 67593                     Yoke Tibial Oss Knee Reinforce     $2,832.50
# 67594                                       Zipper Child        $70.85
# 67595                  Zipper Each Opening Adult Jobskin        $78.73
# 67596                                                NaN            NaN
# 67597                                                NaN            NaN
#
# 0      Aetna - Commercial HMO Negotiated Charge
# 1                                       $996.25   \
# 2                                     $1,562.50
# 3                                        $62.50
# 4                                     $6,250.00
# 5                                     $6,250.00
# ...                                          ...
# 67593                                 $1,416.25
# 67594                                    $35.43
# 67595                                    $39.36
# 67596                                        NaN
# 67597                                        NaN
#
# 0      Aetna - Commercial PPO Negotiated Charge
# 1                                       $996.25   \
# 2                                     $1,562.50
# 3                                        $62.50
# 4                                     $6,250.00
# 5                                     $6,250.00
# ...                                          ...
# 67593                                 $1,416.25
# 67594                                    $35.43
# 67595                                    $39.36
# 67596                                        NaN
# 67597                                        NaN
#
# 0      Aetna - Aetna Better Health Negotiated Charge
# 1                                            $996.25   \
# 2                                          $1,562.50
# 3                                             $62.50
# 4                                          $6,250.00
# 5                                          $6,250.00
# ...                                               ...
# 67593                                      $1,416.25
# 67594                                         $35.43
# 67595                                         $39.36
# 67596                                             NaN
# 67597                                             NaN
#
# 0      Amerigroup - NJ FamilyCare Negotiated Charge
# 1                                           $996.25   \
# 2                                         $1,562.50
# 3                                            $62.50
# 4                                         $6,250.00
# 5                                         $6,250.00
# ...                                              ...
# 67593                                     $1,416.25
# 67594                                        $35.43
# 67595                                        $39.36
# 67596                                            NaN
# 67597                                            NaN
#
# 0      Cigna - Commercial HMO Negotiated Charge
# 1                                       $996.25   \
# 2                                     $1,562.50
# 3                                        $62.50
# 4                                     $6,250.00
# 5                                     $6,250.00
# ...                                          ...
# 67593                                 $1,416.25
# 67594                                    $35.43
# 67595                                    $39.36
# 67596                                        NaN
# 67597                                        NaN
#
# 0      Cigna - Commercial PPO Negotiated Charge   ...
# 1                                       $996.25   ...  \
# 2                                     $1,562.50   ...
# 3                                        $62.50   ...
# 4                                     $6,250.00   ...
# 5                                     $6,250.00   ...
# ...                                          ...  ...
# 67593                                 $1,416.25   ...
# 67594                                    $35.43   ...
# 67595                                    $39.36   ...
# 67596                                        NaN  ...
# 67597                                        NaN  ...
#
# 0      United - Community & State Negotiated Charge
# 1                                           $996.25   \
# 2                                         $1,562.50
# 3                                            $62.50
# 4                                         $6,250.00
# 5                                         $6,250.00
# ...                                              ...
# 67593                                     $1,416.25
# 67594                                        $35.43
# 67595                                        $39.36
# 67596                                            NaN
# 67597                                            NaN
#
# 0      Horizon - Commercial HMO Negotiated Charge
# 1                                         $996.25   \
# 2                                       $1,562.50
# 3                                          $62.50
# 4                                       $6,250.00
# 5                                       $6,250.00
# ...                                            ...
# 67593                                   $1,416.25
# 67594                                      $35.43
# 67595                                      $39.36
# 67596                                          NaN
# 67597                                          NaN
#
# 0      Horizon - Commercial PPO Negotiated Charge
# 1                                         $996.25   \
# 2                                       $1,562.50
# 3                                          $62.50
# 4                                       $6,250.00
# 5                                       $6,250.00
# ...                                            ...
# 67593                                   $1,416.25
# 67594                                      $35.43
# 67595                                      $39.36
# 67596                                          NaN
# 67597                                          NaN
#
# 0      Amerihealth - Commercial Local Value Negotiated Charge
# 1                                               $996.25         \
# 2                                             $1,562.50
# 3                                                $62.50
# 4                                             $6,250.00
# 5                                             $6,250.00
# ...                                                  ...
# 67593                                         $1,416.25
# 67594                                            $35.43
# 67595                                            $39.36
# 67596                                                NaN
# 67597                                                NaN
#
# 0      Amerihealth - Commercial Regional Preferred Negotiated Charge
# 1                                               $996.25                \
# 2                                             $1,562.50
# 3                                                $62.50
# 4                                             $6,250.00
# 5                                             $6,250.00
# ...                                                  ...
# 67593                                         $1,416.25
# 67594                                            $35.43
# 67595                                            $39.36
# 67596                                                NaN
# 67597                                                NaN
#
# 0      Horizon - NJ Health Negotiated Charge
# 1                                    $996.25   \
# 2                                  $1,562.50
# 3                                     $62.50
# 4                                  $6,250.00
# 5                                  $6,250.00
# ...                                       ...
# 67593                              $1,416.25
# 67594                                 $35.43
# 67595                                 $39.36
# 67596                                     NaN
# 67597                                     NaN
#
# 0      Wellcare - NJ FamilyCare Negotiated Charge
# 1                                         $996.25   \
# 2                                       $1,562.50
# 3                                          $62.50
# 4                                       $6,250.00
# 5                                       $6,250.00
# ...                                            ...
# 67593                                   $1,416.25
# 67594                                      $35.43
# 67595                                      $39.36
# 67596                                          NaN
# 67597                                          NaN
#
# 0      De-identified Minimum Negotiated Charge
# 1                                      $996.25   \
# 2                                    $1,562.50
# 3                                       $62.50
# 4                                    $6,250.00
# 5                                    $6,250.00
# ...                                         ...
# 67593                                $1,416.25
# 67594                                   $35.43
# 67595                                   $39.36
# 67596                                       NaN
# 67597                                       NaN
#
# 0      De-identified Maximum Negotiated Charge
# 1                                      $996.25   \
# 2                                    $1,562.50
# 3                                       $62.50
# 4                                    $6,250.00
# 5                                    $6,250.00
# ...                                         ...
# 67593                                $1,416.25
# 67594                                   $35.43
# 67595                                   $39.36
# 67596                                       NaN
# 67597                                       NaN
#
# 0      Discounted Cash Price * (See Below)
# 1                                $1,992.50
# 2                                $3,125.00
# 3                                  $125.00
# 4                               $12,500.00
# 5                               $12,500.00
# ...                                     ...
# 67593                            $2,832.50
# 67594                               $70.85
# 67595                               $78.73
# 67596                                   NaN
# 67597                                   NaN
#
# [67597 rows x 23 columns]

# %%
money_columns = df_mid.columns.to_list()[3:]
remaining_columns = df_mid.columns.to_list()[:3]
df_mid = pd.melt(df_mid, id_vars=remaining_columns, var_name='payer_name', value_name='standard_charge')
df_mid
# Out:
#                         setting    code
# 0        Inpatient / Outpatient   C1887  \
# 1        Inpatient / Outpatient   C1713
# 2        Inpatient / Outpatient  344527
# 3        Inpatient / Outpatient  357561
# 4        Inpatient / Outpatient  357558
# ...                         ...     ...
# 1351935  Inpatient / Outpatient   C1776
# 1351936  Inpatient / Outpatient  208357
# 1351937  Inpatient / Outpatient   52989
# 1351938                     NaN     NaN
# 1351939                     NaN     NaN
#
#                                                description
# 0        1.2 F X 12 Cm Olive-Shaped Distal Tip 165Cm Hy...  \
# 1                             1-Level 16 Mm Cervical Plate
# 2                             22Mm Silicone Orbital Sphere
# 3                3D Printed Cage 30Mm X 11Mm X 11Mm Convex
# 4                 3D Printed Cage 30Mm X 11Mm X 7Mm Convex
# ...                                                    ...
# 1351935                     Yoke Tibial Oss Knee Reinforce
# 1351936                                       Zipper Child
# 1351937                  Zipper Each Opening Adult Jobskin
# 1351938                                                NaN
# 1351939                                                NaN
#
#                                     payer_name standard_charge
# 0                                Gross Charge       $1,992.50
# 1                                Gross Charge       $3,125.00
# 2                                Gross Charge         $125.00
# 3                                Gross Charge      $12,500.00
# 4                                Gross Charge      $12,500.00
# ...                                        ...             ...
# 1351935   Discounted Cash Price * (See Below)       $2,832.50
# 1351936   Discounted Cash Price * (See Below)          $70.85
# 1351937   Discounted Cash Price * (See Below)          $78.73
# 1351938   Discounted Cash Price * (See Below)              NaN
# 1351939   Discounted Cash Price * (See Below)              NaN
#
# [1351940 rows x 5 columns]

# %%
df_mid['code']
# Out:
# 0           C1887
# 1           C1713
# 2          344527
# 3          357561
# 4          357558
#             ...
# 1351935     C1776
# 1351936    208357
# 1351937     52989
# 1351938       NaN
# 1351939       NaN
# Name: code, Length: 1351940, dtype: object

# %%
df_mid['ms_drg'] = df_mid['code'].apply(lambda code: str(code) if code is not None and len(str(code)) == 3 else None)
df_mid['hcpcs_cpt'] = df_mid['code'].apply(lambda code: str(code) if code is not None and len(str(code)) == 5 else None)

df_mid
# Out:
#                         setting    code
# 0        Inpatient / Outpatient   C1887  \
# 1        Inpatient / Outpatient   C1713
# 2        Inpatient / Outpatient  344527
# 3        Inpatient / Outpatient  357561
# 4        Inpatient / Outpatient  357558
# ...                         ...     ...
# 1351935  Inpatient / Outpatient   C1776
# 1351936  Inpatient / Outpatient  208357
# 1351937  Inpatient / Outpatient   52989
# 1351938                     NaN     NaN
# 1351939                     NaN     NaN
#
#                                                description
# 0        1.2 F X 12 Cm Olive-Shaped Distal Tip 165Cm Hy...  \
# 1                             1-Level 16 Mm Cervical Plate
# 2                             22Mm Silicone Orbital Sphere
# 3                3D Printed Cage 30Mm X 11Mm X 11Mm Convex
# 4                 3D Printed Cage 30Mm X 11Mm X 7Mm Convex
# ...                                                    ...
# 1351935                     Yoke Tibial Oss Knee Reinforce
# 1351936                                       Zipper Child
# 1351937                  Zipper Each Opening Adult Jobskin
# 1351938                                                NaN
# 1351939                                                NaN
#
#                                     payer_name standard_charge ms_drg
# 0                                Gross Charge       $1,992.50    None  \
# 1                                Gross Charge       $3,125.00    None
# 2                                Gross Charge         $125.00    None
# 3                                Gross Charge      $12,500.00    None
# 4                                Gross Charge      $12,500.00    None
# ...                                        ...             ...    ...
# 1351935   Discounted Cash Price * (See Below)       $2,832.50    None
# 1351936   Discounted Cash Price * (See Below)          $70.85    None
# 1351937   Discounted Cash Price * (See Below)          $78.73    None
# 1351938   Discounted Cash Price * (See Below)              NaN    nan
# 1351939   Discounted Cash Price * (See Below)              NaN    nan
#
#         hcpcs_cpt
# 0           C1887
# 1           C1713
# 2            None
# 3            None
# 4            None
# ...           ...
# 1351935     C1776
# 1351936      None
# 1351937     52989
# 1351938      None
# 1351939      None
#
# [1351940 rows x 7 columns]

# %%
from helpers import cleanup_dollar_value
df_mid = df_mid[df_mid['standard_charge'].notnull()]
df_mid['standard_charge'] = df_mid['standard_charge'].apply(cleanup_dollar_value)
df_mid = df_mid[df_mid['standard_charge'] != "-"]
df_mid = df_mid[df_mid['standard_charge'] != "n/a"]
df_mid = df_mid[df_mid['standard_charge'] != "#REF!"]
df_mid
# Out:
# /tmp/ipykernel_16577/1042018696.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mid['standard_charge'] = df_mid['standard_charge'].apply(cleanup_dollar_value)
#                         setting    code
# 0        Inpatient / Outpatient   C1887  \
# 1        Inpatient / Outpatient   C1713
# 2        Inpatient / Outpatient  344527
# 3        Inpatient / Outpatient  357561
# 4        Inpatient / Outpatient  357558
# ...                         ...     ...
# 1351933  Inpatient / Outpatient  258875
# 1351934  Inpatient / Outpatient   C1776
# 1351935  Inpatient / Outpatient   C1776
# 1351936  Inpatient / Outpatient  208357
# 1351937  Inpatient / Outpatient   52989
#
#                                                description
# 0        1.2 F X 12 Cm Olive-Shaped Distal Tip 165Cm Hy...  \
# 1                             1-Level 16 Mm Cervical Plate
# 2                             22Mm Silicone Orbital Sphere
# 3                3D Printed Cage 30Mm X 11Mm X 11Mm Convex
# 4                 3D Printed Cage 30Mm X 11Mm X 7Mm Convex
# ...                                                    ...
# 1351933  Xxx Nla Per Allergan Sizer Implant 14X14.5Cm N...
# 1351934                   Yoke Oss Reinforced Sterile 4 Mm
# 1351935                     Yoke Tibial Oss Knee Reinforce
# 1351936                                       Zipper Child
# 1351937                  Zipper Each Opening Adult Jobskin
#
#                                     payer_name standard_charge ms_drg
# 0                                Gross Charge          1992.50   None  \
# 1                                Gross Charge          3125.00   None
# 2                                Gross Charge           125.00   None
# 3                                Gross Charge         12500.00   None
# 4                                Gross Charge         12500.00   None
# ...                                        ...             ...    ...
# 1351933   Discounted Cash Price * (See Below)           562.50   None
# 1351934   Discounted Cash Price * (See Below)          8240.00   None
# 1351935   Discounted Cash Price * (See Below)          2832.50   None
# 1351936   Discounted Cash Price * (See Below)            70.85   None
# 1351937   Discounted Cash Price * (See Below)            78.73   None
#
#         hcpcs_cpt
# 0           C1887
# 1           C1713
# 2            None
# 3            None
# 4            None
# ...           ...
# 1351933      None
# 1351934     C1776
# 1351935     C1776
# 1351936      None
# 1351937     52989
#
# [1351826 rows x 7 columns]

# %%
def payer_category_from_payer_name(payer_name):
    payer_name = payer_name.strip()
    
    if payer_name == "Gross Charge":
        return 'gross'
    elif payer_name.startswith('Discounted Cash Price'):
        return 'cash'
    elif payer_name.startswith('De-identified Minimum Negotiated Charge'):
        return 'min'
    elif payer_name.startswith('De-identified Maximum Negotiated Charge'):
        return 'max'

    return 'payer'

df_mid['payer_category'] = df_mid['payer_name'].apply(payer_category_from_payer_name)
df_mid
# Out:
#                         setting    code
# 0        Inpatient / Outpatient   C1887  \
# 1        Inpatient / Outpatient   C1713
# 2        Inpatient / Outpatient  344527
# 3        Inpatient / Outpatient  357561
# 4        Inpatient / Outpatient  357558
# ...                         ...     ...
# 1351933  Inpatient / Outpatient  258875
# 1351934  Inpatient / Outpatient   C1776
# 1351935  Inpatient / Outpatient   C1776
# 1351936  Inpatient / Outpatient  208357
# 1351937  Inpatient / Outpatient   52989
#
#                                                description
# 0        1.2 F X 12 Cm Olive-Shaped Distal Tip 165Cm Hy...  \
# 1                             1-Level 16 Mm Cervical Plate
# 2                             22Mm Silicone Orbital Sphere
# 3                3D Printed Cage 30Mm X 11Mm X 11Mm Convex
# 4                 3D Printed Cage 30Mm X 11Mm X 7Mm Convex
# ...                                                    ...
# 1351933  Xxx Nla Per Allergan Sizer Implant 14X14.5Cm N...
# 1351934                   Yoke Oss Reinforced Sterile 4 Mm
# 1351935                     Yoke Tibial Oss Knee Reinforce
# 1351936                                       Zipper Child
# 1351937                  Zipper Each Opening Adult Jobskin
#
#                                     payer_name standard_charge ms_drg
# 0                                Gross Charge          1992.50   None  \
# 1                                Gross Charge          3125.00   None
# 2                                Gross Charge           125.00   None
# 3                                Gross Charge         12500.00   None
# 4                                Gross Charge         12500.00   None
# ...                                        ...             ...    ...
# 1351933   Discounted Cash Price * (See Below)           562.50   None
# 1351934   Discounted Cash Price * (See Below)          8240.00   None
# 1351935   Discounted Cash Price * (See Below)          2832.50   None
# 1351936   Discounted Cash Price * (See Below)            70.85   None
# 1351937   Discounted Cash Price * (See Below)            78.73   None
#
#         hcpcs_cpt payer_category
# 0           C1887          gross
# 1           C1713          gross
# 2            None          gross
# 3            None          gross
# 4            None          gross
# ...           ...            ...
# 1351933      None           cash
# 1351934     C1776           cash
# 1351935     C1776           cash
# 1351936      None           cash
# 1351937     52989           cash
#
# [1351826 rows x 8 columns]

# %%
df_mid.loc[df_mid['setting'] == 'Inpatient', 'setting'] = 'inpatient'
df_mid.loc[df_mid['setting'] == 'Inpatient / Outpatient', 'setting'] = 'both'
df_mid.loc[df_mid['setting'] == 'Outpatient', 'setting'] = 'outpatient'

# %%
df_mid['hospital_id'] = ccn
df_mid['line_type'] = None
df_mid['rev_code'] = None
df_mid['local_code'] = None
df_mid['apr_drg'] = None
df_mid['eapg'] = None
df_mid['modifiers'] = None
df_mid['alt_hcpcs_cpt'] = None
df_mid['thru'] = None
df_mid['apc'] = None
df_mid['icd'] = None
df_mid['ndc'] = None
df_mid['drug_hcpcs_multiplier'] = None
df_mid['drug_quantity'] = None
df_mid['drug_unit_of_measurement'] = None
df_mid['drug_type_of_measurement'] = None
df_mid['billing_class'] = None
df_mid['plan_name'] = None
df_mid['standard_charge_percent'] = None
df_mid['contracting_method'] = None
df_mid['additional_generic_notes'] = None
df_mid['additional_payer_specific_notes'] = None

df_mid
# Out:
#         setting    code                                        description
# 0          both   C1887  1.2 F X 12 Cm Olive-Shaped Distal Tip 165Cm Hy...  \
# 1          both   C1713                       1-Level 16 Mm Cervical Plate
# 2          both  344527                       22Mm Silicone Orbital Sphere
# 3          both  357561          3D Printed Cage 30Mm X 11Mm X 11Mm Convex
# 4          both  357558           3D Printed Cage 30Mm X 11Mm X 7Mm Convex
# ...         ...     ...                                                ...
# 1351933    both  258875  Xxx Nla Per Allergan Sizer Implant 14X14.5Cm N...
# 1351934    both   C1776                   Yoke Oss Reinforced Sterile 4 Mm
# 1351935    both   C1776                     Yoke Tibial Oss Knee Reinforce
# 1351936    both  208357                                       Zipper Child
# 1351937    both   52989                  Zipper Each Opening Adult Jobskin
#
#                                     payer_name standard_charge ms_drg
# 0                                Gross Charge          1992.50   None  \
# 1                                Gross Charge          3125.00   None
# 2                                Gross Charge           125.00   None
# 3                                Gross Charge         12500.00   None
# 4                                Gross Charge         12500.00   None
# ...                                        ...             ...    ...
# 1351933   Discounted Cash Price * (See Below)           562.50   None
# 1351934   Discounted Cash Price * (See Below)          8240.00   None
# 1351935   Discounted Cash Price * (See Below)          2832.50   None
# 1351936   Discounted Cash Price * (See Below)            70.85   None
# 1351937   Discounted Cash Price * (See Below)            78.73   None
#
#         hcpcs_cpt payer_category hospital_id line_type  ...
# 0           C1887          gross      310041      None  ...  \
# 1           C1713          gross      310041      None  ...
# 2            None          gross      310041      None  ...
# 3            None          gross      310041      None  ...
# 4            None          gross      310041      None  ...
# ...           ...            ...         ...       ...  ...
# 1351933      None           cash      310041      None  ...
# 1351934     C1776           cash      310041      None  ...
# 1351935     C1776           cash      310041      None  ...
# 1351936      None           cash      310041      None  ...
# 1351937     52989           cash      310041      None  ...
#
#         drug_hcpcs_multiplier drug_quantity drug_unit_of_measurement
# 0                        None          None                     None  \
# 1                        None          None                     None
# 2                        None          None                     None
# 3                        None          None                     None
# 4                        None          None                     None
# ...                       ...           ...                      ...
# 1351933                  None          None                     None
# 1351934                  None          None                     None
# 1351935                  None          None                     None
# 1351936                  None          None                     None
# 1351937                  None          None                     None
#
#         drug_type_of_measurement billing_class plan_name
# 0                           None          None      None  \
# 1                           None          None      None
# 2                           None          None      None
# 3                           None          None      None
# 4                           None          None      None
# ...                          ...           ...       ...
# 1351933                     None          None      None
# 1351934                     None          None      None
# 1351935                     None          None      None
# 1351936                     None          None      None
# 1351937                     None          None      None
#
#         standard_charge_percent contracting_method additional_generic_notes
# 0                          None               None                     None  \
# 1                          None               None                     None
# 2                          None               None                     None
# 3                          None               None                     None
# 4                          None               None                     None
# ...                         ...                ...                      ...
# 1351933                    None               None                     None
# 1351934                    None               None                     None
# 1351935                    None               None                     None
# 1351936                    None               None                     None
# 1351937                    None               None                     None
#
#         additional_payer_specific_notes
# 0                                  None
# 1                                  None
# 2                                  None
# 3                                  None
# 4                                  None
# ...                                 ...
# 1351933                            None
# 1351934                            None
# 1351935                            None
# 1351936                            None
# 1351937                            None
#
# [1351826 rows x 30 columns]

# %%
df_out = pd.DataFrame(df_mid[TARGET_COLUMNS])
df_out
# Out:
#         hospital_id line_type
# 0            310041      None  \
# 1            310041      None
# 2            310041      None
# 3            310041      None
# 4            310041      None
# ...             ...       ...
# 1351933      310041      None
# 1351934      310041      None
# 1351935      310041      None
# 1351936      310041      None
# 1351937      310041      None
#
#                                                description rev_code
# 0        1.2 F X 12 Cm Olive-Shaped Distal Tip 165Cm Hy...     None  \
# 1                             1-Level 16 Mm Cervical Plate     None
# 2                             22Mm Silicone Orbital Sphere     None
# 3                3D Printed Cage 30Mm X 11Mm X 11Mm Convex     None
# 4                 3D Printed Cage 30Mm X 11Mm X 7Mm Convex     None
# ...                                                    ...      ...
# 1351933  Xxx Nla Per Allergan Sizer Implant 14X14.5Cm N...     None
# 1351934                   Yoke Oss Reinforced Sterile 4 Mm     None
# 1351935                     Yoke Tibial Oss Knee Reinforce     None
# 1351936                                       Zipper Child     None
# 1351937                  Zipper Each Opening Adult Jobskin     None
#
#         local_code    code ms_drg apr_drg  eapg hcpcs_cpt  ... billing_class
# 0             None   C1887   None    None  None     C1887  ...          None  \
# 1             None   C1713   None    None  None     C1713  ...          None
# 2             None  344527   None    None  None      None  ...          None
# 3             None  357561   None    None  None      None  ...          None
# 4             None  357558   None    None  None      None  ...          None
# ...            ...     ...    ...     ...   ...       ...  ...           ...
# 1351933       None  258875   None    None  None      None  ...          None
# 1351934       None   C1776   None    None  None     C1776  ...          None
# 1351935       None   C1776   None    None  None     C1776  ...          None
# 1351936       None  208357   None    None  None      None  ...          None
# 1351937       None   52989   None    None  None     52989  ...          None
#
#         setting payer_category                             payer_name
# 0          both          gross                          Gross Charge   \
# 1          both          gross                          Gross Charge
# 2          both          gross                          Gross Charge
# 3          both          gross                          Gross Charge
# 4          both          gross                          Gross Charge
# ...         ...            ...                                    ...
# 1351933    both           cash   Discounted Cash Price * (See Below)
# 1351934    both           cash   Discounted Cash Price * (See Below)
# 1351935    both           cash   Discounted Cash Price * (See Below)
# 1351936    both           cash   Discounted Cash Price * (See Below)
# 1351937    both           cash   Discounted Cash Price * (See Below)
#
#         plan_name standard_charge standard_charge_percent contracting_method
# 0            None         1992.50                    None               None  \
# 1            None         3125.00                    None               None
# 2            None          125.00                    None               None
# 3            None        12500.00                    None               None
# 4            None        12500.00                    None               None
# ...           ...             ...                     ...                ...
# 1351933      None          562.50                    None               None
# 1351934      None         8240.00                    None               None
# 1351935      None         2832.50                    None               None
# 1351936      None           70.85                    None               None
# 1351937      None           78.73                    None               None
#
#         additional_generic_notes additional_payer_specific_notes
# 0                           None                            None
# 1                           None                            None
# 2                           None                            None
# 3                           None                            None
# 4                           None                            None
# ...                          ...                             ...
# 1351933                     None                            None
# 1351934                     None                            None
# 1351935                     None                            None
# 1351936                     None                            None
# 1351937                     None                            None
#
# [1351826 rows x 30 columns]

# %%
df_out.to_csv('rate_' + ccn + '.csv', index=False)
