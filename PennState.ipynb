# %%
import pandas as pd

# %%
TARGET_COLUMNS = [
    'hospital_id',
    #'row_id',
    'line_type',
    'description',
    'rev_code',
    'local_code',
    'code',
    'ms_drg',
    'apr_drg',
    'eapg',
    'hcpcs_cpt',
    'modifiers',
    'alt_hcpcs_cpt',
    'thru',
    'apc',
    'icd',
    'ndc',
    'drug_hcpcs_multiplier',
    'drug_quantity',
    'drug_unit_of_measurement',
    'drug_type_of_measurement',
    'billing_class',
    'setting',
    'payer_category',
    'payer_name',
    'plan_name',
    'standard_charge',
    'standard_charge_percent',
    'contracting_method',
    'additional_generic_notes',
    'additional_payer_specific_notes'
]

# %%
# https://www.pennstatehealth.org/patients-visitors/billing-medical-records/understanding-cost-your-care
#ccn = "399807"
#url = "https://www.pennstatehealth.org/sites/default/files/Finance/November%202022/251854772_The%20Milton%20S.%20Hershey%20Medical%20Center_standardcharges.csv"
#ccn = "390336"
#url = "https://www.pennstatehealth.org/sites/default/files/Finance/November%202022/851608328_Penn%20State%20Health%20Hampden%20Medical%20Center_standardcharges.csv"
#ccn = "390004"
#url = "https://www.pennstatehealth.org/sites/default/files/Finance/November%202022/231512747_Penn%20State%20Health%20Holy%20Spirit%20Medical%20Center_standardcharges.csv"
ccn = "390096"
url = "https://www.pennstatehealth.org/sites/default/files/Finance/November%202022/231352211_St.%20Joseph%20Regional%20Health%20Network%20dba%20St.%20Joseph%20Medical%20Center_standardcharges.csv"
filename = url.split("/")[-1].replace("%20", " ")
ein = filename.split("_")[0]
ein = ein[:2] + "-" + ein[2:]
ein
# Out:
# '23-1352211'

# %%
import subprocess
subprocess.run(["wget", "--no-clobber", url, "-O", filename])
# Out:
# File ‘231352211_St. Joseph Regional Health Network dba St. Joseph Medical Center_standardcharges.csv’ already there; not retrieving.
# CompletedProcess(args=['wget', '--no-clobber', 'https://www.pennstatehealth.org/sites/default/files/Finance/November%202022/231352211_St.%20Joseph%20Regional%20Health%20Network%20dba%20St.%20Joseph%20Medical%20Center_standardcharges.csv', '-O', '231352211_St. Joseph Regional Health Network dba St. Joseph Medical Center_standardcharges.csv'], returncode=1)

# %%
df_in = pd.read_csv(filename, encoding='latin-1', dtype=str, low_memory=False)
df_in
# Out:
#                                                Line Type SJR CDM Code  \
# 0                                                    NaN      4407175
# 1                                                    NaN      3514916
# 2                                                    NaN      3515468
# 3                                                    NaN      3515471
# 4                                                    NaN      5169902
# ...                                                  ...          ...
# 74686                                                NaN          NaN
# 74687                                             Notes:          NaN
# 74688                                                NaN          NaN
# 74689  1. This file was created and uploaded on 06/30...          NaN
# 74690  2. If the Line Type column has a DRG withi...          NaN
#
#                             SJR CDM Description  DRG CPT / HCPCS  \
# 0              10004 Fna Bx W/o Img Gdn Ea Addl  NaN       10004
# 1             PS US Fine Needle Asp w/ Guidance  NaN       10005
# 2       US Fine Needle Aspiration Thyroid Gland  NaN       10005
# 3         US Fine Needle Aspiration w/ Guidance  NaN       10005
# 4      US* FINE NEEDLE ASPIRATION THYROID GLAND  NaN       10005
# ...                                         ...  ...         ...
# 74686                                       NaN  NaN         NaN
# 74687                                       NaN  NaN         NaN
# 74688                                       NaN  NaN         NaN
# 74689                                       NaN  NaN         NaN
# 74690                                       NaN  NaN         NaN
#
#       SJR Revenue Code Gross or Average Charge Self Pay Cash Price  \
# 0                  NaN                  56.00               16.14
# 1                  761               3,265.00              940.97
# 2                  761               3,265.00              940.97
# 3                  761               3,265.00              940.97
# 4                  761               3,265.00              940.97
# ...                ...                     ...                 ...
# 74686              NaN                     NaN                 NaN
# 74687              NaN                     NaN                 NaN
# 74688              NaN                     NaN                 NaN
# 74689              NaN                     NaN                 NaN
# 74690              NaN                     NaN                 NaN
#
#       Min Negotiated Rate Max Negotiated Rate  ... PA Health & Wellness  \
# 0                    -                 44.80   ...                 -
# 1                    -              3,036.89   ...              576.25
# 2                    -              3,036.89   ...              576.25
# 3                    -              3,036.89   ...              576.25
# 4                    -              3,036.89   ...              576.25
# ...                   ...                 ...  ...                  ...
# 74686                 NaN                 NaN  ...                  NaN
# 74687                 NaN                 NaN  ...                  NaN
# 74688                 NaN                 NaN  ...                  NaN
# 74689                 NaN                 NaN  ...                  NaN
# 74690                 NaN                 NaN  ...                  NaN
#
#         PAMA Tower Health    UHC Comm    UHC MA UHC MA CHIP   UPMC Comm  \
# 0       -          33.04       37.52       -         22.90       42.00
# 1       -       1,926.35    2,187.55    554.21    1,335.39    2,448.75
# 2       -       1,926.35    2,187.55    554.21    1,335.39    2,448.75
# 3       -       1,926.35    2,187.55    554.21    1,335.39    2,448.75
# 4       -       1,926.35    2,187.55    554.21    1,335.39    2,448.75
# ...      ...          ...         ...       ...         ...         ...
# 74686    NaN          NaN         NaN       NaN         NaN         NaN
# 74687    NaN          NaN         NaN       NaN         NaN         NaN
# 74688    NaN          NaN         NaN       NaN         NaN         NaN
# 74689    NaN          NaN         NaN       NaN         NaN         NaN
# 74690    NaN          NaN         NaN       NaN         NaN         NaN
#
#           UPMC MA UPMC MA CHIP Vibra Medicare
# 0          21.29        25.05            -
# 1       1,241.03     1,460.43         642.38
# 2       1,241.03     1,460.43         642.38
# 3       1,241.03     1,460.43         642.38
# 4       1,241.03     1,460.43         642.38
# ...           ...          ...            ...
# 74686         NaN          NaN            NaN
# 74687         NaN          NaN            NaN
# 74688         NaN          NaN            NaN
# 74689         NaN          NaN            NaN
# 74690         NaN          NaN            NaN
#
# [74691 rows x 40 columns]

# %%
df_mid = pd.DataFrame(df_in)
df_mid = df_mid.rename(columns={
    'Line Type': 'line_type',
    'HMC CDM Code': 'local_code',
    'HMC CDM Description': 'description',
    'HPD CDM Code': 'local_code',
    'HPD CDM Description': 'description',
    'HSMC CDM Code': 'local_code',
    'HSMC CDM Description': 'description',
    'SJR CDM Code': 'local_code',
    'SJR CDM Description': 'description',
    'DRG': 'ms_drg',
    'CPT / HCPCS': 'hcpcs_cpt',
    'CPT/ HCPCS': 'hcpcs_cpt',
    'HMC Revenue Code': 'rev_code',
    'HPD Revenue Code': 'rev_code',
    'HSMC Revenue Code': 'rev_code',
    'SJR Revenue Code': 'rev_code'
})

df_mid
# Out:
#                                                line_type local_code  \
# 0                                                    NaN    4407175
# 1                                                    NaN    3514916
# 2                                                    NaN    3515468
# 3                                                    NaN    3515471
# 4                                                    NaN    5169902
# ...                                                  ...        ...
# 74686                                                NaN        NaN
# 74687                                             Notes:        NaN
# 74688                                                NaN        NaN
# 74689  1. This file was created and uploaded on 06/30...        NaN
# 74690  2. If the Line Type column has a DRG withi...        NaN
#
#                                     description ms_drg hcpcs_cpt rev_code  \
# 0              10004 Fna Bx W/o Img Gdn Ea Addl    NaN     10004      NaN
# 1             PS US Fine Needle Asp w/ Guidance    NaN     10005      761
# 2       US Fine Needle Aspiration Thyroid Gland    NaN     10005      761
# 3         US Fine Needle Aspiration w/ Guidance    NaN     10005      761
# 4      US* FINE NEEDLE ASPIRATION THYROID GLAND    NaN     10005      761
# ...                                         ...    ...       ...      ...
# 74686                                       NaN    NaN       NaN      NaN
# 74687                                       NaN    NaN       NaN      NaN
# 74688                                       NaN    NaN       NaN      NaN
# 74689                                       NaN    NaN       NaN      NaN
# 74690                                       NaN    NaN       NaN      NaN
#
#       Gross or Average Charge Self Pay Cash Price Min Negotiated Rate  \
# 0                      56.00               16.14                 -
# 1                   3,265.00              940.97                 -
# 2                   3,265.00              940.97                 -
# 3                   3,265.00              940.97                 -
# 4                   3,265.00              940.97                 -
# ...                       ...                 ...                 ...
# 74686                     NaN                 NaN                 NaN
# 74687                     NaN                 NaN                 NaN
# 74688                     NaN                 NaN                 NaN
# 74689                     NaN                 NaN                 NaN
# 74690                     NaN                 NaN                 NaN
#
#       Max Negotiated Rate  ... PA Health & Wellness   PAMA Tower Health  \
# 0                  44.80   ...                 -      -          33.04
# 1               3,036.89   ...              576.25    -       1,926.35
# 2               3,036.89   ...              576.25    -       1,926.35
# 3               3,036.89   ...              576.25    -       1,926.35
# 4               3,036.89   ...              576.25    -       1,926.35
# ...                   ...  ...                  ...    ...          ...
# 74686                 NaN  ...                  NaN    NaN          NaN
# 74687                 NaN  ...                  NaN    NaN          NaN
# 74688                 NaN  ...                  NaN    NaN          NaN
# 74689                 NaN  ...                  NaN    NaN          NaN
# 74690                 NaN  ...                  NaN    NaN          NaN
#
#          UHC Comm    UHC MA UHC MA CHIP   UPMC Comm     UPMC MA UPMC MA CHIP  \
# 0          37.52       -         22.90       42.00       21.29        25.05
# 1       2,187.55    554.21    1,335.39    2,448.75    1,241.03     1,460.43
# 2       2,187.55    554.21    1,335.39    2,448.75    1,241.03     1,460.43
# 3       2,187.55    554.21    1,335.39    2,448.75    1,241.03     1,460.43
# 4       2,187.55    554.21    1,335.39    2,448.75    1,241.03     1,460.43
# ...           ...       ...         ...         ...         ...          ...
# 74686         NaN       NaN         NaN         NaN         NaN          NaN
# 74687         NaN       NaN         NaN         NaN         NaN          NaN
# 74688         NaN       NaN         NaN         NaN         NaN          NaN
# 74689         NaN       NaN         NaN         NaN         NaN          NaN
# 74690         NaN       NaN         NaN         NaN         NaN          NaN
#
#       Vibra Medicare
# 0               -
# 1            642.38
# 2            642.38
# 3            642.38
# 4            642.38
# ...              ...
# 74686            NaN
# 74687            NaN
# 74688            NaN
# 74689            NaN
# 74690            NaN
#
# [74691 rows x 40 columns]

# %%
money_columns = df_mid.columns.to_list()[6:]
remaining_columns = df_mid.columns.to_list()[:6]
df_mid = pd.melt(df_mid, id_vars=remaining_columns, 
                 var_name='payer_name', value_name='standard_charge')
df_mid
# Out:
#                                                  line_type local_code  \
# 0                                                      NaN    4407175
# 1                                                      NaN    3514916
# 2                                                      NaN    3515468
# 3                                                      NaN    3515471
# 4                                                      NaN    5169902
# ...                                                    ...        ...
# 2539489                                                NaN        NaN
# 2539490                                             Notes:        NaN
# 2539491                                                NaN        NaN
# 2539492  1. This file was created and uploaded on 06/30...        NaN
# 2539493  2. If the Line Type column has a DRG withi...        NaN
#
#                                       description ms_drg hcpcs_cpt rev_code  \
# 0                10004 Fna Bx W/o Img Gdn Ea Addl    NaN     10004      NaN
# 1               PS US Fine Needle Asp w/ Guidance    NaN     10005      761
# 2         US Fine Needle Aspiration Thyroid Gland    NaN     10005      761
# 3           US Fine Needle Aspiration w/ Guidance    NaN     10005      761
# 4        US* FINE NEEDLE ASPIRATION THYROID GLAND    NaN     10005      761
# ...                                           ...    ...       ...      ...
# 2539489                                       NaN    NaN       NaN      NaN
# 2539490                                       NaN    NaN       NaN      NaN
# 2539491                                       NaN    NaN       NaN      NaN
# 2539492                                       NaN    NaN       NaN      NaN
# 2539493                                       NaN    NaN       NaN      NaN
#
#                       payer_name standard_charge
# 0        Gross or Average Charge          56.00
# 1        Gross or Average Charge       3,265.00
# 2        Gross or Average Charge       3,265.00
# 3        Gross or Average Charge       3,265.00
# 4        Gross or Average Charge       3,265.00
# ...                          ...             ...
# 2539489           Vibra Medicare             NaN
# 2539490           Vibra Medicare             NaN
# 2539491           Vibra Medicare             NaN
# 2539492           Vibra Medicare             NaN
# 2539493           Vibra Medicare             NaN
#
# [2539494 rows x 8 columns]

# %%
df_mid = df_mid.dropna(subset=['standard_charge'])
df_mid = df_mid[df_mid['standard_charge'] != " N/A "]

df_mid
# Out:
#         line_type local_code  \
# 0             NaN    4407175
# 1             NaN    3514916
# 2             NaN    3515468
# 3             NaN    3515471
# 4             NaN    5169902
# ...           ...        ...
# 2538188       DRG        NaN
# 2538189       DRG        NaN
# 2538190       DRG        NaN
# 2538191       DRG        NaN
# 2538192       DRG        NaN
#
#                                                description ms_drg hcpcs_cpt  \
# 0                         10004 Fna Bx W/o Img Gdn Ea Addl    NaN     10004
# 1                        PS US Fine Needle Asp w/ Guidance    NaN     10005
# 2                  US Fine Needle Aspiration Thyroid Gland    NaN     10005
# 3                    US Fine Needle Aspiration w/ Guidance    NaN     10005
# 4                 US* FINE NEEDLE ASPIRATION THYROID GLAND    NaN     10005
# ...                                                    ...    ...       ...
# 2538188  EXTENSIVE O.R. PROCEDURES UNRELATED TO PRINCIP...    982       NaN
# 2538189  EXTENSIVE O.R. PROCEDURES UNRELATED TO PRINCIP...    983       NaN
# 2538190  NON-EXTENSIVE O.R. PROCEDURES UNRELATED TO PRI...    987       NaN
# 2538191  NON-EXTENSIVE O.R. PROCEDURES UNRELATED TO PRI...    988       NaN
# 2538192  NON-EXTENSIVE O.R. PROCEDURES UNRELATED TO PRI...    989       NaN
#
#         rev_code               payer_name standard_charge
# 0            NaN  Gross or Average Charge          56.00
# 1            761  Gross or Average Charge       3,265.00
# 2            761  Gross or Average Charge       3,265.00
# 3            761  Gross or Average Charge       3,265.00
# 4            761  Gross or Average Charge       3,265.00
# ...          ...                      ...             ...
# 2538188      NaN           Vibra Medicare      18,775.22
# 2538189      NaN           Vibra Medicare      12,416.05
# 2538190      NaN           Vibra Medicare      24,091.67
# 2538191      NaN           Vibra Medicare      12,805.10
# 2538192      NaN           Vibra Medicare       8,614.07
#
# [1385660 rows x 8 columns]

# %%
df_mid.loc[df_mid['line_type'] == 'DRG', 'setting'] = 'inpatient'
df_mid.loc[df_mid['hcpcs_cpt'].notnull(), 'setting'] = 'outpatient'
df_mid
# Out:
#         line_type local_code  \
# 0             NaN    4407175
# 1             NaN    3514916
# 2             NaN    3515468
# 3             NaN    3515471
# 4             NaN    5169902
# ...           ...        ...
# 2538188       DRG        NaN
# 2538189       DRG        NaN
# 2538190       DRG        NaN
# 2538191       DRG        NaN
# 2538192       DRG        NaN
#
#                                                description ms_drg hcpcs_cpt  \
# 0                         10004 Fna Bx W/o Img Gdn Ea Addl    NaN     10004
# 1                        PS US Fine Needle Asp w/ Guidance    NaN     10005
# 2                  US Fine Needle Aspiration Thyroid Gland    NaN     10005
# 3                    US Fine Needle Aspiration w/ Guidance    NaN     10005
# 4                 US* FINE NEEDLE ASPIRATION THYROID GLAND    NaN     10005
# ...                                                    ...    ...       ...
# 2538188  EXTENSIVE O.R. PROCEDURES UNRELATED TO PRINCIP...    982       NaN
# 2538189  EXTENSIVE O.R. PROCEDURES UNRELATED TO PRINCIP...    983       NaN
# 2538190  NON-EXTENSIVE O.R. PROCEDURES UNRELATED TO PRI...    987       NaN
# 2538191  NON-EXTENSIVE O.R. PROCEDURES UNRELATED TO PRI...    988       NaN
# 2538192  NON-EXTENSIVE O.R. PROCEDURES UNRELATED TO PRI...    989       NaN
#
#         rev_code               payer_name standard_charge     setting
# 0            NaN  Gross or Average Charge          56.00   outpatient
# 1            761  Gross or Average Charge       3,265.00   outpatient
# 2            761  Gross or Average Charge       3,265.00   outpatient
# 3            761  Gross or Average Charge       3,265.00   outpatient
# 4            761  Gross or Average Charge       3,265.00   outpatient
# ...          ...                      ...             ...         ...
# 2538188      NaN           Vibra Medicare      18,775.22    inpatient
# 2538189      NaN           Vibra Medicare      12,416.05    inpatient
# 2538190      NaN           Vibra Medicare      24,091.67    inpatient
# 2538191      NaN           Vibra Medicare      12,805.10    inpatient
# 2538192      NaN           Vibra Medicare       8,614.07    inpatient
#
# [1385660 rows x 9 columns]

# %%
def payer_category_from_payer_orig(payer_orig):
    if payer_orig == "Gross or Average Charge":
        return 'gross'
    elif payer_orig == "Self Pay Cash Price":
        return 'cash'
    elif payer_orig == "Min Negotiated Rate":
        return 'min'
    elif payer_orig == "Max Negotiated Rate":
        return 'max'
    
    return 'payer'

df_mid['payer_category'] = df_mid['payer_name'].apply(payer_category_from_payer_orig)
df_mid
# Out:
#         line_type local_code  \
# 0             NaN    4407175
# 1             NaN    3514916
# 2             NaN    3515468
# 3             NaN    3515471
# 4             NaN    5169902
# ...           ...        ...
# 2538188       DRG        NaN
# 2538189       DRG        NaN
# 2538190       DRG        NaN
# 2538191       DRG        NaN
# 2538192       DRG        NaN
#
#                                                description ms_drg hcpcs_cpt  \
# 0                         10004 Fna Bx W/o Img Gdn Ea Addl    NaN     10004
# 1                        PS US Fine Needle Asp w/ Guidance    NaN     10005
# 2                  US Fine Needle Aspiration Thyroid Gland    NaN     10005
# 3                    US Fine Needle Aspiration w/ Guidance    NaN     10005
# 4                 US* FINE NEEDLE ASPIRATION THYROID GLAND    NaN     10005
# ...                                                    ...    ...       ...
# 2538188  EXTENSIVE O.R. PROCEDURES UNRELATED TO PRINCIP...    982       NaN
# 2538189  EXTENSIVE O.R. PROCEDURES UNRELATED TO PRINCIP...    983       NaN
# 2538190  NON-EXTENSIVE O.R. PROCEDURES UNRELATED TO PRI...    987       NaN
# 2538191  NON-EXTENSIVE O.R. PROCEDURES UNRELATED TO PRI...    988       NaN
# 2538192  NON-EXTENSIVE O.R. PROCEDURES UNRELATED TO PRI...    989       NaN
#
#         rev_code               payer_name standard_charge     setting  \
# 0            NaN  Gross or Average Charge          56.00   outpatient
# 1            761  Gross or Average Charge       3,265.00   outpatient
# 2            761  Gross or Average Charge       3,265.00   outpatient
# 3            761  Gross or Average Charge       3,265.00   outpatient
# 4            761  Gross or Average Charge       3,265.00   outpatient
# ...          ...                      ...             ...         ...
# 2538188      NaN           Vibra Medicare      18,775.22    inpatient
# 2538189      NaN           Vibra Medicare      12,416.05    inpatient
# 2538190      NaN           Vibra Medicare      24,091.67    inpatient
# 2538191      NaN           Vibra Medicare      12,805.10    inpatient
# 2538192      NaN           Vibra Medicare       8,614.07    inpatient
#
#         payer_category
# 0                gross
# 1                gross
# 2                gross
# 3                gross
# 4                gross
# ...                ...
# 2538188          payer
# 2538189          payer
# 2538190          payer
# 2538191          payer
# 2538192          payer
#
# [1385660 rows x 10 columns]

# %%
def pad_drg_if_needed(drg):
    if drg is None:
        return 
    
    drg = str(drg).split(".")[0]
    if drg == "nan":
        return None
    
    if len(drg) == 1:
        return "00" + drg
    elif len(drg) == 2:
        return "0" + drg

    return drg

df_mid['ms_drg'] = df_mid['ms_drg'].apply(pad_drg_if_needed)
df_mid['ms_drg']
# Out:
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None
#            ...
# 2538188     982
# 2538189     983
# 2538190     987
# 2538191     988
# 2538192     989
# Name: ms_drg, Length: 1385660, dtype: object

# %%
df_mid['code'] = None
df_mid.loc[df_mid['line_type'] == 'DRG', 'code'] = df_mid[df_mid['line_type'] == 'DRG']['ms_drg']
df_mid.loc[df_mid['hcpcs_cpt'].notnull(), 'code'] = df_mid[df_mid['hcpcs_cpt'].notnull()]['hcpcs_cpt']
df_mid.loc[df_mid['hcpcs_cpt'].notnull(), 'hcpcs_cpt'] = df_mid[df_mid['hcpcs_cpt'].notnull()]['hcpcs_cpt'].str.upper()

df_mid
# Out:
#         line_type local_code  \
# 0             NaN    4407175
# 1             NaN    3514916
# 2             NaN    3515468
# 3             NaN    3515471
# 4             NaN    5169902
# ...           ...        ...
# 2538188       DRG        NaN
# 2538189       DRG        NaN
# 2538190       DRG        NaN
# 2538191       DRG        NaN
# 2538192       DRG        NaN
#
#                                                description ms_drg hcpcs_cpt  \
# 0                         10004 Fna Bx W/o Img Gdn Ea Addl   None     10004
# 1                        PS US Fine Needle Asp w/ Guidance   None     10005
# 2                  US Fine Needle Aspiration Thyroid Gland   None     10005
# 3                    US Fine Needle Aspiration w/ Guidance   None     10005
# 4                 US* FINE NEEDLE ASPIRATION THYROID GLAND   None     10005
# ...                                                    ...    ...       ...
# 2538188  EXTENSIVE O.R. PROCEDURES UNRELATED TO PRINCIP...    982       NaN
# 2538189  EXTENSIVE O.R. PROCEDURES UNRELATED TO PRINCIP...    983       NaN
# 2538190  NON-EXTENSIVE O.R. PROCEDURES UNRELATED TO PRI...    987       NaN
# 2538191  NON-EXTENSIVE O.R. PROCEDURES UNRELATED TO PRI...    988       NaN
# 2538192  NON-EXTENSIVE O.R. PROCEDURES UNRELATED TO PRI...    989       NaN
#
#         rev_code               payer_name standard_charge     setting  \
# 0            NaN  Gross or Average Charge          56.00   outpatient
# 1            761  Gross or Average Charge       3,265.00   outpatient
# 2            761  Gross or Average Charge       3,265.00   outpatient
# 3            761  Gross or Average Charge       3,265.00   outpatient
# 4            761  Gross or Average Charge       3,265.00   outpatient
# ...          ...                      ...             ...         ...
# 2538188      NaN           Vibra Medicare      18,775.22    inpatient
# 2538189      NaN           Vibra Medicare      12,416.05    inpatient
# 2538190      NaN           Vibra Medicare      24,091.67    inpatient
# 2538191      NaN           Vibra Medicare      12,805.10    inpatient
# 2538192      NaN           Vibra Medicare       8,614.07    inpatient
#
#         payer_category   code
# 0                gross  10004
# 1                gross  10005
# 2                gross  10005
# 3                gross  10005
# 4                gross  10005
# ...                ...    ...
# 2538188          payer    982
# 2538189          payer    983
# 2538190          payer    987
# 2538191          payer    988
# 2538192          payer    989
#
# [1385660 rows x 11 columns]

# %%
df_mid['apc'] = None
df_mid['apr_drg'] = None
df_mid['eapg'] = None
df_mid['alt_hcpcs_cpt'] = None
df_mid['thru'] = None
df_mid['icd'] = None
df_mid['drug_hcpcs_multiplier'] = None
df_mid['drug_quantity'] = None
df_mid['drug_unit_of_measurement'] = None
df_mid['drug_type_of_measurement'] = None
df_mid['billing_class'] = None
df_mid['plan_name'] = None
df_mid['modifiers'] = None
df_mid['standard_charge_percent'] = None
df_mid['contracting_method'] = None
df_mid['ndc'] = None
df_mid['additional_generic_notes'] = None
df_mid['additional_payer_specific_notes'] = None
df_mid['hospital_id'] = ccn

def pad_rev_code_if_needed(rev_code):
    if type(rev_code) == str and rev_code != 'na':
        if len(rev_code) == 3:
            return '0' + rev_code
        elif len(rev_code) == 2:
            return '00' + rev_code
        elif len(rev_code) == 1:
            return '000' + rev_code

    return rev_code

df_mid['rev_code'] = df_mid['rev_code'].apply(pad_rev_code_if_needed)
df_mid.loc[df_mid['rev_code'] == '0278<and>0278', 'rev_code'] = '0278'
df_mid
# Out:
#         line_type local_code  \
# 0             NaN    4407175
# 1             NaN    3514916
# 2             NaN    3515468
# 3             NaN    3515471
# 4             NaN    5169902
# ...           ...        ...
# 2538188       DRG        NaN
# 2538189       DRG        NaN
# 2538190       DRG        NaN
# 2538191       DRG        NaN
# 2538192       DRG        NaN
#
#                                                description ms_drg hcpcs_cpt  \
# 0                         10004 Fna Bx W/o Img Gdn Ea Addl   None     10004
# 1                        PS US Fine Needle Asp w/ Guidance   None     10005
# 2                  US Fine Needle Aspiration Thyroid Gland   None     10005
# 3                    US Fine Needle Aspiration w/ Guidance   None     10005
# 4                 US* FINE NEEDLE ASPIRATION THYROID GLAND   None     10005
# ...                                                    ...    ...       ...
# 2538188  EXTENSIVE O.R. PROCEDURES UNRELATED TO PRINCIP...    982       NaN
# 2538189  EXTENSIVE O.R. PROCEDURES UNRELATED TO PRINCIP...    983       NaN
# 2538190  NON-EXTENSIVE O.R. PROCEDURES UNRELATED TO PRI...    987       NaN
# 2538191  NON-EXTENSIVE O.R. PROCEDURES UNRELATED TO PRI...    988       NaN
# 2538192  NON-EXTENSIVE O.R. PROCEDURES UNRELATED TO PRI...    989       NaN
#
#         rev_code               payer_name standard_charge     setting  \
# 0            NaN  Gross or Average Charge          56.00   outpatient
# 1           0761  Gross or Average Charge       3,265.00   outpatient
# 2           0761  Gross or Average Charge       3,265.00   outpatient
# 3           0761  Gross or Average Charge       3,265.00   outpatient
# 4           0761  Gross or Average Charge       3,265.00   outpatient
# ...          ...                      ...             ...         ...
# 2538188      NaN           Vibra Medicare      18,775.22    inpatient
# 2538189      NaN           Vibra Medicare      12,416.05    inpatient
# 2538190      NaN           Vibra Medicare      24,091.67    inpatient
# 2538191      NaN           Vibra Medicare      12,805.10    inpatient
# 2538192      NaN           Vibra Medicare       8,614.07    inpatient
#
#         payer_category  ... drug_type_of_measurement billing_class plan_name  \
# 0                gross  ...                     None          None      None
# 1                gross  ...                     None          None      None
# 2                gross  ...                     None          None      None
# 3                gross  ...                     None          None      None
# 4                gross  ...                     None          None      None
# ...                ...  ...                      ...           ...       ...
# 2538188          payer  ...                     None          None      None
# 2538189          payer  ...                     None          None      None
# 2538190          payer  ...                     None          None      None
# 2538191          payer  ...                     None          None      None
# 2538192          payer  ...                     None          None      None
#
#         modifiers standard_charge_percent contracting_method   ndc  \
# 0            None                    None               None  None
# 1            None                    None               None  None
# 2            None                    None               None  None
# 3            None                    None               None  None
# 4            None                    None               None  None
# ...           ...                     ...                ...   ...
# 2538188      None                    None               None  None
# 2538189      None                    None               None  None
# 2538190      None                    None               None  None
# 2538191      None                    None               None  None
# 2538192      None                    None               None  None
#
#         additional_generic_notes additional_payer_specific_notes hospital_id
# 0                           None                            None      390096
# 1                           None                            None      390096
# 2                           None                            None      390096
# 3                           None                            None      390096
# 4                           None                            None      390096
# ...                          ...                             ...         ...
# 2538188                     None                            None      390096
# 2538189                     None                            None      390096
# 2538190                     None                            None      390096
# 2538191                     None                            None      390096
# 2538192                     None                            None      390096
#
# [1385660 rows x 30 columns]

# %%
df_out = pd.DataFrame(df_mid[TARGET_COLUMNS])
df_out = df_out.dropna(subset=['standard_charge'], axis=0)
df_out['standard_charge'] = df_out['standard_charge'].astype(str)
df_out['standard_charge'] = df_out['standard_charge'].apply(lambda rate: rate.replace(",", "").replace("$", "").strip())
df_out = df_out[df_out['standard_charge'] != 'No Current Volume']
df_out = df_out[df_out['standard_charge'] != '-']
df_out
# Out:
#         hospital_id line_type  \
# 0            390096       NaN
# 1            390096       NaN
# 2            390096       NaN
# 3            390096       NaN
# 4            390096       NaN
# ...             ...       ...
# 2538188      390096       DRG
# 2538189      390096       DRG
# 2538190      390096       DRG
# 2538191      390096       DRG
# 2538192      390096       DRG
#
#                                                description rev_code  \
# 0                         10004 Fna Bx W/o Img Gdn Ea Addl      NaN
# 1                        PS US Fine Needle Asp w/ Guidance     0761
# 2                  US Fine Needle Aspiration Thyroid Gland     0761
# 3                    US Fine Needle Aspiration w/ Guidance     0761
# 4                 US* FINE NEEDLE ASPIRATION THYROID GLAND     0761
# ...                                                    ...      ...
# 2538188  EXTENSIVE O.R. PROCEDURES UNRELATED TO PRINCIP...      NaN
# 2538189  EXTENSIVE O.R. PROCEDURES UNRELATED TO PRINCIP...      NaN
# 2538190  NON-EXTENSIVE O.R. PROCEDURES UNRELATED TO PRI...      NaN
# 2538191  NON-EXTENSIVE O.R. PROCEDURES UNRELATED TO PRI...      NaN
# 2538192  NON-EXTENSIVE O.R. PROCEDURES UNRELATED TO PRI...      NaN
#
#         local_code   code ms_drg apr_drg  eapg hcpcs_cpt  ... billing_class  \
# 0          4407175  10004   None    None  None     10004  ...          None
# 1          3514916  10005   None    None  None     10005  ...          None
# 2          3515468  10005   None    None  None     10005  ...          None
# 3          3515471  10005   None    None  None     10005  ...          None
# 4          5169902  10005   None    None  None     10005  ...          None
# ...            ...    ...    ...     ...   ...       ...  ...           ...
# 2538188        NaN    982    982    None  None       NaN  ...          None
# 2538189        NaN    983    983    None  None       NaN  ...          None
# 2538190        NaN    987    987    None  None       NaN  ...          None
# 2538191        NaN    988    988    None  None       NaN  ...          None
# 2538192        NaN    989    989    None  None       NaN  ...          None
#
#             setting payer_category               payer_name plan_name  \
# 0        outpatient          gross  Gross or Average Charge      None
# 1        outpatient          gross  Gross or Average Charge      None
# 2        outpatient          gross  Gross or Average Charge      None
# 3        outpatient          gross  Gross or Average Charge      None
# 4        outpatient          gross  Gross or Average Charge      None
# ...             ...            ...                      ...       ...
# 2538188   inpatient          payer           Vibra Medicare      None
# 2538189   inpatient          payer           Vibra Medicare      None
# 2538190   inpatient          payer           Vibra Medicare      None
# 2538191   inpatient          payer           Vibra Medicare      None
# 2538192   inpatient          payer           Vibra Medicare      None
#
#         standard_charge standard_charge_percent contracting_method  \
# 0                 56.00                    None               None
# 1               3265.00                    None               None
# 2               3265.00                    None               None
# 3               3265.00                    None               None
# 4               3265.00                    None               None
# ...                 ...                     ...                ...
# 2538188        18775.22                    None               None
# 2538189        12416.05                    None               None
# 2538190        24091.67                    None               None
# 2538191        12805.10                    None               None
# 2538192         8614.07                    None               None
#
#         additional_generic_notes additional_payer_specific_notes
# 0                           None                            None
# 1                           None                            None
# 2                           None                            None
# 3                           None                            None
# 4                           None                            None
# ...                          ...                             ...
# 2538188                     None                            None
# 2538189                     None                            None
# 2538190                     None                            None
# 2538191                     None                            None
# 2538192                     None                            None
#
# [819417 rows x 30 columns]

# %%
df_out.to_csv("rate_" + ccn + ".csv", index=False)

# %%
df_out[df_out['code'].isnull()].shape
# Out:
# (67692, 30)
