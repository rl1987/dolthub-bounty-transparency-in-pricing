# %%
import pandas as pd

# %%
TARGET_COLUMNS = [ 
    'hospital_ccn',
    'hospital_ein',
    'code_type',
    'internal_code',
    'description',
    'code_orig',
    'code_prefix',
    'code',
    'modifier',
    'ndc',
    'ndc_num_hcpcs_doses',
    'ndc_quantity_desc',
    'apc',
    'rev_code',
    'rev_desc',
    'billing_class',
    'patient_class',
    'payer_category',
    'payer_orig',
    'payer_name',
    'plan_orig',
    'plan_name',
    'plan_id',
    'plan_type',
    'rate',
    'rate_method',
    'rate_desc',
    'filename',
    'file_last_updated',
    'url',
    'permalink'
]

# %%
ccn = "460051"
url = "https://content.steward.org/sites/default/files/2022-09/820588653_JordanValleyMedCenter_standardcharges_0.csv"
filename = url.split("/")[-1]
ein = filename.split("_")[0]
ein = ein[:2] + "-" + ein[2:]

# %%
import subprocess
subprocess.run(["wget", "--no-clobber", url, "-O", filename])
# Out:
# File ‘820588653_JordanValleyMedCenter_standardcharges_0.csv’ already there; not retrieving.
# CompletedProcess(args=['wget', '--no-clobber', 'https://content.steward.org/sites/default/files/2022-09/820588653_JordanValleyMedCenter_standardcharges_0.csv', '-O', '820588653_JordanValleyMedCenter_standardcharges_0.csv'], returncode=1)

# %%
df_in = pd.read_csv(filename, dtype={'REV CODE': str})
df_in
# Out:
#       LINE TYPE CHARGE CODE/PACKAGE  \
# 0           CDM          1142505110
# 1           CDM          1140505110
# 2           CDM          1140530110
# 3           CDM          1142510110
# 4           CDM          1150500110
# ...         ...                 ...
# 13161       DRG          MS-DRG 975
# 13162       DRG          MS-DRG 981
# 13163       DRG          MS-DRG 982
# 13164       DRG          MS-DRG 987
# 13165       DRG          MS-DRG 988
#
#                                       CHARGE DESCRIPTION  DRG  CPT  MODIFIERS  \
# 0                                          R&B - PRIVATE  NaN  NaN        NaN
# 1                                          R&B - PRIVATE       NaN        NaN
# 2                                          R&B - PRIVATE  NaN  NaN        NaN
# 3                                          R&B - PRIVATE  NaN  NaN        NaN
# 4                                          R&B - PRIVATE  NaN             NaN
# ...                                                  ...  ...  ...        ...
# 13161           HIV WITH MAJOR RELATED CONDITION WITH CC  975  NaN        NaN
# 13162  EXTENSIVE O.R. PROCEDURES UNRELATED TO PRINCIP...  981  NaN        NaN
# 13163  EXTENSIVE O.R. PROCEDURES UNRELATED TO PRINCIP...  982  NaN        NaN
# 13164  NON-EXTENSIVE O.R. PROCEDURES UNRELATED TO PRI...  987  NaN        NaN
# 13165  NON-EXTENSIVE O.R. PROCEDURES UNRELATED TO PRI...  988  NaN        NaN
#
#       REV CODE  NDC  GROSS CHARGES  SELF PAY CASH PRICE  ...  \
# 0          110  NaN        1681.84               420.46  ...
# 1          110  NaN        1681.84               420.46  ...
# 2          110  NaN        1681.84               420.46  ...
# 3          110  NaN        1681.84               420.46  ...
# 4          110  NaN        1681.84               420.46  ...
# ...        ...  ...            ...                  ...  ...
# 13161      NaN  NaN       34332.07              8583.02  ...
# 13162      NaN  NaN      113342.20             28335.55  ...
# 13163      NaN  NaN       13015.86              3253.96  ...
# 13164      NaN  NaN       81240.86             20310.21  ...
# 13165      NaN  NaN       37159.77              9289.94  ...
#
#        PEHP Summit Exclusive Network IP Rate  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 13161                               15229.22
# 13162                               54389.91
# 13163                               13015.86
# 13164                               36000.31
# 13165                               19649.27
#
#        PEHP Summit Exclusive Network OP Rate  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 13161                                    NaN
# 13162                                    NaN
# 13163                                    NaN
# 13164                                    NaN
# 13165                                    NaN
#
#        PEHP Summit Public Employees IP Rate  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 13161                              16866.31
# 13162                              60236.66
# 13163                              13015.86
# 13164                              39870.23
# 13165                              21761.50
#
#        PEHP Summit Public Employees OP Rate  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 13161                                   NaN
# 13162                                   NaN
# 13163                                   NaN
# 13164                                   NaN
# 13165                                   NaN
#
#        Select Health Emergency Services IP Rate  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 13161                                  34332.07
# 13162                                 113342.20
# 13163                                  13015.86
# 13164                                  81240.86
# 13165                                  37159.77
#
#        Select Health Emergency Services OP Rate  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 13161                                       NaN
# 13162                                       NaN
# 13163                                       NaN
# 13164                                       NaN
# 13165                                       NaN
#
#        UHC Medicare Advantage IP Rate  UHC Medicare Advantage OP Rate  \
# 0                                 NaN                             NaN
# 1                                 NaN                             NaN
# 2                                 NaN                             NaN
# 3                                 NaN                             NaN
# 4                                 NaN                             NaN
# ...                               ...                             ...
# 13161                        10595.64                             NaN
# 13162                        31675.36                             NaN
# 13163                        13015.86                             NaN
# 13164                        23153.42                             NaN
# 13165                        13138.84                             NaN
#
#        UHC Options PPO IP Rate  UHC Options PPO OP Rate
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
# ...                        ...                      ...
# 13161                 16593.76                      NaN
# 13162                 58937.94                      NaN
# 13163                 13015.86                      NaN
# 13164                 42319.22                      NaN
# 13165                 21803.72                      NaN
#
# [13166 rows x 36 columns]

# %%
df_mid = pd.DataFrame(df_in)
df_mid = df_mid.rename(columns={
    'LINE TYPE': 'code_type',
    'CHARGE CODE/PACKAGE': 'code_orig',
    'CHARGE DESCRIPTION': 'description',
    'DRG': 'drg',
    'CPT': 'cpt',
    'MODIFIERS': 'modifier',
    'REV CODE': 'rev_code',
    'NDC': 'ndc',
})

df_mid
# Out:
#       code_type   code_orig  \
# 0           CDM  1142505110
# 1           CDM  1140505110
# 2           CDM  1140530110
# 3           CDM  1142510110
# 4           CDM  1150500110
# ...         ...         ...
# 13161       DRG  MS-DRG 975
# 13162       DRG  MS-DRG 981
# 13163       DRG  MS-DRG 982
# 13164       DRG  MS-DRG 987
# 13165       DRG  MS-DRG 988
#
#                                              description  drg  cpt  modifier  \
# 0                                          R&B - PRIVATE  NaN  NaN       NaN
# 1                                          R&B - PRIVATE       NaN       NaN
# 2                                          R&B - PRIVATE  NaN  NaN       NaN
# 3                                          R&B - PRIVATE  NaN  NaN       NaN
# 4                                          R&B - PRIVATE  NaN            NaN
# ...                                                  ...  ...  ...       ...
# 13161           HIV WITH MAJOR RELATED CONDITION WITH CC  975  NaN       NaN
# 13162  EXTENSIVE O.R. PROCEDURES UNRELATED TO PRINCIP...  981  NaN       NaN
# 13163  EXTENSIVE O.R. PROCEDURES UNRELATED TO PRINCIP...  982  NaN       NaN
# 13164  NON-EXTENSIVE O.R. PROCEDURES UNRELATED TO PRI...  987  NaN       NaN
# 13165  NON-EXTENSIVE O.R. PROCEDURES UNRELATED TO PRI...  988  NaN       NaN
#
#       rev_code  ndc  GROSS CHARGES  SELF PAY CASH PRICE  ...  \
# 0          110  NaN        1681.84               420.46  ...
# 1          110  NaN        1681.84               420.46  ...
# 2          110  NaN        1681.84               420.46  ...
# 3          110  NaN        1681.84               420.46  ...
# 4          110  NaN        1681.84               420.46  ...
# ...        ...  ...            ...                  ...  ...
# 13161      NaN  NaN       34332.07              8583.02  ...
# 13162      NaN  NaN      113342.20             28335.55  ...
# 13163      NaN  NaN       13015.86              3253.96  ...
# 13164      NaN  NaN       81240.86             20310.21  ...
# 13165      NaN  NaN       37159.77              9289.94  ...
#
#        PEHP Summit Exclusive Network IP Rate  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 13161                               15229.22
# 13162                               54389.91
# 13163                               13015.86
# 13164                               36000.31
# 13165                               19649.27
#
#        PEHP Summit Exclusive Network OP Rate  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 13161                                    NaN
# 13162                                    NaN
# 13163                                    NaN
# 13164                                    NaN
# 13165                                    NaN
#
#        PEHP Summit Public Employees IP Rate  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 13161                              16866.31
# 13162                              60236.66
# 13163                              13015.86
# 13164                              39870.23
# 13165                              21761.50
#
#        PEHP Summit Public Employees OP Rate  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 13161                                   NaN
# 13162                                   NaN
# 13163                                   NaN
# 13164                                   NaN
# 13165                                   NaN
#
#        Select Health Emergency Services IP Rate  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 13161                                  34332.07
# 13162                                 113342.20
# 13163                                  13015.86
# 13164                                  81240.86
# 13165                                  37159.77
#
#        Select Health Emergency Services OP Rate  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 13161                                       NaN
# 13162                                       NaN
# 13163                                       NaN
# 13164                                       NaN
# 13165                                       NaN
#
#        UHC Medicare Advantage IP Rate  UHC Medicare Advantage OP Rate  \
# 0                                 NaN                             NaN
# 1                                 NaN                             NaN
# 2                                 NaN                             NaN
# 3                                 NaN                             NaN
# 4                                 NaN                             NaN
# ...                               ...                             ...
# 13161                        10595.64                             NaN
# 13162                        31675.36                             NaN
# 13163                        13015.86                             NaN
# 13164                        23153.42                             NaN
# 13165                        13138.84                             NaN
#
#        UHC Options PPO IP Rate  UHC Options PPO OP Rate
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
# ...                        ...                      ...
# 13161                 16593.76                      NaN
# 13162                 58937.94                      NaN
# 13163                 13015.86                      NaN
# 13164                 42319.22                      NaN
# 13165                 21803.72                      NaN
#
# [13166 rows x 36 columns]

# %%
money_columns = df_mid.columns.to_list()[8:]
remaining_columns = df_mid.columns.to_list()[:8]
df_mid = pd.melt(df_mid, id_vars=remaining_columns, var_name='payer_orig', value_name='rate')
df_mid
# Out:
#        code_type   code_orig  \
# 0            CDM  1142505110
# 1            CDM  1140505110
# 2            CDM  1140530110
# 3            CDM  1142510110
# 4            CDM  1150500110
# ...          ...         ...
# 368643       DRG  MS-DRG 975
# 368644       DRG  MS-DRG 981
# 368645       DRG  MS-DRG 982
# 368646       DRG  MS-DRG 987
# 368647       DRG  MS-DRG 988
#
#                                               description  drg  cpt  modifier  \
# 0                                           R&B - PRIVATE  NaN  NaN       NaN
# 1                                           R&B - PRIVATE       NaN       NaN
# 2                                           R&B - PRIVATE  NaN  NaN       NaN
# 3                                           R&B - PRIVATE  NaN  NaN       NaN
# 4                                           R&B - PRIVATE  NaN            NaN
# ...                                                   ...  ...  ...       ...
# 368643           HIV WITH MAJOR RELATED CONDITION WITH CC  975  NaN       NaN
# 368644  EXTENSIVE O.R. PROCEDURES UNRELATED TO PRINCIP...  981  NaN       NaN
# 368645  EXTENSIVE O.R. PROCEDURES UNRELATED TO PRINCIP...  982  NaN       NaN
# 368646  NON-EXTENSIVE O.R. PROCEDURES UNRELATED TO PRI...  987  NaN       NaN
# 368647  NON-EXTENSIVE O.R. PROCEDURES UNRELATED TO PRI...  988  NaN       NaN
#
#        rev_code  ndc               payer_orig     rate
# 0           110  NaN            GROSS CHARGES  1681.84
# 1           110  NaN            GROSS CHARGES  1681.84
# 2           110  NaN            GROSS CHARGES  1681.84
# 3           110  NaN            GROSS CHARGES  1681.84
# 4           110  NaN            GROSS CHARGES  1681.84
# ...         ...  ...                      ...      ...
# 368643      NaN  NaN  UHC Options PPO OP Rate      NaN
# 368644      NaN  NaN  UHC Options PPO OP Rate      NaN
# 368645      NaN  NaN  UHC Options PPO OP Rate      NaN
# 368646      NaN  NaN  UHC Options PPO OP Rate      NaN
# 368647      NaN  NaN  UHC Options PPO OP Rate      NaN
#
# [368648 rows x 10 columns]

# %%
df_mid['rev_code'] = df_mid['rev_code'].fillna('na')

def pad_rev_code_if_needed(rev_code):
    if type(rev_code) == str and rev_code != 'na':
        if len(rev_code) == 3:
            return '0' + rev_code
        elif len(rev_code) == 2:
            return '00' + rev_code
        elif len(rev_code) == 1:
            return '000' + rev_code

    return rev_code

df_mid['rev_code'] = df_mid['rev_code'].apply(pad_rev_code_if_needed)
df_mid
# Out:
#        code_type   code_orig  \
# 0            CDM  1142505110
# 1            CDM  1140505110
# 2            CDM  1140530110
# 3            CDM  1142510110
# 4            CDM  1150500110
# ...          ...         ...
# 368643       DRG  MS-DRG 975
# 368644       DRG  MS-DRG 981
# 368645       DRG  MS-DRG 982
# 368646       DRG  MS-DRG 987
# 368647       DRG  MS-DRG 988
#
#                                               description  drg  cpt  modifier  \
# 0                                           R&B - PRIVATE  NaN  NaN       NaN
# 1                                           R&B - PRIVATE       NaN       NaN
# 2                                           R&B - PRIVATE  NaN  NaN       NaN
# 3                                           R&B - PRIVATE  NaN  NaN       NaN
# 4                                           R&B - PRIVATE  NaN            NaN
# ...                                                   ...  ...  ...       ...
# 368643           HIV WITH MAJOR RELATED CONDITION WITH CC  975  NaN       NaN
# 368644  EXTENSIVE O.R. PROCEDURES UNRELATED TO PRINCIP...  981  NaN       NaN
# 368645  EXTENSIVE O.R. PROCEDURES UNRELATED TO PRINCIP...  982  NaN       NaN
# 368646  NON-EXTENSIVE O.R. PROCEDURES UNRELATED TO PRI...  987  NaN       NaN
# 368647  NON-EXTENSIVE O.R. PROCEDURES UNRELATED TO PRI...  988  NaN       NaN
#
#        rev_code  ndc               payer_orig     rate
# 0          0110  NaN            GROSS CHARGES  1681.84
# 1          0110  NaN            GROSS CHARGES  1681.84
# 2          0110  NaN            GROSS CHARGES  1681.84
# 3          0110  NaN            GROSS CHARGES  1681.84
# 4          0110  NaN            GROSS CHARGES  1681.84
# ...         ...  ...                      ...      ...
# 368643       na  NaN  UHC Options PPO OP Rate      NaN
# 368644       na  NaN  UHC Options PPO OP Rate      NaN
# 368645       na  NaN  UHC Options PPO OP Rate      NaN
# 368646       na  NaN  UHC Options PPO OP Rate      NaN
# 368647       na  NaN  UHC Options PPO OP Rate      NaN
#
# [368648 rows x 10 columns]

# %%
df_mid['code_type'] = df_mid['code_type'].str.lower()
df_mid
# Out:
#        code_type   code_orig  \
# 0            cdm  1142505110
# 1            cdm  1140505110
# 2            cdm  1140530110
# 3            cdm  1142510110
# 4            cdm  1150500110
# ...          ...         ...
# 368643       drg  MS-DRG 975
# 368644       drg  MS-DRG 981
# 368645       drg  MS-DRG 982
# 368646       drg  MS-DRG 987
# 368647       drg  MS-DRG 988
#
#                                               description  drg  cpt  modifier  \
# 0                                           R&B - PRIVATE  NaN  NaN       NaN
# 1                                           R&B - PRIVATE       NaN       NaN
# 2                                           R&B - PRIVATE  NaN  NaN       NaN
# 3                                           R&B - PRIVATE  NaN  NaN       NaN
# 4                                           R&B - PRIVATE  NaN            NaN
# ...                                                   ...  ...  ...       ...
# 368643           HIV WITH MAJOR RELATED CONDITION WITH CC  975  NaN       NaN
# 368644  EXTENSIVE O.R. PROCEDURES UNRELATED TO PRINCIP...  981  NaN       NaN
# 368645  EXTENSIVE O.R. PROCEDURES UNRELATED TO PRINCIP...  982  NaN       NaN
# 368646  NON-EXTENSIVE O.R. PROCEDURES UNRELATED TO PRI...  987  NaN       NaN
# 368647  NON-EXTENSIVE O.R. PROCEDURES UNRELATED TO PRI...  988  NaN       NaN
#
#        rev_code  ndc               payer_orig     rate
# 0          0110  NaN            GROSS CHARGES  1681.84
# 1          0110  NaN            GROSS CHARGES  1681.84
# 2          0110  NaN            GROSS CHARGES  1681.84
# 3          0110  NaN            GROSS CHARGES  1681.84
# 4          0110  NaN            GROSS CHARGES  1681.84
# ...         ...  ...                      ...      ...
# 368643       na  NaN  UHC Options PPO OP Rate      NaN
# 368644       na  NaN  UHC Options PPO OP Rate      NaN
# 368645       na  NaN  UHC Options PPO OP Rate      NaN
# 368646       na  NaN  UHC Options PPO OP Rate      NaN
# 368647       na  NaN  UHC Options PPO OP Rate      NaN
#
# [368648 rows x 10 columns]

# %%
df_mid_drg = pd.DataFrame(df_mid.loc[df_mid['code_type'] == 'drg'])
df_mid_drg
# Out:
#        code_type   code_orig  \
# 12851        drg  MS-DRG 064
# 12852        drg  MS-DRG 054
# 12853        drg  MS-DRG 065
# 12854        drg  MS-DRG 026
# 12855        drg  MS-DRG 003
# ...          ...         ...
# 368643       drg  MS-DRG 975
# 368644       drg  MS-DRG 981
# 368645       drg  MS-DRG 982
# 368646       drg  MS-DRG 987
# 368647       drg  MS-DRG 988
#
#                                               description  drg  cpt  modifier  \
# 12851   INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...   64  NaN       NaN
# 12852                   NERVOUS SYSTEM NEOPLASMS WITH MCC   54  NaN       NaN
# 12853   INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...   65  NaN       NaN
# 12854   CRANIOTOMY AND ENDOVASCULAR INTRACRANIAL PROCE...   26  NaN       NaN
# 12855   ECMO OR TRACHEOSTOMY WITH MV >96 HOURS OR PRIN...    3  NaN       NaN
# ...                                                   ...  ...  ...       ...
# 368643           HIV WITH MAJOR RELATED CONDITION WITH CC  975  NaN       NaN
# 368644  EXTENSIVE O.R. PROCEDURES UNRELATED TO PRINCIP...  981  NaN       NaN
# 368645  EXTENSIVE O.R. PROCEDURES UNRELATED TO PRINCIP...  982  NaN       NaN
# 368646  NON-EXTENSIVE O.R. PROCEDURES UNRELATED TO PRI...  987  NaN       NaN
# 368647  NON-EXTENSIVE O.R. PROCEDURES UNRELATED TO PRI...  988  NaN       NaN
#
#        rev_code  ndc               payer_orig       rate
# 12851        na  NaN            GROSS CHARGES   32819.97
# 12852        na  NaN            GROSS CHARGES   28181.57
# 12853        na  NaN            GROSS CHARGES   30676.41
# 12854        na  NaN            GROSS CHARGES   28739.66
# 12855        na  NaN            GROSS CHARGES  188193.12
# ...         ...  ...                      ...        ...
# 368643       na  NaN  UHC Options PPO OP Rate        NaN
# 368644       na  NaN  UHC Options PPO OP Rate        NaN
# 368645       na  NaN  UHC Options PPO OP Rate        NaN
# 368646       na  NaN  UHC Options PPO OP Rate        NaN
# 368647       na  NaN  UHC Options PPO OP Rate        NaN
#
# [8820 rows x 10 columns]

# %%
df_mid_cdm = pd.DataFrame(df_mid.loc[df_mid['code_type'] == 'cdm'])
df_mid_cdm['code_prefix'] = 'cdm'
df_mid_cdm
# Out:
#        code_type   code_orig                 description  drg    cpt  \
# 0            cdm  1142505110               R&B - PRIVATE  NaN    NaN
# 1            cdm  1140505110               R&B - PRIVATE         NaN
# 2            cdm  1140530110               R&B - PRIVATE  NaN    NaN
# 3            cdm  1142510110               R&B - PRIVATE  NaN    NaN
# 4            cdm  1150500110               R&B - PRIVATE  NaN
# ...          ...         ...                         ...  ...    ...
# 368328       cdm  9420000105  DM OP SMT INDIV PER 30 MIN  NaN  G0108
# 368329       cdm  9420000106    DM OP SMT GRP PER 30 MIN  NaN  G0109
# 368330       cdm  42505S9443             LACTATION CLASS  NaN  S9443
# 368331       cdm  9430000001               CARDIAC REHAB  NaN  93797
# 368332       cdm  9430000002       CARDIAC REHAB/MONITOR  NaN  93798
#
#         modifier rev_code  ndc               payer_orig     rate code_prefix
# 0            NaN     0110  NaN            GROSS CHARGES  1681.84         cdm
# 1            NaN     0110  NaN            GROSS CHARGES  1681.84         cdm
# 2            NaN     0110  NaN            GROSS CHARGES  1681.84         cdm
# 3            NaN     0110  NaN            GROSS CHARGES  1681.84         cdm
# 4            NaN     0110  NaN            GROSS CHARGES  1681.84         cdm
# ...          ...      ...  ...                      ...      ...         ...
# 368328       NaN     0942  NaN  UHC Options PPO OP Rate    96.12         cdm
# 368329       NaN     0942  NaN  UHC Options PPO OP Rate    59.02         cdm
# 368330       NaN     0942  NaN  UHC Options PPO OP Rate    60.25         cdm
# 368331       NaN     0943  NaN  UHC Options PPO OP Rate   180.09         cdm
# 368332       NaN     0943  NaN  UHC Options PPO OP Rate   198.10         cdm
#
# [351680 rows x 11 columns]

# %%
df_mid_drg['code_type'] = 'drg'
df_mid_drg['code_prefix'] = 'ms-drg'
df_mid_drg['code'] = df_mid_drg['code_orig'].apply(lambda code_orig: code_orig.replace("MS-DRG ", ""))
df_mid_drg
# Out:
#        code_type   code_orig  \
# 12851        drg  MS-DRG 064
# 12852        drg  MS-DRG 054
# 12853        drg  MS-DRG 065
# 12854        drg  MS-DRG 026
# 12855        drg  MS-DRG 003
# ...          ...         ...
# 368643       drg  MS-DRG 975
# 368644       drg  MS-DRG 981
# 368645       drg  MS-DRG 982
# 368646       drg  MS-DRG 987
# 368647       drg  MS-DRG 988
#
#                                               description  drg  cpt  modifier  \
# 12851   INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...   64  NaN       NaN
# 12852                   NERVOUS SYSTEM NEOPLASMS WITH MCC   54  NaN       NaN
# 12853   INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...   65  NaN       NaN
# 12854   CRANIOTOMY AND ENDOVASCULAR INTRACRANIAL PROCE...   26  NaN       NaN
# 12855   ECMO OR TRACHEOSTOMY WITH MV >96 HOURS OR PRIN...    3  NaN       NaN
# ...                                                   ...  ...  ...       ...
# 368643           HIV WITH MAJOR RELATED CONDITION WITH CC  975  NaN       NaN
# 368644  EXTENSIVE O.R. PROCEDURES UNRELATED TO PRINCIP...  981  NaN       NaN
# 368645  EXTENSIVE O.R. PROCEDURES UNRELATED TO PRINCIP...  982  NaN       NaN
# 368646  NON-EXTENSIVE O.R. PROCEDURES UNRELATED TO PRI...  987  NaN       NaN
# 368647  NON-EXTENSIVE O.R. PROCEDURES UNRELATED TO PRI...  988  NaN       NaN
#
#        rev_code  ndc               payer_orig       rate code_prefix code
# 12851        na  NaN            GROSS CHARGES   32819.97      ms-drg  064
# 12852        na  NaN            GROSS CHARGES   28181.57      ms-drg  054
# 12853        na  NaN            GROSS CHARGES   30676.41      ms-drg  065
# 12854        na  NaN            GROSS CHARGES   28739.66      ms-drg  026
# 12855        na  NaN            GROSS CHARGES  188193.12      ms-drg  003
# ...         ...  ...                      ...        ...         ...  ...
# 368643       na  NaN  UHC Options PPO OP Rate        NaN      ms-drg  975
# 368644       na  NaN  UHC Options PPO OP Rate        NaN      ms-drg  981
# 368645       na  NaN  UHC Options PPO OP Rate        NaN      ms-drg  982
# 368646       na  NaN  UHC Options PPO OP Rate        NaN      ms-drg  987
# 368647       na  NaN  UHC Options PPO OP Rate        NaN      ms-drg  988
#
# [8820 rows x 12 columns]

# %%
df_mid_cdm['code'] = df_mid_cdm['code_orig']

# %%
df_mid = pd.concat([df_mid_drg, df_mid_cdm])
df_mid
# Out:
#        code_type   code_orig  \
# 12851        drg  MS-DRG 064
# 12852        drg  MS-DRG 054
# 12853        drg  MS-DRG 065
# 12854        drg  MS-DRG 026
# 12855        drg  MS-DRG 003
# ...          ...         ...
# 368328       cdm  9420000105
# 368329       cdm  9420000106
# 368330       cdm  42505S9443
# 368331       cdm  9430000001
# 368332       cdm  9430000002
#
#                                               description  drg    cpt  \
# 12851   INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...   64    NaN
# 12852                   NERVOUS SYSTEM NEOPLASMS WITH MCC   54    NaN
# 12853   INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...   65    NaN
# 12854   CRANIOTOMY AND ENDOVASCULAR INTRACRANIAL PROCE...   26    NaN
# 12855   ECMO OR TRACHEOSTOMY WITH MV >96 HOURS OR PRIN...    3    NaN
# ...                                                   ...  ...    ...
# 368328                         DM OP SMT INDIV PER 30 MIN  NaN  G0108
# 368329                           DM OP SMT GRP PER 30 MIN  NaN  G0109
# 368330                                    LACTATION CLASS  NaN  S9443
# 368331                                      CARDIAC REHAB  NaN  93797
# 368332                              CARDIAC REHAB/MONITOR  NaN  93798
#
#         modifier rev_code  ndc               payer_orig       rate  \
# 12851        NaN       na  NaN            GROSS CHARGES   32819.97
# 12852        NaN       na  NaN            GROSS CHARGES   28181.57
# 12853        NaN       na  NaN            GROSS CHARGES   30676.41
# 12854        NaN       na  NaN            GROSS CHARGES   28739.66
# 12855        NaN       na  NaN            GROSS CHARGES  188193.12
# ...          ...      ...  ...                      ...        ...
# 368328       NaN     0942  NaN  UHC Options PPO OP Rate      96.12
# 368329       NaN     0942  NaN  UHC Options PPO OP Rate      59.02
# 368330       NaN     0942  NaN  UHC Options PPO OP Rate      60.25
# 368331       NaN     0943  NaN  UHC Options PPO OP Rate     180.09
# 368332       NaN     0943  NaN  UHC Options PPO OP Rate     198.10
#
#        code_prefix        code
# 12851       ms-drg         064
# 12852       ms-drg         054
# 12853       ms-drg         065
# 12854       ms-drg         026
# 12855       ms-drg         003
# ...            ...         ...
# 368328         cdm  9420000105
# 368329         cdm  9420000106
# 368330         cdm  42505S9443
# 368331         cdm  9430000001
# 368332         cdm  9430000002
#
# [360500 rows x 12 columns]

# %%
del df_mid['drg']
del df_mid['cpt']
df_mid['modifier'] = df_mid['modifier'].fillna('na')
df_mid['rev_code'] = df_mid['rev_code'].fillna('na')
df_mid['ndc'] = df_mid['ndc'].fillna('na')

# %%
df_mid
# Out:
#        code_type   code_orig  \
# 12851        drg  MS-DRG 064
# 12852        drg  MS-DRG 054
# 12853        drg  MS-DRG 065
# 12854        drg  MS-DRG 026
# 12855        drg  MS-DRG 003
# ...          ...         ...
# 368328       cdm  9420000105
# 368329       cdm  9420000106
# 368330       cdm  42505S9443
# 368331       cdm  9430000001
# 368332       cdm  9430000002
#
#                                               description modifier rev_code  \
# 12851   INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...       na       na
# 12852                   NERVOUS SYSTEM NEOPLASMS WITH MCC       na       na
# 12853   INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...       na       na
# 12854   CRANIOTOMY AND ENDOVASCULAR INTRACRANIAL PROCE...       na       na
# 12855   ECMO OR TRACHEOSTOMY WITH MV >96 HOURS OR PRIN...       na       na
# ...                                                   ...      ...      ...
# 368328                         DM OP SMT INDIV PER 30 MIN       na     0942
# 368329                           DM OP SMT GRP PER 30 MIN       na     0942
# 368330                                    LACTATION CLASS       na     0942
# 368331                                      CARDIAC REHAB       na     0943
# 368332                              CARDIAC REHAB/MONITOR       na     0943
#
#        ndc               payer_orig       rate code_prefix        code
# 12851   na            GROSS CHARGES   32819.97      ms-drg         064
# 12852   na            GROSS CHARGES   28181.57      ms-drg         054
# 12853   na            GROSS CHARGES   30676.41      ms-drg         065
# 12854   na            GROSS CHARGES   28739.66      ms-drg         026
# 12855   na            GROSS CHARGES  188193.12      ms-drg         003
# ...     ..                      ...        ...         ...         ...
# 368328  na  UHC Options PPO OP Rate      96.12         cdm  9420000105
# 368329  na  UHC Options PPO OP Rate      59.02         cdm  9420000106
# 368330  na  UHC Options PPO OP Rate      60.25         cdm  42505S9443
# 368331  na  UHC Options PPO OP Rate     180.09         cdm  9430000001
# 368332  na  UHC Options PPO OP Rate     198.10         cdm  9430000002
#
# [360500 rows x 10 columns]

# %%
def payer_category_from_payer_orig(payer_orig):
    if payer_orig == "GROSS CHARGES":
        return 'gross'
    elif payer_orig == "SELF PAY CASH PRICE":
        return 'cash'
    elif payer_orig == "MIN NEGOTIATED RATE":
        return 'min'
    elif payer_orig == "MAX NEGOTIATED RATE":
        return 'max'
    
    return 'payer'

df_mid['payer_category'] = df_mid['payer_orig'].apply(payer_category_from_payer_orig)
df_mid
# Out:
#        code_type   code_orig  \
# 12851        drg  MS-DRG 064
# 12852        drg  MS-DRG 054
# 12853        drg  MS-DRG 065
# 12854        drg  MS-DRG 026
# 12855        drg  MS-DRG 003
# ...          ...         ...
# 368328       cdm  9420000105
# 368329       cdm  9420000106
# 368330       cdm  42505S9443
# 368331       cdm  9430000001
# 368332       cdm  9430000002
#
#                                               description modifier rev_code  \
# 12851   INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...       na       na
# 12852                   NERVOUS SYSTEM NEOPLASMS WITH MCC       na       na
# 12853   INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...       na       na
# 12854   CRANIOTOMY AND ENDOVASCULAR INTRACRANIAL PROCE...       na       na
# 12855   ECMO OR TRACHEOSTOMY WITH MV >96 HOURS OR PRIN...       na       na
# ...                                                   ...      ...      ...
# 368328                         DM OP SMT INDIV PER 30 MIN       na     0942
# 368329                           DM OP SMT GRP PER 30 MIN       na     0942
# 368330                                    LACTATION CLASS       na     0942
# 368331                                      CARDIAC REHAB       na     0943
# 368332                              CARDIAC REHAB/MONITOR       na     0943
#
#        ndc               payer_orig       rate code_prefix        code  \
# 12851   na            GROSS CHARGES   32819.97      ms-drg         064
# 12852   na            GROSS CHARGES   28181.57      ms-drg         054
# 12853   na            GROSS CHARGES   30676.41      ms-drg         065
# 12854   na            GROSS CHARGES   28739.66      ms-drg         026
# 12855   na            GROSS CHARGES  188193.12      ms-drg         003
# ...     ..                      ...        ...         ...         ...
# 368328  na  UHC Options PPO OP Rate      96.12         cdm  9420000105
# 368329  na  UHC Options PPO OP Rate      59.02         cdm  9420000106
# 368330  na  UHC Options PPO OP Rate      60.25         cdm  42505S9443
# 368331  na  UHC Options PPO OP Rate     180.09         cdm  9430000001
# 368332  na  UHC Options PPO OP Rate     198.10         cdm  9430000002
#
#        payer_category
# 12851           gross
# 12852           gross
# 12853           gross
# 12854           gross
# 12855           gross
# ...               ...
# 368328          payer
# 368329          payer
# 368330          payer
# 368331          payer
# 368332          payer
#
# [360500 rows x 11 columns]

# %%
def patient_class_from_payer_orig(payer_orig):
    if "OP Rate" in payer_orig:
        return "outpatient"
    elif "IP Rate" in payer_orig:
        return "inpatient"
    
    return 'na'

df_mid['patient_class'] = df_mid['payer_orig'].apply(patient_class_from_payer_orig)
df_mid
# Out:
#        code_type   code_orig  \
# 12851        drg  MS-DRG 064
# 12852        drg  MS-DRG 054
# 12853        drg  MS-DRG 065
# 12854        drg  MS-DRG 026
# 12855        drg  MS-DRG 003
# ...          ...         ...
# 368328       cdm  9420000105
# 368329       cdm  9420000106
# 368330       cdm  42505S9443
# 368331       cdm  9430000001
# 368332       cdm  9430000002
#
#                                               description modifier rev_code  \
# 12851   INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...       na       na
# 12852                   NERVOUS SYSTEM NEOPLASMS WITH MCC       na       na
# 12853   INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...       na       na
# 12854   CRANIOTOMY AND ENDOVASCULAR INTRACRANIAL PROCE...       na       na
# 12855   ECMO OR TRACHEOSTOMY WITH MV >96 HOURS OR PRIN...       na       na
# ...                                                   ...      ...      ...
# 368328                         DM OP SMT INDIV PER 30 MIN       na     0942
# 368329                           DM OP SMT GRP PER 30 MIN       na     0942
# 368330                                    LACTATION CLASS       na     0942
# 368331                                      CARDIAC REHAB       na     0943
# 368332                              CARDIAC REHAB/MONITOR       na     0943
#
#        ndc               payer_orig       rate code_prefix        code  \
# 12851   na            GROSS CHARGES   32819.97      ms-drg         064
# 12852   na            GROSS CHARGES   28181.57      ms-drg         054
# 12853   na            GROSS CHARGES   30676.41      ms-drg         065
# 12854   na            GROSS CHARGES   28739.66      ms-drg         026
# 12855   na            GROSS CHARGES  188193.12      ms-drg         003
# ...     ..                      ...        ...         ...         ...
# 368328  na  UHC Options PPO OP Rate      96.12         cdm  9420000105
# 368329  na  UHC Options PPO OP Rate      59.02         cdm  9420000106
# 368330  na  UHC Options PPO OP Rate      60.25         cdm  42505S9443
# 368331  na  UHC Options PPO OP Rate     180.09         cdm  9430000001
# 368332  na  UHC Options PPO OP Rate     198.10         cdm  9430000002
#
#        payer_category patient_class
# 12851           gross            na
# 12852           gross            na
# 12853           gross            na
# 12854           gross            na
# 12855           gross            na
# ...               ...           ...
# 368328          payer    outpatient
# 368329          payer    outpatient
# 368330          payer    outpatient
# 368331          payer    outpatient
# 368332          payer    outpatient
#
# [360500 rows x 12 columns]

# %%
df_mid['billing_class'] = 'na'

# %%
def plan_type_from_payer_orig(payer_orig):
    if "PPO" in payer_orig:
        return "PPO"
    elif "HMO" in payer_orig:
        return "HMO"
    
    return None

df_mid['plan_type'] = df_mid['payer_orig'].apply(plan_type_from_payer_orig)
df_mid
# Out:
#        code_type   code_orig  \
# 12851        drg  MS-DRG 064
# 12852        drg  MS-DRG 054
# 12853        drg  MS-DRG 065
# 12854        drg  MS-DRG 026
# 12855        drg  MS-DRG 003
# ...          ...         ...
# 368328       cdm  9420000105
# 368329       cdm  9420000106
# 368330       cdm  42505S9443
# 368331       cdm  9430000001
# 368332       cdm  9430000002
#
#                                               description modifier rev_code  \
# 12851   INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...       na       na
# 12852                   NERVOUS SYSTEM NEOPLASMS WITH MCC       na       na
# 12853   INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...       na       na
# 12854   CRANIOTOMY AND ENDOVASCULAR INTRACRANIAL PROCE...       na       na
# 12855   ECMO OR TRACHEOSTOMY WITH MV >96 HOURS OR PRIN...       na       na
# ...                                                   ...      ...      ...
# 368328                         DM OP SMT INDIV PER 30 MIN       na     0942
# 368329                           DM OP SMT GRP PER 30 MIN       na     0942
# 368330                                    LACTATION CLASS       na     0942
# 368331                                      CARDIAC REHAB       na     0943
# 368332                              CARDIAC REHAB/MONITOR       na     0943
#
#        ndc               payer_orig       rate code_prefix        code  \
# 12851   na            GROSS CHARGES   32819.97      ms-drg         064
# 12852   na            GROSS CHARGES   28181.57      ms-drg         054
# 12853   na            GROSS CHARGES   30676.41      ms-drg         065
# 12854   na            GROSS CHARGES   28739.66      ms-drg         026
# 12855   na            GROSS CHARGES  188193.12      ms-drg         003
# ...     ..                      ...        ...         ...         ...
# 368328  na  UHC Options PPO OP Rate      96.12         cdm  9420000105
# 368329  na  UHC Options PPO OP Rate      59.02         cdm  9420000106
# 368330  na  UHC Options PPO OP Rate      60.25         cdm  42505S9443
# 368331  na  UHC Options PPO OP Rate     180.09         cdm  9430000001
# 368332  na  UHC Options PPO OP Rate     198.10         cdm  9430000002
#
#        payer_category patient_class billing_class plan_type
# 12851           gross            na            na      None
# 12852           gross            na            na      None
# 12853           gross            na            na      None
# 12854           gross            na            na      None
# 12855           gross            na            na      None
# ...               ...           ...           ...       ...
# 368328          payer    outpatient            na       PPO
# 368329          payer    outpatient            na       PPO
# 368330          payer    outpatient            na       PPO
# 368331          payer    outpatient            na       PPO
# 368332          payer    outpatient            na       PPO
#
# [360500 rows x 14 columns]

# %%
df_mid['plan_orig'] = 'na'
df_mid['hospital_ccn'] = ccn
df_mid['hospital_ein'] = ein
df_mid['filename'] = filename
df_mid['url'] = url
df_mid['internal_code'] = 'na'
df_mid
# Out:
#        code_type   code_orig  \
# 12851        drg  MS-DRG 064
# 12852        drg  MS-DRG 054
# 12853        drg  MS-DRG 065
# 12854        drg  MS-DRG 026
# 12855        drg  MS-DRG 003
# ...          ...         ...
# 368328       cdm  9420000105
# 368329       cdm  9420000106
# 368330       cdm  42505S9443
# 368331       cdm  9430000001
# 368332       cdm  9430000002
#
#                                               description modifier rev_code  \
# 12851   INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...       na       na
# 12852                   NERVOUS SYSTEM NEOPLASMS WITH MCC       na       na
# 12853   INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...       na       na
# 12854   CRANIOTOMY AND ENDOVASCULAR INTRACRANIAL PROCE...       na       na
# 12855   ECMO OR TRACHEOSTOMY WITH MV >96 HOURS OR PRIN...       na       na
# ...                                                   ...      ...      ...
# 368328                         DM OP SMT INDIV PER 30 MIN       na     0942
# 368329                           DM OP SMT GRP PER 30 MIN       na     0942
# 368330                                    LACTATION CLASS       na     0942
# 368331                                      CARDIAC REHAB       na     0943
# 368332                              CARDIAC REHAB/MONITOR       na     0943
#
#        ndc               payer_orig       rate code_prefix        code  \
# 12851   na            GROSS CHARGES   32819.97      ms-drg         064
# 12852   na            GROSS CHARGES   28181.57      ms-drg         054
# 12853   na            GROSS CHARGES   30676.41      ms-drg         065
# 12854   na            GROSS CHARGES   28739.66      ms-drg         026
# 12855   na            GROSS CHARGES  188193.12      ms-drg         003
# ...     ..                      ...        ...         ...         ...
# 368328  na  UHC Options PPO OP Rate      96.12         cdm  9420000105
# 368329  na  UHC Options PPO OP Rate      59.02         cdm  9420000106
# 368330  na  UHC Options PPO OP Rate      60.25         cdm  42505S9443
# 368331  na  UHC Options PPO OP Rate     180.09         cdm  9430000001
# 368332  na  UHC Options PPO OP Rate     198.10         cdm  9430000002
#
#        payer_category patient_class billing_class plan_type plan_orig  \
# 12851           gross            na            na      None        na
# 12852           gross            na            na      None        na
# 12853           gross            na            na      None        na
# 12854           gross            na            na      None        na
# 12855           gross            na            na      None        na
# ...               ...           ...           ...       ...       ...
# 368328          payer    outpatient            na       PPO        na
# 368329          payer    outpatient            na       PPO        na
# 368330          payer    outpatient            na       PPO        na
# 368331          payer    outpatient            na       PPO        na
# 368332          payer    outpatient            na       PPO        na
#
#        hospital_ccn hospital_ein  \
# 12851        460051   82-0588653
# 12852        460051   82-0588653
# 12853        460051   82-0588653
# 12854        460051   82-0588653
# 12855        460051   82-0588653
# ...             ...          ...
# 368328       460051   82-0588653
# 368329       460051   82-0588653
# 368330       460051   82-0588653
# 368331       460051   82-0588653
# 368332       460051   82-0588653
#
#                                                  filename  \
# 12851   820588653_JordanValleyMedCenter_standardcharge...
# 12852   820588653_JordanValleyMedCenter_standardcharge...
# 12853   820588653_JordanValleyMedCenter_standardcharge...
# 12854   820588653_JordanValleyMedCenter_standardcharge...
# 12855   820588653_JordanValleyMedCenter_standardcharge...
# ...                                                   ...
# 368328  820588653_JordanValleyMedCenter_standardcharge...
# 368329  820588653_JordanValleyMedCenter_standardcharge...
# 368330  820588653_JordanValleyMedCenter_standardcharge...
# 368331  820588653_JordanValleyMedCenter_standardcharge...
# 368332  820588653_JordanValleyMedCenter_standardcharge...
#
#                                                       url internal_code
# 12851   https://content.steward.org/sites/default/file...            na
# 12852   https://content.steward.org/sites/default/file...            na
# 12853   https://content.steward.org/sites/default/file...            na
# 12854   https://content.steward.org/sites/default/file...            na
# 12855   https://content.steward.org/sites/default/file...            na
# ...                                                   ...           ...
# 368328  https://content.steward.org/sites/default/file...            na
# 368329  https://content.steward.org/sites/default/file...            na
# 368330  https://content.steward.org/sites/default/file...            na
# 368331  https://content.steward.org/sites/default/file...            na
# 368332  https://content.steward.org/sites/default/file...            na
#
# [360500 rows x 20 columns]

# %%
df_out = pd.DataFrame(columns=TARGET_COLUMNS)
df_out = df_out.append(df_mid)
df_out = df_out.dropna(subset=['rate'], axis=0)
df_out
# Out:
# /tmp/ipykernel_13585/1393279649.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_out = df_out.append(df_mid)
#        hospital_ccn hospital_ein code_type internal_code  \
# 12851        460051   82-0588653       drg            na
# 12852        460051   82-0588653       drg            na
# 12853        460051   82-0588653       drg            na
# 12854        460051   82-0588653       drg            na
# 12855        460051   82-0588653       drg            na
# ...             ...          ...       ...           ...
# 368328       460051   82-0588653       cdm            na
# 368329       460051   82-0588653       cdm            na
# 368330       460051   82-0588653       cdm            na
# 368331       460051   82-0588653       cdm            na
# 368332       460051   82-0588653       cdm            na
#
#                                               description   code_orig  \
# 12851   INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...  MS-DRG 064
# 12852                   NERVOUS SYSTEM NEOPLASMS WITH MCC  MS-DRG 054
# 12853   INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...  MS-DRG 065
# 12854   CRANIOTOMY AND ENDOVASCULAR INTRACRANIAL PROCE...  MS-DRG 026
# 12855   ECMO OR TRACHEOSTOMY WITH MV >96 HOURS OR PRIN...  MS-DRG 003
# ...                                                   ...         ...
# 368328                         DM OP SMT INDIV PER 30 MIN  9420000105
# 368329                           DM OP SMT GRP PER 30 MIN  9420000106
# 368330                                    LACTATION CLASS  42505S9443
# 368331                                      CARDIAC REHAB  9430000001
# 368332                              CARDIAC REHAB/MONITOR  9430000002
#
#        code_prefix        code modifier ndc  ... plan_name plan_id plan_type  \
# 12851       ms-drg         064       na  na  ...       NaN     NaN       NaN
# 12852       ms-drg         054       na  na  ...       NaN     NaN       NaN
# 12853       ms-drg         065       na  na  ...       NaN     NaN       NaN
# 12854       ms-drg         026       na  na  ...       NaN     NaN       NaN
# 12855       ms-drg         003       na  na  ...       NaN     NaN       NaN
# ...            ...         ...      ...  ..  ...       ...     ...       ...
# 368328         cdm  9420000105       na  na  ...       NaN     NaN       PPO
# 368329         cdm  9420000106       na  na  ...       NaN     NaN       PPO
# 368330         cdm  42505S9443       na  na  ...       NaN     NaN       PPO
# 368331         cdm  9430000001       na  na  ...       NaN     NaN       PPO
# 368332         cdm  9430000002       na  na  ...       NaN     NaN       PPO
#
#              rate rate_method rate_desc  \
# 12851    32819.97         NaN       NaN
# 12852    28181.57         NaN       NaN
# 12853    30676.41         NaN       NaN
# 12854    28739.66         NaN       NaN
# 12855   188193.12         NaN       NaN
# ...           ...         ...       ...
# 368328      96.12         NaN       NaN
# 368329      59.02         NaN       NaN
# 368330      60.25         NaN       NaN
# 368331     180.09         NaN       NaN
# 368332     198.10         NaN       NaN
#
#                                                  filename file_last_updated  \
# 12851   820588653_JordanValleyMedCenter_standardcharge...               NaN
# 12852   820588653_JordanValleyMedCenter_standardcharge...               NaN
# 12853   820588653_JordanValleyMedCenter_standardcharge...               NaN
# 12854   820588653_JordanValleyMedCenter_standardcharge...               NaN
# 12855   820588653_JordanValleyMedCenter_standardcharge...               NaN
# ...                                                   ...               ...
# 368328  820588653_JordanValleyMedCenter_standardcharge...               NaN
# 368329  820588653_JordanValleyMedCenter_standardcharge...               NaN
# 368330  820588653_JordanValleyMedCenter_standardcharge...               NaN
# 368331  820588653_JordanValleyMedCenter_standardcharge...               NaN
# 368332  820588653_JordanValleyMedCenter_standardcharge...               NaN
#
#                                                       url permalink
# 12851   https://content.steward.org/sites/default/file...       NaN
# 12852   https://content.steward.org/sites/default/file...       NaN
# 12853   https://content.steward.org/sites/default/file...       NaN
# 12854   https://content.steward.org/sites/default/file...       NaN
# 12855   https://content.steward.org/sites/default/file...       NaN
# ...                                                   ...       ...
# 368328  https://content.steward.org/sites/default/file...       NaN
# 368329  https://content.steward.org/sites/default/file...       NaN
# 368330  https://content.steward.org/sites/default/file...       NaN
# 368331  https://content.steward.org/sites/default/file...       NaN
# 368332  https://content.steward.org/sites/default/file...       NaN
#
# [165645 rows x 31 columns]

# %%
df_out.to_csv(ccn + ".csv", index=False)
