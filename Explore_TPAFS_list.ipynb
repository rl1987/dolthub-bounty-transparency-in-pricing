# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/TPAFS/transparency-data/main/price_transparency/hospitals/machine_readable_links.csv"
df = pd.read_csv(url)
df
# Out:
#          ccn                     reporting_entity_name_legal
# 0     390231              Abington Hospital Jefferson Health  \
# 1     390012              Lansdale Hospital Jefferson Health
# 2     399808  The Hospital of the University of Pennsylvania
# 3     390223                Penn Presbyterian Medical Center
# 4     393303             Children's Hospital of Philadelphia
# ...      ...                                             ...
# 7194  713025                                             NaN
# 7195  713026                                             NaN
# 7196  713027                                             NaN
# 7197  713028                                             NaN
# 7198  713029                                             NaN
#
#                            reporting_entity_name_common reporting_entity_type
# 0                    Abington Hospital Jefferson Health              hospital  \
# 1                    Lansdale Hospital Jefferson Health              hospital
# 2        The Hospital of the University of Pennsylvania              hospital
# 3                      Penn Presbyterian Medical Center              hospital
# 4                   Children's Hospital of Philadelphia              hospital
# ...                                                 ...                   ...
# 7194                North Shore Rehabilitation Hospital              hospital
# 7195                   Bogalusa Rehabilitation Hospital              hospital
# 7196  Sage Specialty And Rehabilitation Center Of La...              hospital
# 7197  Encompass Health Rehabilitation Hospital Of Sh...              hospital
# 7198             Shreveport Rehabilitation Hospital Llc              hospital
#
#                                    machine_readable_url
# 0     https://use2webtechstgpricelist.blob.core.wind...  \
# 1     https://use2webtechstgpricelist.blob.core.wind...
# 2     https://www.pennmedicine.org/-/media/documents...
# 3     https://www.pennmedicine.org/-/media/documents...
# 4     https://media.chop.edu/data/files/finance/23-1...
# ...                                                 ...
# 7194                                                NaN
# 7195                                                NaN
# 7196                                                NaN
# 7197  https://encompasshealth.com/-/media/healthsout...
# 7198                                                NaN
#
#      machine_readable_url_status
# 0                             up  \
# 1                             up
# 2                             up
# 3                             up
# 4                             up
# ...                          ...
# 7194                         NaN
# 7195                         NaN
# 7196                         NaN
# 7197                          up
# 7198                         NaN
#
#                                   machine_readable_page
# 0     https://www.abingtonhealth.org/app/security/lo...  \
# 1     https://www.abingtonhealth.org/app/security/lo...
# 2     https://www.pennmedicine.org/for-patients-and-...
# 3     https://www.pennmedicine.org/for-patients-and-...
# 4     https://www.chop.edu/centers-programs/billing-...
# ...                                                 ...
# 7194                                                NaN
# 7195                                                NaN
# 7196                                                NaN
# 7197  https://encompasshealth.com/locations/shrevepo...
# 7198                                                NaN
#
#                                      supplemental_url
# 0                                                 NaN  \
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 7194                https://www.northshore-rehab.com/
# 7195  https://www.bogalusarehabilitationhospital.com/
# 7196       https://www.thecarpenterhealthnetwork.com/
# 7197                     https://encompasshealth.com/
# 7198        https://www.shreveport-rehabhospital.com/
#
#                                               file_name file_format
# 0     23-1352152 _JAB001_Abington Hospital - Jeffers...         csv  \
# 1     26-3359979_JAB002_Abington - Lansdale Hospital...         csv
# 2                                                   NaN         csv
# 3                                                   NaN         csv
# 4                                                   NaN         csv
# ...                                                 ...         ...
# 7194                                                NaN         NaN
# 7195                                                NaN         NaN
# 7196                                                NaN         NaN
# 7197  "84-4765362_Encompass Health Rehabilitation Ho...         csv
# 7198                                                NaN         NaN
#
#       file_size meets_standard standard_issue state_or_region
# 0           NaN            NaN            NaN              PA  \
# 1           NaN            NaN            NaN              PA
# 2           NaN            NaN            NaN              PA
# 3           NaN            NaN            NaN              PA
# 4           NaN            NaN            NaN              PA
# ...         ...            ...            ...             ...
# 7194        NaN            NaN            NaN              LA
# 7195        NaN            NaN            NaN              LA
# 7196        NaN            NaN            NaN              LA
# 7197  8422326.0            NaN            NaN              LA
# 7198        NaN            NaN            NaN              LA
#
#      last_updated_date  entry_date notes
# 0                  NaN  2022-10-29   NaN
# 1                  NaN  2022-10-29   NaN
# 2                  NaN  2022-10-29   NaN
# 3                  NaN  2022-10-29   NaN
# 4                  NaN  2022-10-29   NaN
# ...                ...         ...   ...
# 7194               NaN  2022-11-26   NaN
# 7195               NaN  2022-11-26   NaN
# 7196               NaN  2022-11-26   NaN
# 7197        2022-07-18  2022-11-26   NaN
# 7198               NaN  2022-11-26   NaN
#
# [7199 rows x 17 columns]

# %%
df['supplemental_url'].value_counts()[:20]
# Out:
# supplemental_url
# https://encompasshealth.com/                 147
# https://www.selectspecialtyhospitals.com/     71
# https://www.kindredhospitals.com/             54
# https://www.providence.org/                   47
# https://www.hcafloridahealthcare.com/         45
# https://www.dignityhealth.org/                34
# https://www.mercy.net/                        33
# https://www.adventhealth.com/                 32
# https://www.avera.org/                        31
# https://thrive.kaiserpermanente.org/          29
# https://www.sutterhealth.org/                 29
# https://intermountainhealthcare.org/          25
# https://www.bswhealth.com/                    25
# https://www.texashealth.org/                  23
# https://www.ssmhealth.com/                    22
# https://www.christushealth.org/               22
# https://www.adventisthealth.org/              21
# https://www.mercy.com/                        21
# https://my.clevelandclinic.org/               20
# https://oceanshealthcare.com/                 19
# Name: count, dtype: int64
