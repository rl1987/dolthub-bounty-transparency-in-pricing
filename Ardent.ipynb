# %%
import subprocess

import pandas as pd

from helpers import *

# %%
TARGET_COLUMNS = [ 
    'hospital_id',
    #'row_id',
    'line_type',
    'description',
    'rev_code',
    'local_code',
    'code',
    'ms_drg',
    'apr_drg',
    'eapg',
    'hcpcs_cpt',
    'modifiers',
    'alt_hcpcs_cpt',
    'thru',
    'apc',
    'icd',
    'ndc',
    'drug_hcpcs_multiplier',
    'drug_quantity',
    'drug_unit_of_measurement',
    'drug_type_of_measurement',
    'billing_class',
    'setting',
    'rate_category',
    'payer_name',
    'plan_name',
    'standard_charge',
    'standard_charge_percent',
    'contracting_method',
    'additional_generic_notes',
    'additional_payer_specific_notes'
]

# %%
TRANSPARENCY_PAGE = "https://hillcrestcushing.com/pricing-transparency"
ccn = "370099"
url = "https://coc.ardenthealthservices.com/2023/oklahoma/201024792_Hillcrest-Hospital-Cushing_standardcharges.csv"
filename = derive_filename_from_url(url)
ein = derive_ein_from_filename(filename)
ein
# Out:
# '20-1024792'

# %%
subprocess.run(["wget", "--no-clobber", url, "-O", filename])
# Out:
# File ‘201024792_Hillcrest-Hospital-Cushing_standardcharges.csv’ already there; not retrieving.
# CompletedProcess(args=['wget', '--no-clobber', 'https://coc.ardenthealthservices.com/2023/oklahoma/201024792_Hillcrest-Hospital-Cushing_standardcharges.csv', '-O', '201024792_Hillcrest-Hospital-Cushing_standardcharges.csv'], returncode=1)

# %%
df_in = pd.read_csv(filename, dtype=str, skiprows=[0])
df_in
# Out:
#        Procedure Code Type                                       Revenue Code  \
# 0          10011       ERX  0637 - PHARMACY-EXTENSION OF 025X-SELF-ADMINIS...
# 1          10011       ERX  0637 - PHARMACY-EXTENSION OF 025X-SELF-ADMINIS...
# 2          10011       ERX  0637 - PHARMACY-EXTENSION OF 025X-SELF-ADMINIS...
# 3          10011       ERX  0637 - PHARMACY-EXTENSION OF 025X-SELF-ADMINIS...
# 4          10011       ERX  0637 - PHARMACY-EXTENSION OF 025X-SELF-ADMINIS...
# ...          ...       ...                                                ...
# 402181     MS999       DRG                                                NaN
# 402182     MS999       DRG                                                NaN
# 402183     MS999       DRG                                                NaN
# 402184     MS999       DRG                                                NaN
# 402185     MS999       DRG                                                NaN
#
#           Procedure Description  Quantity                               Payer  \
# 0       FAMOTIDINE 20 MG TABLET  1 tablet      ADMINISTRATIVE CONCEPTS [1005]
# 1       FAMOTIDINE 20 MG TABLET  1 tablet   AETNA MEDICARE REPLACEMENT [1020]
# 2       FAMOTIDINE 20 MG TABLET  1 tablet                        AETNA [1015]
# 3       FAMOTIDINE 20 MG TABLET  1 tablet   ALLIED BENEFIT SYSTEMS INC [1030]
# 4       FAMOTIDINE 20 MG TABLET  1 tablet  ALLIED NATIONAL GLOBAL CARE [1035]
# ...                         ...       ...                                 ...
# 402181              Ungroupable         1            UNITED HEALTHCARE [2060]
# 402182              Ungroupable         1           UNIVERSAL FIDELITY [2085]
# 402183              Ungroupable         1                 VA CCN OPTUM [3920]
# 402184              Ungroupable         1                      WEB TPA [2115]
# 402185              Ungroupable         1                WORKER'S COMP [2125]
#
#                                        Plan Inpatient Gross Charges  \
# 0          ADMINISTRATIVE CONCEPTS [100502]                    6.34
# 1       AETNA MEDICARE REPLACEMENT [102002]                    6.34
# 2                  AETNA ACO WILCO [101532]                    6.34
# 3           ALLIED BENEFIT SYSTEMS [103000]                    6.34
# 4                  ALLIED NATIONAL [103500]                    6.34
# ...                                     ...                     ...
# 402181   UNITED HEALTHCARE CHARTER [206031]               103014.89
# 402182     UNIVERSAL FIDELITY LIFE [208500]               103014.89
# 402183                VA CCN OPTUM [392000]               103014.89
# 402184                     WEB TPA [211500]               135906.83
# 402185              CITY OF TULSA [2125108]               135906.83
#
#        Inpatient Expected Reimbursement Inpatient Max Reimbursement  \
# 0                                   NaN                         NaN
# 1                                   NaN                         NaN
# 2                                   NaN                         NaN
# 3                                   NaN                         NaN
# 4                                   NaN                         NaN
# ...                                 ...                         ...
# 402181                              NaN                    70338.37
# 402182                              NaN                    70338.37
# 402183                         62953.34                    70338.37
# 402184                              NaN                    70338.37
# 402185                              NaN                    70338.37
#
#        Inpatient Minimal Reimbursement Outpatient Gross Charges  \
# 0                                  NaN                     6.34
# 1                                  NaN                     6.34
# 2                                  NaN                     6.34
# 3                                  NaN                     6.34
# 4                                  NaN                     6.34
# ...                                ...                      ...
# 402181                        14961.16                      NaN
# 402182                        14961.16                      NaN
# 402183                        14961.16                      NaN
# 402184                        14961.16                      NaN
# 402185                        14961.16                      NaN
#
#        Outpatient Expected Reimbursement Outpatient Max Reimbursement  \
# 0                                   5.58                   2583.81335
# 1                                    NaN                   2583.81335
# 2                                   2.98                   2583.81335
# 3                                   5.58                   2583.81335
# 4                                   5.58                   2583.81335
# ...                                  ...                          ...
# 402181                               NaN                          NaN
# 402182                               NaN                          NaN
# 402183                               NaN                          NaN
# 402184                               NaN                          NaN
# 402185                               NaN                          NaN
#
#        Outpatient Minimal Reimbursement Discounted Cash Price
# 0                                  1.59                   1.9
# 1                                  1.59                   1.9
# 2                                  1.59                   1.9
# 3                                  1.59                   1.9
# 4                                  1.59                   1.9
# ...                                 ...                   ...
# 402181                              NaN              30904.47
# 402182                              NaN              30904.47
# 402183                              NaN              30904.47
# 402184                              NaN              30904.47
# 402185                              NaN              30904.47
#
# [402186 rows x 16 columns]

# %%
df_mid = pd.DataFrame(df_in)
df_mid = df_mid.rename(columns={
    'Procedure': 'code',
    'Code Type': 'line_type',
    'Revenue Code': 'rev_code',
    'Procedure Description': 'description',
    'Quantity': 'drug_quantity',
    'Payer': 'payer_name',
    'Plan': 'plan_name',
})

df_mid
# Out:
#          code line_type                                           rev_code  \
# 0       10011       ERX  0637 - PHARMACY-EXTENSION OF 025X-SELF-ADMINIS...
# 1       10011       ERX  0637 - PHARMACY-EXTENSION OF 025X-SELF-ADMINIS...
# 2       10011       ERX  0637 - PHARMACY-EXTENSION OF 025X-SELF-ADMINIS...
# 3       10011       ERX  0637 - PHARMACY-EXTENSION OF 025X-SELF-ADMINIS...
# 4       10011       ERX  0637 - PHARMACY-EXTENSION OF 025X-SELF-ADMINIS...
# ...       ...       ...                                                ...
# 402181  MS999       DRG                                                NaN
# 402182  MS999       DRG                                                NaN
# 402183  MS999       DRG                                                NaN
# 402184  MS999       DRG                                                NaN
# 402185  MS999       DRG                                                NaN
#
#                     description drug_quantity  \
# 0       FAMOTIDINE 20 MG TABLET      1 tablet
# 1       FAMOTIDINE 20 MG TABLET      1 tablet
# 2       FAMOTIDINE 20 MG TABLET      1 tablet
# 3       FAMOTIDINE 20 MG TABLET      1 tablet
# 4       FAMOTIDINE 20 MG TABLET      1 tablet
# ...                         ...           ...
# 402181              Ungroupable             1
# 402182              Ungroupable             1
# 402183              Ungroupable             1
# 402184              Ungroupable             1
# 402185              Ungroupable             1
#
#                                 payer_name  \
# 0           ADMINISTRATIVE CONCEPTS [1005]
# 1        AETNA MEDICARE REPLACEMENT [1020]
# 2                             AETNA [1015]
# 3        ALLIED BENEFIT SYSTEMS INC [1030]
# 4       ALLIED NATIONAL GLOBAL CARE [1035]
# ...                                    ...
# 402181            UNITED HEALTHCARE [2060]
# 402182           UNIVERSAL FIDELITY [2085]
# 402183                 VA CCN OPTUM [3920]
# 402184                      WEB TPA [2115]
# 402185                WORKER'S COMP [2125]
#
#                                   plan_name Inpatient Gross Charges  \
# 0          ADMINISTRATIVE CONCEPTS [100502]                    6.34
# 1       AETNA MEDICARE REPLACEMENT [102002]                    6.34
# 2                  AETNA ACO WILCO [101532]                    6.34
# 3           ALLIED BENEFIT SYSTEMS [103000]                    6.34
# 4                  ALLIED NATIONAL [103500]                    6.34
# ...                                     ...                     ...
# 402181   UNITED HEALTHCARE CHARTER [206031]               103014.89
# 402182     UNIVERSAL FIDELITY LIFE [208500]               103014.89
# 402183                VA CCN OPTUM [392000]               103014.89
# 402184                     WEB TPA [211500]               135906.83
# 402185              CITY OF TULSA [2125108]               135906.83
#
#        Inpatient Expected Reimbursement Inpatient Max Reimbursement  \
# 0                                   NaN                         NaN
# 1                                   NaN                         NaN
# 2                                   NaN                         NaN
# 3                                   NaN                         NaN
# 4                                   NaN                         NaN
# ...                                 ...                         ...
# 402181                              NaN                    70338.37
# 402182                              NaN                    70338.37
# 402183                         62953.34                    70338.37
# 402184                              NaN                    70338.37
# 402185                              NaN                    70338.37
#
#        Inpatient Minimal Reimbursement Outpatient Gross Charges  \
# 0                                  NaN                     6.34
# 1                                  NaN                     6.34
# 2                                  NaN                     6.34
# 3                                  NaN                     6.34
# 4                                  NaN                     6.34
# ...                                ...                      ...
# 402181                        14961.16                      NaN
# 402182                        14961.16                      NaN
# 402183                        14961.16                      NaN
# 402184                        14961.16                      NaN
# 402185                        14961.16                      NaN
#
#        Outpatient Expected Reimbursement Outpatient Max Reimbursement  \
# 0                                   5.58                   2583.81335
# 1                                    NaN                   2583.81335
# 2                                   2.98                   2583.81335
# 3                                   5.58                   2583.81335
# 4                                   5.58                   2583.81335
# ...                                  ...                          ...
# 402181                               NaN                          NaN
# 402182                               NaN                          NaN
# 402183                               NaN                          NaN
# 402184                               NaN                          NaN
# 402185                               NaN                          NaN
#
#        Outpatient Minimal Reimbursement Discounted Cash Price
# 0                                  1.59                   1.9
# 1                                  1.59                   1.9
# 2                                  1.59                   1.9
# 3                                  1.59                   1.9
# 4                                  1.59                   1.9
# ...                                 ...                   ...
# 402181                              NaN              30904.47
# 402182                              NaN              30904.47
# 402183                              NaN              30904.47
# 402184                              NaN              30904.47
# 402185                              NaN              30904.47
#
# [402186 rows x 16 columns]

# %%
df_mid.loc[df_mid['rev_code'].notnull(), 'rev_code'] = df_mid[df_mid['rev_code'].notnull()]['rev_code'].apply(
    lambda rev_code: rev_code.split(' ')[0]
)
set(df_mid['rev_code'].to_list())
# Out:
# {'0110',
#  '0113',
#  '0120',
#  '0124',
#  '0164',
#  '0171',
#  '0200',
#  '0250',
#  '0255',
#  '0258',
#  '0260',
#  '0270',
#  '0271',
#  '0272',
#  '0274',
#  '0276',
#  '0278',
#  '0300',
#  '0301',
#  '0302',
#  '0305',
#  '0306',
#  '0307',
#  '0309',
#  '0310',
#  '0311',
#  '0312',
#  '0314',
#  '0320',
#  '0322',
#  '0324',
#  '0340',
#  '0341',
#  '0342',
#  '0343',
#  '0344',
#  '0349',
#  '0350',
#  '0351',
#  '0352',
#  '0359',
#  '0360',
#  '0370',
#  '0390',
#  '0391',
#  '0401',
#  '0402',
#  '0403',
#  '0404',
#  '0410',
#  '0420',
#  '0423',
#  '0424',
#  '0430',
#  '0434',
#  '0440',
#  '0444',
#  '0450',
#  '0460',
#  '0471',
#  '0480',
#  '0482',
#  '0483',
#  '0490',
#  '0510',
#  '0610',
#  '0611',
#  '0612',
#  '0615',
#  '0619',
#  '0636',
#  '0637',
#  '0710',
#  '0720',
#  '0721',
#  '0723',
#  '0730',
#  '0750',
#  '0761',
#  '0762',
#  '0771',
#  '0917',
#  '0920',
#  '0921',
#  '0940',
#  '0942',
#  nan}

# %%
money_idx = df_mid.columns.to_list().index('Inpatient Gross Charges')
money_columns = df_mid.columns.to_list()[money_idx:]
money_columns
# Out:
# ['Inpatient Gross Charges',
#  'Inpatient Expected Reimbursement',
#  'Inpatient Max Reimbursement',
#  'Inpatient Minimal Reimbursement',
#  'Outpatient Gross Charges',
#  'Outpatient Expected Reimbursement',
#  'Outpatient Max Reimbursement',
#  'Outpatient Minimal Reimbursement',
#  'Discounted Cash Price']

# %%
remaining_columns = df_mid.columns.to_list()[:money_idx]
df_mid = pd.melt(df_mid, id_vars=remaining_columns, var_name='payer_name2', value_name='standard_charge')
df_mid
# Out:
#           code line_type rev_code              description drug_quantity  \
# 0        10011       ERX     0637  FAMOTIDINE 20 MG TABLET      1 tablet
# 1        10011       ERX     0637  FAMOTIDINE 20 MG TABLET      1 tablet
# 2        10011       ERX     0637  FAMOTIDINE 20 MG TABLET      1 tablet
# 3        10011       ERX     0637  FAMOTIDINE 20 MG TABLET      1 tablet
# 4        10011       ERX     0637  FAMOTIDINE 20 MG TABLET      1 tablet
# ...        ...       ...      ...                      ...           ...
# 3619669  MS999       DRG      NaN              Ungroupable             1
# 3619670  MS999       DRG      NaN              Ungroupable             1
# 3619671  MS999       DRG      NaN              Ungroupable             1
# 3619672  MS999       DRG      NaN              Ungroupable             1
# 3619673  MS999       DRG      NaN              Ungroupable             1
#
#                                  payer_name  \
# 0            ADMINISTRATIVE CONCEPTS [1005]
# 1         AETNA MEDICARE REPLACEMENT [1020]
# 2                              AETNA [1015]
# 3         ALLIED BENEFIT SYSTEMS INC [1030]
# 4        ALLIED NATIONAL GLOBAL CARE [1035]
# ...                                     ...
# 3619669            UNITED HEALTHCARE [2060]
# 3619670           UNIVERSAL FIDELITY [2085]
# 3619671                 VA CCN OPTUM [3920]
# 3619672                      WEB TPA [2115]
# 3619673                WORKER'S COMP [2125]
#
#                                    plan_name              payer_name2  \
# 0           ADMINISTRATIVE CONCEPTS [100502]  Inpatient Gross Charges
# 1        AETNA MEDICARE REPLACEMENT [102002]  Inpatient Gross Charges
# 2                   AETNA ACO WILCO [101532]  Inpatient Gross Charges
# 3            ALLIED BENEFIT SYSTEMS [103000]  Inpatient Gross Charges
# 4                   ALLIED NATIONAL [103500]  Inpatient Gross Charges
# ...                                      ...                      ...
# 3619669   UNITED HEALTHCARE CHARTER [206031]    Discounted Cash Price
# 3619670     UNIVERSAL FIDELITY LIFE [208500]    Discounted Cash Price
# 3619671                VA CCN OPTUM [392000]    Discounted Cash Price
# 3619672                     WEB TPA [211500]    Discounted Cash Price
# 3619673              CITY OF TULSA [2125108]    Discounted Cash Price
#
#         standard_charge
# 0                  6.34
# 1                  6.34
# 2                  6.34
# 3                  6.34
# 4                  6.34
# ...                 ...
# 3619669        30904.47
# 3619670        30904.47
# 3619671        30904.47
# 3619672        30904.47
# 3619673        30904.47
#
# [3619674 rows x 9 columns]

# %%
df_mid['setting'] = None

df_mid.loc[df_mid['payer_name2'].str.contains('Inpatient'), 'setting'] = 'inpatient'
df_mid.loc[df_mid['payer_name2'].str.contains('Outpatient'), 'setting'] = 'outpatient'

df_mid

# %%
df_mid.loc[df_mid['payer_name2'].str.contains('Gross'), 'rate_category'] = 'gross'
df_mid.loc[df_mid['payer_name2'].str.contains('Cash'), 'rate_category'] = 'cash'
df_mid.loc[df_mid['payer_name2'].str.contains('Min'), 'rate_category'] = 'min'
df_mid.loc[df_mid['payer_name2'].str.contains('Max'), 'rate_category'] = 'max'
df_mid.loc[df_mid['payer_name2'].str.contains('Expected Reimbursement'), 'rate_category'] = 'negotiated'
df_mid

# %%
df_mid.loc[df_mid['rate_category'] != 'negotiated', 'payer_name'] = df_mid[df_mid['rate_category'] != 'negotiated']['payer_name2']
df_mid.loc[df_mid['rate_category'] != 'negotiated', 'plan_name'] = None
del df_mid['payer_name2']
df_mid

# %%
df_mid['line_type'].value_counts()

# %%
df_mid.loc[df_mid['line_type'] == 'DRG', 'ms_drg'] = df_mid[df_mid['line_type'] == 'DRG']['code'].str.replace('MS', '')

# %%
df_mid['hospital_id'] = ccn
df_mid['local_code'] = None
df_mid['apr_drg'] = None
df_mid['eapg'] = None
df_mid['hcpcs_cpt'] = None
df_mid['modifiers'] = None
df_mid['alt_hcpcs_cpt'] = None
df_mid['thru'] = None
df_mid['apc'] = None
df_mid['icd'] = None
df_mid['ndc'] = None
df_mid['drug_hcpcs_multiplier'] = None
df_mid['standard_charge_percent'] = None
df_mid['contracting_method'] = None
df_mid['additional_generic_notes'] = None
df_mid['additional_payer_specific_notes'] = None
df_mid['billing_class'] = None
df_mid['drug_unit_of_measurement'] = None
df_mid['drug_type_of_measurement'] = None

df_mid

# %%
df_out = pd.DataFrame(df_mid[TARGET_COLUMNS])
df_out

# %%
df_out.to_csv('rate_' + ccn + '.csv', index=False)
