# %%
import pandas as pd

# %%
df = pd.read_csv('http_head_results.csv')
df
# Out:
#          ccn                           organization_name  \
# 0     440058       SOUTHERN TENNESSEE MEDICAL CENTER LLC
# 1     200024                CENTRAL MAINE MEDICAL CENTER
# 2     220062           ADCARE HOSPITAL OF WORCESTER, INC
# 3     112011    SELECT SPECIALTY HOSPITAL - SAVANNAH INC
# 4     330246                         ST CHARLES HOSPITAL
# ...      ...                                         ...
# 3899  210017                                  GRMC, INC.
# 3900  010061                HH HEALTH SYSTEM-JACKSON LLC
# 3901  362023  SELECT SPECIALTY HOSPITAL - BOARDMAN, INC.
# 3902  060044        CATHOLIC HEALTH INITIATIVES COLORADO
# 3903  170074        STORMONT VAIL HEALTH FLINT HILLS LLC
#
#                                  doing_business_as_name  \
# 0     SOUTHERN TENNESSEE REGIONAL HEALTH SYSTEM WINC...
# 1                                                   NaN
# 2                          ADCARE HOSPITAL OF WORCESTER
# 3                    SELECT SPECIALTY HOSPITAL SAVANNAH
# 4                                                   NaN
# ...                                                 ...
# 3899                    GARRETT REGIONAL MEDICAL CENTER
# 3900                           HIGHLANDS MEDICAL CENTER
# 3901                 SELECT SPECIALTY HOSPITAL-BOARDMAN
# 3902                     CENTURA ST. ELIZABETH HOSPITAL
# 3903                  STORMONT VAIL HEALTH, FLINT HILLS
#
#                                        homepage  \
# 0         https://www.southerntnwinchester.com/
# 1                         https://www.cmhc.org/
# 2                           https://adcare.com/
# 3     https://www.selectspecialtyhospitals.com/
# 4                        https://www.chsli.org/
# ...                                         ...
# 3899          https://www.grmc-wvumedicine.org/
# 3900            https://highlandsmedcenter.com/
# 3901  https://www.selectspecialtyhospitals.com/
# 3902                   https://www.centura.org/
# 3903        https://gearycommunityhospital.org/
#
#                                standard_charge_file_url  http_status  \
# 0     https://www.southerntnwinchester.com/sites/str...          200
# 1     https://www.cmhc.org/app/uploads/2022/09/01021...          200
# 2     https://admin.adcare.com/wp-content/uploads/20...          403
# 3     https://resources.selectmedical.com/Pricing-Tr...          200
# 4     https://www.chsli.org/sites/default/files/2022...          200
# ...                                                 ...          ...
# 3899  https://www.grmc-wvumedicine.org/wp-content/up...          200
# 3900  https://www.cdmpricing.com/95675211e480b185fd2...          200
# 3901  https://resources.selectmedical.com/Pricing-Tr...          200
# 3902  http://www.coloradoplainsmedicalcenter.com/sit...          200
# 3903  https://secure.claraprice.net/price-transparen...          200
#
#       content_len                                       content_type
# 0             NaN                                    application/zip
# 1       2568536.0                                    application/zip
# 2             NaN                           text/html; charset=UTF-8
# 3       3208545.0                           application/octet-stream
# 4       2202315.0  application/vnd.openxmlformats-officedocument....
# ...           ...                                                ...
# 3899     334018.0  application/vnd.openxmlformats-officedocument....
# 3900       2484.0                                          text/html
# 3901    3111292.0                           application/octet-stream
# 3902          NaN                                          text/html
# 3903          NaN                           text/html; charset=utf-8
#
# [3904 rows x 8 columns]

# %%
df = df[df['http_status'] == 200]
df = df.dropna(subset=['content_len'], axis=0)
df['content_len'] = df['content_len'].astype(int)
df = df[df['content_len'] < 30 * 1024 * 1024]
#df = df[df['standard_charge_file_url'].str.contains("cdmpricing.com")==False]
df = df[df['standard_charge_file_url'].str.contains("standardcharge")]
df
# Out:
#          ccn                                  organization_name  \
# 1     200024                       CENTRAL MAINE MEDICAL CENTER
# 3     112011           SELECT SPECIALTY HOSPITAL - SAVANNAH INC
# 4     330246                                ST CHARLES HOSPITAL
# 7     252005         SELECT SPECIALTY HOSPITAL - GULF COAST INC
# 9     182003          SELECT SPECIALTY HOSPITAL - LEXINGTON INC
# ...      ...                                                ...
# 3891  143030  THE REHABILITATION INSTITUTE OF SOUTHERN ILLIN...
# 3896  143031  ENCOMPASS HEALTH REHABILITATION HOSPITAL OF LI...
# 3897  100029                                   STEWARD NSMC INC
# 3898  110230                              EHCA JOHNS CREEK, LLC
# 3901  362023         SELECT SPECIALTY HOSPITAL - BOARDMAN, INC.
#
#                                  doing_business_as_name  \
# 1                                                   NaN
# 3                    SELECT SPECIALTY HOSPITAL SAVANNAH
# 4                                                   NaN
# 7                SELECT SPECIALTY HOSPITAL - GULF COAST
# 9          SELECT SPECIALTY HOSPITAL - CENTRAL KENTUCKY
# ...                                                 ...
# 3891  THE REHABILITATION INSTITUTE OF SOUTHERN ILLINOIS
# 3896  ENCOMPASS HEALTH REHABILITATION INSTITUTE OF L...
# 3897                                                NaN
# 3898                         EMORY JOHNS CREEK HOSPITAL
# 3901                 SELECT SPECIALTY HOSPITAL-BOARDMAN
#
#                                        homepage  \
# 1                         https://www.cmhc.org/
# 3     https://www.selectspecialtyhospitals.com/
# 4                        https://www.chsli.org/
# 7     https://www.selectspecialtyhospitals.com/
# 9     https://www.selectspecialtyhospitals.com/
# ...                                         ...
# 3891               https://encompasshealth.com/
# 3896               https://encompasshealth.com/
# 3897              https://www.northshoremc.org/
# 3898           https://www.emoryhealthcare.org/
# 3901  https://www.selectspecialtyhospitals.com/
#
#                                standard_charge_file_url  http_status  \
# 1     https://www.cmhc.org/app/uploads/2022/09/01021...          200
# 3     https://resources.selectmedical.com/Pricing-Tr...          200
# 4     https://www.chsli.org/sites/default/files/2022...          200
# 7     https://resources.selectmedical.com/Pricing-Tr...          200
# 9     https://resources.selectmedical.com/Pricing-Tr...          200
# ...                                                 ...          ...
# 3891  https://encompasshealth.com/-/media/healthsout...          200
# 3896  https://encompasshealth.com/-/media/healthsout...          200
# 3897  https://content.steward.org/sites/default/file...          200
# 3898  https://www.emoryhealthcare.org/ui/pricing-tra...          200
# 3901  https://resources.selectmedical.com/Pricing-Tr...          200
#
#       content_len                                       content_type
# 1         2568536                                    application/zip
# 3         3208545                           application/octet-stream
# 4         2202315  application/vnd.openxmlformats-officedocument....
# 7         3112794                           application/octet-stream
# 9          599418                           application/octet-stream
# ...           ...                                                ...
# 3891      9937760                                           text/csv
# 3896      8655579                                           text/csv
# 3897      7189407                                           text/csv
# 3898     14169358                                   application/json
# 3901      3111292                           application/octet-stream
#
# [1143 rows x 8 columns]

# %%
df[df['homepage'] == 'https://www.selectspecialtyhospitals.com/']['standard_charge_file_url'].tolist()
# Out:
# ['https://resources.selectmedical.com/Pricing-Transparency/critical-illness-recovery
standardcharges.csv',
#  'https://resources.selectmedical.com/Pricing-Transparency/critical-illness-recovery/26-3643089_Select_Specialty_Hospital-Akron_standardcharges.csv',
#  'https://resources.selectmedical.com/Pricing-Transparency/critical-illness-recovery/06-1713547_Select_Specialty_Hospital-Gainesville_standardcharges.csv',
#  'https://resources.selectmedical.com/Pricing-Transparency/critical-illness-recovery/71-0958380_Select_Specialty_Hospital-Greensboro_standardcharges.csv',
#  'https://resources.selectmedical.com/Pricing-Transparency/critical-illness-recovery/03-0508559_Select_Specialty_Hospital-Palm_Beach_standardcharges.csv',
#  'https://resources.selectmedical.com/Pricing-Transparency/critical-illness-recovery/26-4770769_Acuity_Hospital_of_New_Jersey_standardcharges.csv',
#  'https://resources.selectmedical.com/Pricing-Transparency/critical-illness-recovery/25-1816237_Select_Specialty_Hospital-Northern_Kentucky_standardcharges.csv',
#  'https://resources.selectmedical.com/Pricing-Transparency/critical-illness-recovery/65-0366469_Select_Specialty_Hospital-Springfield_standardcharges.csv',
#  'https://resources.selectmedical.com/Pricing-Transparency/critical-illness-recovery/25-1855473_Select_Specialty_Hospital-Des_Moines_standardcharges.csv',
#  'https://resources.selectmedical.com/Pricing-Transparency/critical-illness-recovery/46-3235750_Select_Specialty_Hospital-Daytona_Beach_standardcharges.csv',
#  'https://resources.selectmedical.com/Pricing-Transparency/critical-illness-recovery/81-1476363_Select_Specialty_Hospital-Cleveland_Fairhill_standardcharges.csv',
#  'https://resources.selectmedical.com/Pricing-Transparency/critical-illness-recovery/81-1467358_Select_Specialty_Hospital-Midtown_Atlanta_standardcharges.csv',
#  'https://resources.selectmedical.com/Pricing-Transparency/critical-illness-recovery/81-2297468_Select_Specialty_Hosital-Tucson_standardcharges.csv',
#  'https://resources.selectmedical.com/Pricing-Transparency/critical-illness-recovery/81-2366365_Select_Specialty_Hospital-Belhaven_standardcharges.csv',
#  'https://resources.selectmedical.com/Pricing-Transparency/critical-illness-recovery/38-4031103_Select_Specialty_Hospital-Spectrum_Health_standardcharges.csv',
#  'https://resources.selectmedical.com/Pricing-Transparency/critical-illness-recovery/83-3331871_Select_Specialty_Hospital-Miami_Lakes_standardcharges.csv',
#  'https://resources.selectmedical.com/Pricing-Transparency/critical-illness-recovery/83-3353703_Select_Specialty_Hospital-The_Villages_standardcharges.csv',
#  'https://resources.selectmedical.com/Pricing-Transparency/critical-illness-recovery/83-3761916_LTACH_Morgantown_standardcharges.csv',
#  'https://resources.selectmedical.com/Pricing-Transparency/critical-illness-recovery/34-1880514_Select_Specialty_Hospital-Boardman_standardcharges.csv']

# %% [markdown]
# Select Medical is not compliant...

# %%
from urllib.parse import urlparse

df['domain'] = df['standard_charge_file_url'].apply(lambda url: urlparse(url).netloc)
df['domain'].value_counts()
# Out:
# encompasshealth.com               130
# resources.selectmedical.com        97
# core.secure.ehc.com                97
# www.kindredhospitals.com           40
# content.steward.org                32
#                                  ...
# hbhospital.org                      1
# www.rumcsi.org                      1
# www.merithealthriverregion.com      1
# www.catholicmedicalcenter.org       1
# brrh.ernesthealth.com               1
# Name: domain, Length: 321, dtype: int64

# %%
set(df['domain'].to_list())
# Out:
# {'altushospitals.org',
#  'anmed.org',
#  'app.vestacare.com',
#  'apprhs.org',
#  'assets.changehealthcare.com',
#  'assets.contentstack.io',
#  'baptisthealth.net',
#  'bestcare.org',
#  'brooksrehab.org',
#  'brrh.ernesthealth.com',
#  'carle.org',
#  'cdn.goodshepherdrehab.org',
#  'cdn.hs.uab.edu',
#  'chc.la',
#  'chimercyhealth.com',
#  'choaassets.choa.org',
#  'clariti-health.com',
#  'cleverleypteusstatic.blob.core.windows.net',
#  'coc.ardenthealthservices.com',
#  'communityhospitalokc.com',
#  'content.steward.org',
#  'corbin.continuecare.org',
#  'core.secure.ehc.com',
#  'creeksidebh.com',
#  'dam.upmc.com',
#  'dev-corpus-christi-hospital.pantheonsite.io',
#  'elpasochildrens.org',
#  'encompasshealth.com',
#  'everestrehab.com',
#  'files.blountmemorial.org',
#  'files.nc.gov',
#  'files.trueaccess.care',
#  'finance.vumc.org',
#  'flushinghospital.org',
#  'fluxconsole.com',
#  'fresnosurgicalhospital.com',
#  'global-uploads.webflow.com',
#  'goldteamstorage.blob.core.windows.net',
#  'halifaxhealth.org',
#  'hbhospital.org',
#  'hchdst.org',
#  'health.uconn.edu',
#  'hendrick.continuecare.org',
#  'himasanpablo.com',
#  'images.sharp.com',
#  'intermountainhealthcare.org',
#  'irp.cdn-website.com',
#  'jamaicahospital.org',
#  'lindsayhospital.com',
#  'lluh.org',
#  'madisonville.continuecare.org',
#  'mhsystem.org',
#  'miramontbh.com',
#  'missionhealth.org',
#  'mwsurgicalhospital.com',
#  'ncstoragemlessentia.blob.core.windows.net',
#  'ncstoragemlgundersen.blob.core.windows.net',
#  'nolandhospitals.com',
#  'northwesthillssurgical.com',
#  'nwsurgicalokc.com',
#  'ochsnerlg.org',
#  'odessa.continuecare.org',
#  'onebrooklynhealth.org',
#  'paducah.continuecare.org',
#  'palmetto.continuecare.org',
#  'pennrehab.org',
#  'pineville.continuecare.org',
#  'ppgh.com',
#  'pricetransparency.blob.core.windows.net',
#  'prismahealth.org',
#  'res.cloudinary.com',
#  'resources.selectmedical.com',
#  'russellcares.com',
#  's3.amazonaws.com',
#  'saintmarysreno.com',
#  'sanjorgechildrenshospital.com',
#  'scottishriteforchildren.org',
#  'sireading.com',
#  'southtexassurgical.com',
#  'static1.squarespace.com',
#  'sths-org.s3.amazonaws.com',
#  'sundelaware.com',
#  'svhealthcare.org',
#  'tgcaz.org',
#  'thephysicianscentre.com',
#  'trinityhealth.com',
#  'tyler.continuecare.org',
#  'ufhealth.org',
#  'ufhealthjax.org',
#  'uhsfilecdn.eskycity.net',
#  'unmhealth.org',
#  'uvahealth.com',
#  'wexnermedical.osu.edu',
#  'whs.org',
#  'willowcreekbh.com',
#  'wvumedicine.org',
#  'www.adventhealth.com',
#  'www.ahcs.org',
#  'www.alicehyde.com',
#  'www.alliancehealthdurant.com',
#  'www.alliancehealthponcacity.com',
#  'www.alliancehealthwoodward.com',
#  'www.allied-services.org',
#  'www.allinahealth.org',
#  'www.andersonrehabinstitute.com',
#  'www.aspirus.org',
#  'www.atlanticrehabinstitute.com',
#  'www.atriummedicalcenter.com',
#  'www.bakersfieldhearthospital.com',
#  'www.baptistfirst.org',
#  'www.baptistrehab.com',
#  'www.batemanhospital.org',
#  'www.baystatehealth.org',
#  'www.beaumont.org',
#  'www.bellin.org',
#  'www.benefis.org',
#  'www.blythedale.org',
#  'www.bmc.org',
#  'www.bonsecourscommunityhosp.org',
#  'www.braverahealth.com',
#  'www.brgeneral.org',
#  'www.bridgeporthospital.org',
#  'www.browardhealth.org',
#  'www.calvaryhospital.org',
#  'www.capefearvalley.com',
#  'www.carlsbadmedicalcenter.com',
#  'www.casacolina.org',
#  'www.catholicmedicalcenter.org',
#  'www.cchwyo.org',
#  'www.ccmhhealth.com',
#  'www.cedarparkregional.com',
#  'www.cedars-sinai.org',
#  'www.centrahealth.com',
#  'www.centraltexasrehabhospital.com',
#  'www.chghospitals.com',
#  'www.chifranciscanrehabhospital.com',
#  'www.chistalexiushealth.org',
#  'www.chistvincent.com',
#  'www.chkd.org',
#  'www.chla.org',
#  'www.christushealth.org',
#  'www.chsli.org',
#  'www.cityofhope.org',
#  'www.cmhc.org',
#  'www.comhs.org',
#  'www.commonwealthhealth.net',
#  'www.conwaymedicalcenter.com',
#  'www.crescentregionalhospital.com',
#  'www.crestwoodmedcenter.com',
#  'www.crh.org',
#  'www.cvmc.org',
#  'www.cvph.org',
#  'www.davisregional.com',
#  'www.deltahealthsystem.org',
#  'www.detar.com',
#  'www.donalsonvillehospital.org',
#  'www.dukehealth.org',
#  'www.duncanregional.com',
#  'www.dunessurgicalhospital.com',
#  'www.eastgeorgiaregional.com',
#  'www.einstein.edu',
#  'www.elcaminohealth.org',
#  'www.emoryhealthcare.org',
#  'www.exeterhospital.com',
#  'www.flowershospital.com',
#  'www.fourwindshospital.com',
#  'www.fundltcfacility.com',
#  'www.gadsdenregional.com',
#  'www.garnethealth.org',
#  'www.geisinger.org',
#  'www.goodsamhosp.org',
#  'www.grandlakehealth.org',
#  'www.grandviewhealth.com',
#  'www.greenwichhospital.org',
#  'www.healthiertucson.com',
#  'www.healthsourcesaginaw.org',
#  'www.hebrewhealthcare.org',
#  'www.henryford.com',
#  'www.heywood.org',
#  'www.hhc.org',
#  'www.honorhealth.com',
#  'www.idahofallscommunityhospital.com',
#  'www.inova.org',
#  'www.insightsurgicalhospital.com',
#  'www.kch.com',
#  'www.kennedykrieger.org',
#  'www.kindredhospitals.com',
#  'www.knoxvillerehabhospital.com',
#  'www.lakegranburymedicalcenter.com',
#  'www.lancasterrehabhospital.com',
#  'www.laredomedical.com',
#  'www.lexmed.com',
#  'www.lifespan.org',
#  'www.limamemorial.org',
#  'www.lkmc.com',
#  'www.lmhospital.org',
#  'www.lnrmc.com',
#  'www.longviewregional.com',
#  'www.luminishealth.org',
#  'www.luriechildrens.org',
#  'www.lutherandowntownhospital.com',
#  'www.lutheranhospital.com',
#  'www.maderahospital.org',
#  'www.margaretvillehosp.org',
#  'www.marywashingtonhealthcare.com',
#  'www.matsuregional.com',
#  'www.mauryregional.com',
#  'www.mcehospital.com',
#  'www.mclaren.org',
#  'www.melrosewakefield.org',
#  'www.memorialcare.org',
#  'www.memorialhermannkingwood.com',
#  'www.mercyrehabiowacity.com',
#  'www.merithealthbiloxi.com',
#  'www.merithealthcentral.com',
#  'www.merithealthmadison.com',
#  'www.merithealthnatchez.com',
#  'www.merithealthrankin.com',
#  'www.merithealthriveroaks.com',
#  'www.merithealthriverregion.com',
#  'www.merithealthwesley.com',
#  'www.merithealthwomanshospital.com',
#  'www.methodist-rehab.com',
#  'www.methodisthealthsystem.org',
#  'www.midjeffextendedcare.com',
#  'www.milebluff.com',
#  'www.moberlyregionalmedicalcenter.com',
#  'www.mountainviewhospital.org',
#  'www.mountainviewregional.com',
#  'www.myammc.org',
#  'www.mymlc.com',
#  'www.myrgh.org',
#  'www.navarrohospital.com',
#  'www.ncspecialty.com',
#  'www.nermc.com',
#  'www.nicklauschildrens.org',
#  'www.northokaloosa.com',
#  'www.northwesthealth.com',
#  'www.northwestspecialtyhospital.com',
#  'www.novanthealth.org',
#  'www.nwhealthlaporte.com',
#  'www.nwhealthporter.com',
#  'www.nwhealthstarke.com',
#  'www.oakleafsurgical.com',
#  'www.ohiohealth.com',
#  'www.oregon.gov',
#  'www.orlandohealth.com',
#  'www.osfhealthcare.org',
#  'www.osftch.com',
#  'www.owensborohealth.org',
#  'www.palomarhealthrehabinstitute.com',
#  'www.parkview.com',
#  'www.parrishhealthcare.com',
#  'www.pbrmc.com',
#  'www.pennstatehealth.org',
#  'www.physicianshouma.com',
#  'www.physiciansregional.com',
#  'www.piedmont.org',
#  'www.premierhealth.com',
#  'www.rehabhospital.com',
#  'www.rehabhospitalofmontana.com',
#  'www.rehabhospitalri.com',
#  'www.rehabhospitalwi.com',
#  'www.rsfh.com',
#  'www.ruhealth.org',
#  'www.rumcsi.org',
#  'www.rwjbh.org',
#  'www.samedaysurgerycenter.org',
#  'www.seattlechildrens.org',
#  'www.sentara.com',
#  'www.sghs.org',
#  'www.sgmc.org',
#  'www.shorepointhealthcharlotte.com',
#  'www.sierra-view.com',
#  'www.sjchs.org',
#  'www.skagitregionalhealth.org',
#  'www.slhn.org',
#  'www.southbaldwinrmc.com',
#  'www.southcountyhealth.org',
#  'www.southtexassurgicalhospital.com',
#  'www.spartanburgregional.com',
#  'www.srmcfl.com',
#  'www.st-marys.org',
#  'www.stanthonycommunityhosp.org',
#  'www.starrcountyhospital.com',
#  'www.sthspecialtysurgery.com',
#  'www.stjude.org',
#  'www.stmaryrehabilitationhospital.com',
#  'www.stonybrookmedicine.edu',
#  'www.strosenh.org',
#  'www.summahealth.org',
#  'www.sutterhealth.org',
#  'www.templehealth.org',
#  'www.tennovaclarksville.com',
#  'www.tennovacleveland.com',
#  'www.tennovajefferson.com',
#  'www.tennovalafollette.com',
#  'www.tennovanewport.com',
#  'www.tennovanorthknoxville.com',
#  'www.texaschildrens.org',
#  'www.texasrehabarlington.com',
#  'www.texasrehabhospital.com',
#  'www.texasrehabkeller.com',
#  'www.theduponthospital.com',
#  'www.themedcenter.net',
#  'www.theorthohospital.com',
#  'www.uchicagomedicine.org',
#  'www.ucihealth.org',
#  'www.upstate.edu',
#  'www.vailhealth.org',
#  'www.warmc.com',
#  'www.weirtonmedical.com',
#  'www.wellspan.org',
#  'www.wellstar.org',
#  'www.westchestermedicalcenter.org',
#  'www.westerlyhospital.org',
#  'www.whittierhealth.com',
#  'www.woodlandheights.net',
#  'www.wth.org',
#  'www.ynhh.org',
#  'www1.pennmedicine.org'}

# %%
df[df['domain'] == 'encompasshealth.com']['standard_charge_file_url'].tolist()
# Out:
# ['https://encompasshealth.com/-/media/healthsouth/project/healthsouth/files/2023-price-transparency/94-3430783_anmed-health-rehabilitation-hospital_standardcharges.csv',
#  'https://encompasshealth.com/-/media/healthsouth/project/healthsouth/files/2023-price-transparency/04-2948290_fairlawn-rehabilitation-hospital-an-affiliate-of-encompass-health-_standardcharges.csv',
#  'https://encompasshealth.com/-/media/healthsouth/project/healthsouth/files/2023-price-transparency/63-1244181_encompass-health-rehabilitation-hospital-of-spring-hill_standardcharges.csv',
#  'https://encompasshealth.com/-/media/healthsouth/project/healthsouth/files/2023-price-transparency/63-1119356_encompass-health-rehabilitation-hospital-of-panama-city-_standardcharges.csv',
#  'https://encompasshealth.com/-/media/healthsouth/project/healthsouth/files/2023-price-transparency/63-1106107_encompass-health-rehabilitation-hospital-of-montgomery_standardcharges.csv',
#  'https://encompasshealth.com/-/media/healthsouth/project/healthsouth/files/2023-price-transparency/62-1178229_encompass-health-lakeshore-rehabilitation-hospital_standardcharges.csv',
#  'https://encompasshealth.com/-/media/healthsouth/project/healthsouth/files/2023-price-transparency/63-1097851_encompass-health-rehabilitation-hospital-of-dothan_standardcharges.csv',
#  'https://encompasshealth.com/-/media/healthsouth/project/healthsouth/files/2023-price-transparency/63-1280233_regional-rehabilitation-hospital_standardcharges.csv',
#  'https://encompasshealth.com/-/media/healthsouth/project/healthsouth/files/2023-price-transparency/63-1227351_encompass-health-rehabilitation-hospital-of-sewickley_standardcharges.csv',
#  'https://encompasshealth.com/-/media/healthsouth/project/healthsouth/files/2023-price-transparency/63-1105923_encompass-health-rehabilitation-hospital-of-mechanicsburg_standardcharges.csv',
#  'https://encompasshealth.com/-/media/healthsouth/project/healthsouth/files/2023-price-transparency/63-1