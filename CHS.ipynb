# %%
import subprocess

import pandas as pd

# %%
TARGET_COLUMNS = [ 
    'hospital_id',
    #'row_id',
    'line_type',
    'description',
    'rev_code',
    'local_code',
    'code',
    'ms_drg',
    'apr_drg',
    'eapg',
    'hcpcs_cpt',
    'modifiers',
    'alt_hcpcs_cpt',
    'thru',
    'apc',
    'icd',
    'ndc',
    'drug_hcpcs_multiplier',
    'drug_quantity',
    'drug_unit_of_measurement',
    'drug_type_of_measurement',
    'billing_class',
    'setting',
    'payer_category',
    'payer_name',
    'plan_name',
    'standard_charge',
    'standard_charge_percent',
    'contracting_method',
    'additional_generic_notes',
    'additional_payer_specific_notes'
]

# %%
#ccn = "030085"
#url = "https://www.healthiertucson.com/Uploads/Public/Documents/charge-masters/522379881_NW%20Oro%20Valley_standardcharges.csv"
#ccn = "030114"
#url = "https://www.healthiertucson.com/Uploads/Public/Documents/charge-masters/522379881_NW%20Oro%20Valley_standardcharges.csv"
#ccn = "030148"
#url = "https://www.healthiertucson.com/Uploads/Public/Documents/charge-masters/384088744_NW%20Sahuarita_standardcharges.csv"

ccn = "100122"
url = "https://www.northokaloosa.com/Uploads/Public/Documents/charge-masters/650460321_N%20Okaloosa_standardcharges.csv"

filename = url.split("/")[-1].replace("%20", " ")
ein = filename.split("_")[0]
ein = ein[:2] + "-" + ein[2:]
ein
# Out:
# '65-0460321'

# %%
subprocess.run(["wget", "--no-clobber", url, "-O", filename])
# Out:
# File ‘650460321_N Okaloosa_standardcharges.csv’ already there; not retrieving.
# CompletedProcess(args=['wget', '--no-clobber', 'https://www.northokaloosa.com/Uploads/Public/Documents/charge-masters/650460321_N%20Okaloosa_standardcharges.csv', '-O', '650460321_N Okaloosa_standardcharges.csv'], returncode=1)

# %%
df_in = pd.read_csv(filename, dtype={'CPT': str})
df_in
# Out:
#         SVCCD           Description    CPT  Gross Charge As of Date
# 0     1210182   ENOXAPARIN 10MG INJ  J1650        109.75  2/13/2023  \
# 1     1612172      UE-FOREARM 2V CR  73090       1945.18  2/13/2023
# 2     2891819     FEBRILE AGG EA AG  86000         41.53  2/13/2023
# 3     1212723  HYDROXYZI UP TO 25MG  J3410         31.25  2/13/2023
# 4     1693792        S-BX NDL LIVER  47000       2905.76  2/13/2023
# ...       ...                   ...    ...           ...        ...
# 5736      NaN                   NaN    NaN           NaN        NaN
# 5737      NaN                   NaN    NaN           NaN        NaN
# 5738      NaN                   NaN    NaN           NaN        NaN
# 5739      NaN                   NaN    NaN           NaN        NaN
# 5740      NaN                   NaN    NaN           NaN        NaN
#
#       DISCOUNTED CASH PRICE INPATIENT  DISCOUNTED CASH PRICE OUTPATIENT
# 0                             29.6325                           19.7550  \
# 1                            525.1986                          350.1324
# 2                             11.2131                            7.4754
# 3                              8.4375                            5.6250
# 4                            784.5552                          523.0368
# ...                               ...                               ...
# 5736                              NaN                               NaN
# 5737                              NaN                               NaN
# 5738                              NaN                               NaN
# 5739                              NaN                               NaN
# 5740                              NaN                               NaN
#
#      DE-IDENTIFIED MIN  DE-IDENTIFIED MAX
# 0                3.951           44.77800  \
# 1             70.02648          793.63344
# 2              1.49508           16.94424
# 3                1.125           12.75000
# 4            104.60736         1185.55008
# ...                ...                ...
# 5736               NaN                NaN
# 5737               NaN                NaN
# 5738               NaN                NaN
# 5739               NaN                NaN
# 5740                                  NaN
#
#       FL Blue (BCBS) Commercial - All Plans   ...
# 0                                   15.58450  ...  \
# 1                                  276.21556  ...
# 2                                    5.89726  ...
# 3                                    4.43750  ...
# 4                                  412.61792  ...
# ...                                      ...  ...
# 5736                                     NaN  ...
# 5737                                     NaN  ...
# 5738                                     NaN  ...
# 5739                                     NaN  ...
# 5740                                     NaN  ...
#
#       Humana HMO PPO - All Plans   Humana MM - All Plans
# 0                        11.52375                 3.95100  \
# 1                       204.24390                70.02648
# 2                         4.36065                 1.49508
# 3                         3.28125                 1.12500
# 4                       305.10480               104.60736
# ...                           ...                     ...
# 5736                          NaN                     NaN
# 5737                          NaN                     NaN
# 5738                          NaN                     NaN
# 5739                          NaN                     NaN
# 5740                          NaN                     NaN
#
#       Sunshine (incldg fka Wellcare) MM - All Plans
# 0                                            3.95100  \
# 1                                           70.02648
# 2                                            1.49508
# 3                                            1.12500
# 4                                          104.60736
# ...                                              ...
# 5736                                             NaN
# 5737                                             NaN
# 5738                                             NaN
# 5739                                             NaN
# 5740                                             NaN
#
#       Lighthouse MM - All Plans   United MA - All Plans
# 0                        5.26800                  6.5850  \
# 1                       93.36864                116.7108
# 2                        1.99344                  2.4918
# 3                        1.50000                  1.8750
# 4                      139.47648                174.3456
# ...                          ...                     ...
# 5736                         NaN                     NaN
# 5737                         NaN                     NaN
# 5738                         NaN                     NaN
# 5739                         NaN                     NaN
# 5740                         NaN                     NaN
#
#       Humana MA - All Plans   Wellcare MA - All Plans
# 0                    7.35325                   5.70700  \
# 1                  130.32706                 101.14936
# 2                    2.78251                   2.15956
# 3                    2.09375                   1.62500
# 4                  194.68592                 151.09952
# ...                      ...                       ...
# 5736                     NaN                       NaN
# 5737                     NaN                       NaN
# 5738                     NaN                       NaN
# 5739                     NaN                       NaN
# 5740                     NaN                       NaN
#
#       BCBSFL MA - All Plans   Cigna/Healthspring MA - All Plans
# 0                    6.80450                             6.69475  \
# 1                  120.60116                           118.65598
# 2                    2.57486                             2.53333
# 3                    1.93750                             1.90625
# 4                  180.15712                           177.25136
# ...                      ...                                 ...
# 5736                     NaN                                 NaN
# 5737                     NaN                                 NaN
# 5738                     NaN                                 NaN
# 5739                     NaN                                 NaN
# 5740                     NaN                                 NaN
#
#       Multiplan - All Plans
# 0                   18.43800
# 1                  326.79024
# 2                    6.97704
# 3                    5.25000
# 4                  488.16768
# ...                      ...
# 5736                     NaN
# 5737                     NaN
# 5738                     NaN
# 5739                     NaN
# 5740                     NaN
#
# [5741 rows x 24 columns]

# %%
df_mid = pd.DataFrame(df_in)
last_updated = df_mid['As of Date'].to_list()[0]
del df_mid['As of Date']
last_updated
# Out:
# '2/13/2023'

# %%
from dateutil.parser import parse as parse_datetime
last_updated = parse_datetime(last_updated).isoformat().split("T")[0]
last_updated
# Out:
# '2023-02-13'

# %%
df_mid = df_mid.rename(columns={
    'SVCCD': 'local_code',
    'Description': 'description',
    'CPT': 'hcpcs_cpt',
})

df_mid
# Out:
#      local_code           description hcpcs_cpt  Gross Charge
# 0       1210182   ENOXAPARIN 10MG INJ     J1650        109.75  \
# 1       1612172      UE-FOREARM 2V CR     73090       1945.18
# 2       2891819     FEBRILE AGG EA AG     86000         41.53
# 3       1212723  HYDROXYZI UP TO 25MG     J3410         31.25
# 4       1693792        S-BX NDL LIVER     47000       2905.76
# ...         ...                   ...       ...           ...
# 5736        NaN                   NaN       NaN           NaN
# 5737        NaN                   NaN       NaN           NaN
# 5738        NaN                   NaN       NaN           NaN
# 5739        NaN                   NaN       NaN           NaN
# 5740        NaN                   NaN       NaN           NaN
#
#       DISCOUNTED CASH PRICE INPATIENT  DISCOUNTED CASH PRICE OUTPATIENT
# 0                             29.6325                           19.7550  \
# 1                            525.1986                          350.1324
# 2                             11.2131                            7.4754
# 3                              8.4375                            5.6250
# 4                            784.5552                          523.0368
# ...                               ...                               ...
# 5736                              NaN                               NaN
# 5737                              NaN                               NaN
# 5738                              NaN                               NaN
# 5739                              NaN                               NaN
# 5740                              NaN                               NaN
#
#      DE-IDENTIFIED MIN  DE-IDENTIFIED MAX
# 0                3.951           44.77800  \
# 1             70.02648          793.63344
# 2              1.49508           16.94424
# 3                1.125           12.75000
# 4            104.60736         1185.55008
# ...                ...                ...
# 5736               NaN                NaN
# 5737               NaN                NaN
# 5738               NaN                NaN
# 5739               NaN                NaN
# 5740                                  NaN
#
#       FL Blue (BCBS) Commercial - All Plans
# 0                                   15.58450  \
# 1                                  276.21556
# 2                                    5.89726
# 3                                    4.43750
# 4                                  412.61792
# ...                                      ...
# 5736                                     NaN
# 5737                                     NaN
# 5738                                     NaN
# 5739                                     NaN
# 5740                                     NaN
#
#       United Healthcare HMO PPO - All Plans   ...
# 0                                   20.41350  ...  \
# 1                                  361.80348  ...
# 2                                    7.72458  ...
# 3                                    5.81250  ...
# 4                                  540.47136  ...
# ...                                      ...  ...
# 5736                                     NaN  ...
# 5737                                     NaN  ...
# 5738                                     NaN  ...
# 5739                                     NaN  ...
# 5740                                     NaN  ...
#
#       Humana HMO PPO - All Plans   Humana MM - All Plans
# 0                        11.52375                 3.95100  \
# 1                       204.24390                70.02648
# 2                         4.36065                 1.49508
# 3                         3.28125                 1.12500
# 4                       305.10480               104.60736
# ...                           ...                     ...
# 5736                          NaN                     NaN
# 5737                          NaN                     NaN
# 5738                          NaN                     NaN
# 5739                          NaN                     NaN
# 5740                          NaN                     NaN
#
#       Sunshine (incldg fka Wellcare) MM - All Plans
# 0                                            3.95100  \
# 1                                           70.02648
# 2                                            1.49508
# 3                                            1.12500
# 4                                          104.60736
# ...                                              ...
# 5736                                             NaN
# 5737                                             NaN
# 5738                                             NaN
# 5739                                             NaN
# 5740                                             NaN
#
#       Lighthouse MM - All Plans   United MA - All Plans
# 0                        5.26800                  6.5850  \
# 1                       93.36864                116.7108
# 2                        1.99344                  2.4918
# 3                        1.50000                  1.8750
# 4                      139.47648                174.3456
# ...                          ...                     ...
# 5736                         NaN                     NaN
# 5737                         NaN                     NaN
# 5738                         NaN                     NaN
# 5739                         NaN                     NaN
# 5740                         NaN                     NaN
#
#       Humana MA - All Plans   Wellcare MA - All Plans
# 0                    7.35325                   5.70700  \
# 1                  130.32706                 101.14936
# 2                    2.78251                   2.15956
# 3                    2.09375                   1.62500
# 4                  194.68592                 151.09952
# ...                      ...                       ...
# 5736                     NaN                       NaN
# 5737                     NaN                       NaN
# 5738                     NaN                       NaN
# 5739                     NaN                       NaN
# 5740                     NaN                       NaN
#
#       BCBSFL MA - All Plans   Cigna/Healthspring MA - All Plans
# 0                    6.80450                             6.69475  \
# 1                  120.60116                           118.65598
# 2                    2.57486                             2.53333
# 3                    1.93750                             1.90625
# 4                  180.15712                           177.25136
# ...                      ...                                 ...
# 5736                     NaN                                 NaN
# 5737                     NaN                                 NaN
# 5738                     NaN                                 NaN
# 5739                     NaN                                 NaN
# 5740                     NaN                                 NaN
#
#       Multiplan - All Plans
# 0                   18.43800
# 1                  326.79024
# 2                    6.97704
# 3                    5.25000
# 4                  488.16768
# ...                      ...
# 5736                     NaN
# 5737                     NaN
# 5738                     NaN
# 5739                     NaN
# 5740                     NaN
#
# [5741 rows x 23 columns]

# %%
money_columns = df_mid.columns.to_list()[3:]
remaining_columns = df_mid.columns.to_list()[:3]
df_mid = pd.melt(df_mid, id_vars=remaining_columns, var_name='payer_name', value_name='standard_charge')
df_mid
# Out:
#        local_code           description hcpcs_cpt              payer_name
# 0         1210182   ENOXAPARIN 10MG INJ     J1650            Gross Charge  \
# 1         1612172      UE-FOREARM 2V CR     73090            Gross Charge
# 2         2891819     FEBRILE AGG EA AG     86000            Gross Charge
# 3         1212723  HYDROXYZI UP TO 25MG     J3410            Gross Charge
# 4         1693792        S-BX NDL LIVER     47000            Gross Charge
# ...           ...                   ...       ...                     ...
# 114815        NaN                   NaN       NaN  Multiplan - All Plans
# 114816        NaN                   NaN       NaN  Multiplan - All Plans
# 114817        NaN                   NaN       NaN  Multiplan - All Plans
# 114818        NaN                   NaN       NaN  Multiplan - All Plans
# 114819        NaN                   NaN       NaN  Multiplan - All Plans
#
#        standard_charge
# 0               109.75
# 1              1945.18
# 2                41.53
# 3                31.25
# 4              2905.76
# ...                ...
# 114815             NaN
# 114816             NaN
# 114817             NaN
# 114818             NaN
# 114819             NaN
#
# [114820 rows x 5 columns]

# %%
df_mid['hospital_id'] = ccn
df_mid['line_type'] = None
df_mid['rev_code'] = None
df_mid['code'] = None

# %%
df_mid['hcpcs_cpt'] = df_mid['hcpcs_cpt'].astype(str)

df_mid.loc[df_mid['local_code'] == 'DRG', 'ms_drg'] = df_mid[df_mid['local_code'] == 'DRG']['hcpcs_cpt'].str.zfill(3)

df_mid['hcpcs_cpt'] = df_mid['hcpcs_cpt'].apply(lambda cpt: None if type(cpt) == str and len(cpt) < 5 and cpt.isnumeric() else cpt)

df_mid['local_code'] = df_mid['local_code'].fillna('')
df_mid.loc[~df_mid['local_code'].str.isnumeric(), 'line_type'] = df_mid[~df_mid['local_code'].str.isnumeric()]['local_code']
df_mid.loc[~df_mid['local_code'].str.isnumeric(), 'local_code'] = None
df_mid
# Out:
#        local_code           description hcpcs_cpt              payer_name
# 0         1210182   ENOXAPARIN 10MG INJ     J1650            Gross Charge  \
# 1         1612172      UE-FOREARM 2V CR     73090            Gross Charge
# 2         2891819     FEBRILE AGG EA AG     86000            Gross Charge
# 3         1212723  HYDROXYZI UP TO 25MG     J3410            Gross Charge
# 4         1693792        S-BX NDL LIVER     47000            Gross Charge
# ...           ...                   ...       ...                     ...
# 114815       None                   NaN       nan  Multiplan - All Plans
# 114816       None                   NaN       nan  Multiplan - All Plans
# 114817       None                   NaN       nan  Multiplan - All Plans
# 114818       None                   NaN       nan  Multiplan - All Plans
# 114819       None                   NaN       nan  Multiplan - All Plans
#
#        standard_charge hospital_id line_type rev_code  code ms_drg
# 0               109.75      100122      None     None  None    NaN
# 1              1945.18      100122      None     None  None    NaN
# 2                41.53      100122      None     None  None    NaN
# 3                31.25      100122      None     None  None    NaN
# 4              2905.76      100122      None     None  None    NaN
# ...                ...         ...       ...      ...   ...    ...
# 114815             NaN      100122               None  None    NaN
# 114816             NaN      100122               None  None    NaN
# 114817             NaN      100122               None  None    NaN
# 114818             NaN      100122               None  None    NaN
# 114819             NaN      100122               None  None    NaN
#
# [114820 rows x 10 columns]

# %%
df_mid.loc[df_mid['hcpcs_cpt'] == 'SURG', 'hcpcs_cpt'] = None
df_mid.loc[df_mid['hcpcs_cpt'] == 'MANUL', 'hcpcs_cpt'] = None
df_mid.loc[df_mid['hcpcs_cpt'] == 'nan', 'hcpcs_cpt'] = None

# %%
df_mid['apr_drg'] = None
df_mid['eapg'] = None
df_mid['modifiers'] = None
df_mid['alt_hcpcs_cpt'] = None
df_mid['thru'] = None
df_mid['apc'] = None
df_mid['icd'] = None
df_mid['ndc'] = None
df_mid['drug_hcpcs_multiplier'] = None
df_mid['drug_quantity'] = None
df_mid['drug_unit_of_measurement'] = None
df_mid['drug_type_of_measurement'] = None
df_mid['billing_class'] = None

df_mid
# Out:
#        local_code           description hcpcs_cpt              payer_name
# 0         1210182   ENOXAPARIN 10MG INJ     J1650            Gross Charge  \
# 1         1612172      UE-FOREARM 2V CR     73090            Gross Charge
# 2         2891819     FEBRILE AGG EA AG     86000            Gross Charge
# 3         1212723  HYDROXYZI UP TO 25MG     J3410            Gross Charge
# 4         1693792        S-BX NDL LIVER     47000            Gross Charge
# ...           ...                   ...       ...                     ...
# 114815       None                   NaN      None  Multiplan - All Plans
# 114816       None                   NaN      None  Multiplan - All Plans
# 114817       None                   NaN      None  Multiplan - All Plans
# 114818       None                   NaN      None  Multiplan - All Plans
# 114819       None                   NaN      None  Multiplan - All Plans
#
#        standard_charge hospital_id line_type rev_code  code ms_drg  ...
# 0               109.75      100122      None     None  None    NaN  ...  \
# 1              1945.18      100122      None     None  None    NaN  ...
# 2                41.53      100122      None     None  None    NaN  ...
# 3                31.25      100122      None     None  None    NaN  ...
# 4              2905.76      100122      None     None  None    NaN  ...
# ...                ...         ...       ...      ...   ...    ...  ...
# 114815             NaN      100122               None  None    NaN  ...
# 114816             NaN      100122               None  None    NaN  ...
# 114817             NaN      100122               None  None    NaN  ...
# 114818             NaN      100122               None  None    NaN  ...
# 114819             NaN      100122               None  None    NaN  ...
#
#        alt_hcpcs_cpt  thru   apc   icd   ndc drug_hcpcs_multiplier
# 0               None  None  None  None  None                  None  \
# 1               None  None  None  None  None                  None
# 2               None  None  None  None  None                  None
# 3               None  None  None  None  None                  None
# 4               None  None  None  None  None                  None
# ...              ...   ...   ...   ...   ...                   ...
# 114815          None  None  None  None  None                  None
# 114816          None  None  None  None  None                  None
# 114817          None  None  None  None  None                  None
# 114818          None  None  None  None  None                  None
# 114819          None  None  None  None  None                  None
#
#        drug_quantity drug_unit_of_measurement drug_type_of_measurement
# 0               None                     None                     None  \
# 1               None                     None                     None
# 2               None                     None                     None
# 3               None                     None                     None
# 4               None                     None                     None
# ...              ...                      ...                      ...
# 114815          None                     None                     None
# 114816          None                     None                     None
# 114817          None                     None                     None
# 114818          None                     None                     None
# 114819          None                     None                     None
#
#        billing_class
# 0               None
# 1               None
# 2               None
# 3               None
# 4               None
# ...              ...
# 114815          None
# 114816          None
# 114817          None
# 114818          None
# 114819          None
#
# [114820 rows x 23 columns]

# %%
def setting_from_payer_name(payer_name):
    if "INPATIENT" in payer_name:
        return 'inpatient'
    elif "OUTPATIENT" in payer_name:
        return 'outpatient'

    return None

df_mid['setting'] = df_mid['payer_name'].apply(setting_from_payer_name)
df_mid
# Out:
#        local_code           description hcpcs_cpt              payer_name
# 0         1210182   ENOXAPARIN 10MG INJ     J1650            Gross Charge  \
# 1         1612172      UE-FOREARM 2V CR     73090            Gross Charge
# 2         2891819     FEBRILE AGG EA AG     86000            Gross Charge
# 3         1212723  HYDROXYZI UP TO 25MG     J3410            Gross Charge
# 4         1693792        S-BX NDL LIVER     47000            Gross Charge
# ...           ...                   ...       ...                     ...
# 114815       None                   NaN      None  Multiplan - All Plans
# 114816       None                   NaN      None  Multiplan - All Plans
# 114817       None                   NaN      None  Multiplan - All Plans
# 114818       None                   NaN      None  Multiplan - All Plans
# 114819       None                   NaN      None  Multiplan - All Plans
#
#        standard_charge hospital_id line_type rev_code  code ms_drg  ...  thru
# 0               109.75      100122      None     None  None    NaN  ...  None  \
# 1              1945.18      100122      None     None  None    NaN  ...  None
# 2                41.53      100122      None     None  None    NaN  ...  None
# 3                31.25      100122      None     None  None    NaN  ...  None
# 4              2905.76      100122      None     None  None    NaN  ...  None
# ...                ...         ...       ...      ...   ...    ...  ...   ...
# 114815             NaN      100122               None  None    NaN  ...  None
# 114816             NaN      100122               None  None    NaN  ...  None
# 114817             NaN      100122               None  None    NaN  ...  None
# 114818             NaN      100122               None  None    NaN  ...  None
# 114819             NaN      100122               None  None    NaN  ...  None
#
#          apc   icd   ndc drug_hcpcs_multiplier drug_quantity
# 0       None  None  None                  None          None  \
# 1       None  None  None                  None          None
# 2       None  None  None                  None          None
# 3       None  None  None                  None          None
# 4       None  None  None                  None          None
# ...      ...   ...   ...                   ...           ...
# 114815  None  None  None                  None          None
# 114816  None  None  None                  None          None
# 114817  None  None  None                  None          None
# 114818  None  None  None                  None          None
# 114819  None  None  None                  None          None
#
#        drug_unit_of_measurement drug_type_of_measurement billing_class setting
# 0                          None                     None          None    None
# 1                          None                     None          None    None
# 2                          None                     None          None    None
# 3                          None                     None          None    None
# 4                          None                     None          None    None
# ...                         ...                      ...           ...     ...
# 114815                     None                     None          None    None
# 114816                     None                     None          None    None
# 114817                     None                     None          None    None
# 114818                     None                     None          None    None
# 114819                     None                     None          None    None
#
# [114820 rows x 24 columns]

# %%
def payer_category_from_payer_name(payer_name):
    if payer_name == "Gross Charge":
        return 'gross'
    elif payer_name == "DISCOUNTED CASH PRICE INPATIENT" or payer_name == "DISCOUNTED CASH PRICE OUTPATIENT":
        return 'cash'
    elif payer_name == "DE-IDENTIFIED MIN":
        return 'min'
    elif payer_name == "DE-IDENTIFIED MAX":
        return 'max'

    return 'payer'

df_mid['payer_category'] = df_mid['payer_name'].apply(payer_category_from_payer_name)
df_mid
# Out:
#        local_code           description hcpcs_cpt              payer_name
# 0         1210182   ENOXAPARIN 10MG INJ     J1650            Gross Charge  \
# 1         1612172      UE-FOREARM 2V CR     73090            Gross Charge
# 2         2891819     FEBRILE AGG EA AG     86000            Gross Charge
# 3         1212723  HYDROXYZI UP TO 25MG     J3410            Gross Charge
# 4         1693792        S-BX NDL LIVER     47000            Gross Charge
# ...           ...                   ...       ...                     ...
# 114815       None                   NaN      None  Multiplan - All Plans
# 114816       None                   NaN      None  Multiplan - All Plans
# 114817       None                   NaN      None  Multiplan - All Plans
# 114818       None                   NaN      None  Multiplan - All Plans
# 114819       None                   NaN      None  Multiplan - All Plans
#
#        standard_charge hospital_id line_type rev_code  code ms_drg  ...   apc
# 0               109.75      100122      None     None  None    NaN  ...  None  \
# 1              1945.18      100122      None     None  None    NaN  ...  None
# 2                41.53      100122      None     None  None    NaN  ...  None
# 3                31.25      100122      None     None  None    NaN  ...  None
# 4              2905.76      100122      None     None  None    NaN  ...  None
# ...                ...         ...       ...      ...   ...    ...  ...   ...
# 114815             NaN      100122               None  None    NaN  ...  None
# 114816             NaN      100122               None  None    NaN  ...  None
# 114817             NaN      100122               None  None    NaN  ...  None
# 114818             NaN      100122               None  None    NaN  ...  None
# 114819             NaN      100122               None  None    NaN  ...  None
#
#          icd   ndc drug_hcpcs_multiplier drug_quantity
# 0       None  None                  None          None  \
# 1       None  None                  None          None
# 2       None  None                  None          None
# 3       None  None                  None          None
# 4       None  None                  None          None
# ...      ...   ...                   ...           ...
# 114815  None  None                  None          None
# 114816  None  None                  None          None
# 114817  None  None                  None          None
# 114818  None  None                  None          None
# 114819  None  None                  None          None
#
#        drug_unit_of_measurement drug_type_of_measurement billing_class
# 0                          None                     None          None  \
# 1                          None                     None          None
# 2                          None                     None          None
# 3                          None                     None          None
# 4                          None                     None          None
# ...                         ...                      ...           ...
# 114815                     None                     None          None
# 114816                     None                     None          None
# 114817                     None                     None          None
# 114818                     None                     None          None
# 114819                     None                     None          None
#
#        setting payer_category
# 0         None          gross
# 1         None          gross
# 2         None          gross
# 3         None          gross
# 4         None          gross
# ...        ...            ...
# 114815    None          payer
# 114816    None          payer
# 114817    None          payer
# 114818    None          payer
# 114819    None          payer
#
# [114820 rows x 25 columns]

# %%
df_mid['plan_name'] = None
df_mid['standard_charge_percent'] = None
df_mid['contracting_method'] = None
df_mid['additional_generic_notes'] = None
df_mid['additional_payer_specific_notes'] = None

df_mid
# Out:
#        local_code           description hcpcs_cpt              payer_name
# 0         1210182   ENOXAPARIN 10MG INJ     J1650            Gross Charge  \
# 1         1612172      UE-FOREARM 2V CR     73090            Gross Charge
# 2         2891819     FEBRILE AGG EA AG     86000            Gross Charge
# 3         1212723  HYDROXYZI UP TO 25MG     J3410            Gross Charge
# 4         1693792        S-BX NDL LIVER     47000            Gross Charge
# ...           ...                   ...       ...                     ...
# 114815       None                   NaN      None  Multiplan - All Plans
# 114816       None                   NaN      None  Multiplan - All Plans
# 114817       None                   NaN      None  Multiplan - All Plans
# 114818       None                   NaN      None  Multiplan - All Plans
# 114819       None                   NaN      None  Multiplan - All Plans
#
#        standard_charge hospital_id line_type rev_code  code ms_drg  ...
# 0               109.75      100122      None     None  None    NaN  ...  \
# 1              1945.18      100122      None     None  None    NaN  ...
# 2                41.53      100122      None     None  None    NaN  ...
# 3                31.25      100122      None     None  None    NaN  ...
# 4              2905.76      100122      None     None  None    NaN  ...
# ...                ...         ...       ...      ...   ...    ...  ...
# 114815             NaN      100122               None  None    NaN  ...
# 114816             NaN      100122               None  None    NaN  ...
# 114817             NaN      100122               None  None    NaN  ...
# 114818             NaN      100122               None  None    NaN  ...
# 114819             NaN      100122               None  None    NaN  ...
#
#        drug_unit_of_measurement drug_type_of_measurement billing_class
# 0                          None                     None          None  \
# 1                          None                     None          None
# 2                          None                     None          None
# 3                          None                     None          None
# 4                          None                     None          None
# ...                         ...                      ...           ...
# 114815                     None                     None          None
# 114816                     None                     None          None
# 114817                     None                     None          None
# 114818                     None                     None          None
# 114819                     None                     None          None
#
#        setting payer_category plan_name standard_charge_percent
# 0         None          gross      None                    None  \
# 1         None          gross      None                    None
# 2         None          gross      None                    None
# 3         None          gross      None                    None
# 4         None          gross      None                    None
# ...        ...            ...       ...                     ...
# 114815    None          payer      None                    None
# 114816    None          payer      None                    None
# 114817    None          payer      None                    None
# 114818    None          payer      None                    None
# 114819    None          payer      None                    None
#
#        contracting_method additional_generic_notes
# 0                    None                     None  \
# 1                    None                     None
# 2                    None                     None
# 3                    None                     None
# 4                    None                     None
# ...                   ...                      ...
# 114815               None                     None
# 114816               None                     None
# 114817               None                     None
# 114818               None                     None
# 114819               None                     None
#
#        additional_payer_specific_notes
# 0                                 None
# 1                                 None
# 2                                 None
# 3                                 None
# 4                                 None
# ...                                ...
# 114815                            None
# 114816                            None
# 114817                            None
# 114818                            None
# 114819                            None
#
# [114820 rows x 30 columns]

# %%
df_mid = df_mid.dropna(subset=['standard_charge'])
df_mid.shape
# Out:
# (114661, 30)

# %%
df_out = pd.DataFrame(df_mid[TARGET_COLUMNS])
df_out
# Out:
#        hospital_id line_type                   description rev_code
# 0           100122      None           ENOXAPARIN 10MG INJ     None  \
# 1           100122      None              UE-FOREARM 2V CR     None
# 2           100122      None             FEBRILE AGG EA AG     None
# 3           100122      None          HYDROXYZI UP TO 25MG     None
# 4           100122      None                S-BX NDL LIVER     None
# ...            ...       ...                           ...      ...
# 114807      100122      SURG  Ca screen;flexi sigmoidscope     None
# 114808      100122      SURG  Colorectal scrn; hi risk ind     None
# 114809      100122      SURG  Colon ca scrn not hi rsk ind     None
# 114810      100122      SURG     Wound closure by adhesive     None
# 114811      100122      SURG      AVF USE MAGNETIC/ART/VEN     None
#
#        local_code  code ms_drg apr_drg  eapg hcpcs_cpt  ... billing_class
# 0         1210182  None    NaN    None  None     J1650  ...          None  \
# 1         1612172  None    NaN    None  None     73090  ...          None
# 2         2891819  None    NaN    None  None     86000  ...          None
# 3         1212723  None    NaN    None  None     J3410  ...          None
# 4         1693792  None    NaN    None  None     47000  ...          None
# ...           ...   ...    ...     ...   ...       ...  ...           ...
# 114807       None  None    NaN    None  None     G0104  ...          None
# 114808       None  None    NaN    None  None     G0105  ...          None
# 114809       None  None    NaN    None  None     G0121  ...          None
# 114810       None  None    NaN    None  None     G0168  ...          None
# 114811       None  None    NaN    None  None     G2171  ...          None
#
#        setting payer_category              payer_name plan_name
# 0         None          gross            Gross Charge      None  \
# 1         None          gross            Gross Charge      None
# 2         None          gross            Gross Charge      None
# 3         None          gross            Gross Charge      None
# 4         None          gross            Gross Charge      None
# ...        ...            ...                     ...       ...
# 114807    None          payer  Multiplan - All Plans       None
# 114808    None          payer  Multiplan - All Plans       None
# 114809    None          payer  Multiplan - All Plans       None
# 114810    None          payer  Multiplan - All Plans       None
# 114811    None          payer  Multiplan - All Plans       None
#
#        standard_charge standard_charge_percent contracting_method
# 0               109.75                    None               None  \
# 1              1945.18                    None               None
# 2                41.53                    None               None
# 3                31.25                    None               None
# 4              2905.76                    None               None
# ...                ...                     ...                ...
# 114807      2770.50732                    None               None
# 114808     3249.651006                    None               None
# 114809     3204.677556                    None               None
# 114810         336.924                    None               None
# 114811      16350.5076                    None               None
#
#        additional_generic_notes additional_payer_specific_notes
# 0                          None                            None
# 1                          None                            None
# 2                          None                            None
# 3                          None                            None
# 4                          None                            None
# ...                         ...                             ...
# 114807                     None                            None
# 114808                     None                            None
# 114809                     None                            None
# 114810                     None                            None
# 114811                     None                            None
#
# [114661 rows x 30 columns]

# %%
df_out.to_csv('rate_' + ccn + '.csv', index=False)
