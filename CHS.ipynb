# %%
import subprocess

import pandas as pd

# %%
TARGET_COLUMNS = [ 
    'hospital_id',
    #'row_id',
    'line_type',
    'description',
    'rev_code',
    'local_code',
    'code',
    'ms_drg',
    'apr_drg',
    'eapg',
    'hcpcs_cpt',
    'modifiers',
    'alt_hcpcs_cpt',
    'thru',
    'apc',
    'icd',
    'ndc',
    'drug_hcpcs_multiplier',
    'drug_quantity',
    'drug_unit_of_measurement',
    'drug_type_of_measurement',
    'billing_class',
    'setting',
    'payer_category',
    'payer_name',
    'plan_name',
    'standard_charge',
    'standard_charge_percent',
    'contracting_method',
    'additional_generic_notes',
    'additional_payer_specific_notes'
]

# %%
#ccn = "030085"
#url = "https://www.healthiertucson.com/Uploads/Public/Documents/charge-masters/522379881_NW%20Oro%20Valley_standardcharges.csv"
#ccn = "030114"
#url = "https://www.healthiertucson.com/Uploads/Public/Documents/charge-masters/522379881_NW%20Oro%20Valley_standardcharges.csv"
#ccn = "030148"
#url = "https://www.healthiertucson.com/Uploads/Public/Documents/charge-masters/384088744_NW%20Sahuarita_standardcharges.csv"

#ccn = "100122"
#url = "https://www.northokaloosa.com/Uploads/Public/Documents/charge-masters/650460321_N%20Okaloosa_standardcharges.csv"

ccn = "370006"
url = "https://www.alliancehealthponcacity.com/Uploads/Public/Documents/charge-masters/204052936_Alliance%20Ponca%20City_standardcharges.csv"

filename = url.split("/")[-1].replace("%20", " ")
ein = filename.split("_")[0]
ein = ein[:2] + "-" + ein[2:]
ein
# Out:
# '20-4052936'

# %%
subprocess.run(["wget", "--no-clobber", url, "-O", filename])
# Out:
# File ‘204052936_Alliance Ponca City_standardcharges.csv’ already there; not retrieving.
# CompletedProcess(args=['wget', '--no-clobber', 'https://www.alliancehealthponcacity.com/Uploads/Public/Documents/charge-masters/204052936_Alliance%20Ponca%20City_standardcharges.csv', '-O', '204052936_Alliance Ponca City_standardcharges.csv'], returncode=1)

# %%
df_in = pd.read_csv(filename, dtype={'CPT': str})
df_in
# Out:
#            SVCCD                     Description       CPT  Gross Charge
# 0     2600636.00  INIT HYDRATION 31 MIN-1 HR m/s  96360.00        521.00  \
# 1     2603636.00    ADD HR HYDRATION >30 MIN m/s  96361.00        167.00
# 2     2603736.00     INTRAMUSCULAR/SUBCU INJ m/s  96372.00        218.00
# 3     2604736.00             INITIAL IV PUSH m/s  96374.00        521.00
# 4     2605736.00  ADDIT IV PUSH/NEW SUBSTANCE ms  96375.00        235.00
# ...          ...                             ...       ...           ...
# 3543        SURG      Cardioversion electric ext  92960.00      13172.28
# 3544        SURG     Airway inhalation treatment  94640.00      19260.61
# 3545        SURG    Colorectal scrn; hi risk ind     G0105      16012.90
# 3546        SURG    Colon ca scrn not hi rsk ind     G0121      15186.57
# 3547        SURG    Inj for sacroiliac jt anesth     G0260       4597.70
#
#       As of Date  DISCOUNTED CASH PRICE INPATIENT
# 0        44588.0                           286.55  \
# 1        44588.0                            91.85
# 2        44588.0                           119.90
# 3        44588.0                           286.55
# 4        44588.0                           129.25
# ...          ...                              ...
# 3543     44588.0                          7244.75
# 3544     44588.0                         10593.34
# 3545     44588.0                          8807.10
# 3546     44588.0                          8352.61
# 3547     44588.0                          2528.74
#
#       DISCOUNTED CASH PRICE OUTPATIENT  DE-IDENTIFIED MIN  DE-IDENTIFIED MAX
# 0                               182.35              57.78             331.93  \
# 1                                58.45              18.52             106.40
# 2                                76.30              24.18             138.89
# 3                               182.35              57.78             331.93
# 4                                82.25              26.06             149.72
# ...                                ...                ...                ...
# 3543                           4610.30            1460.81            8392.06
# 3544                           6741.21            2136.00           12270.93
# 3545                           5604.52            1775.83           10201.82
# 3546                           5315.30            1684.19            9675.37
# 3547                           1609.20             509.89            2929.20
#
#       BCBS of Oklahoma  United Healthcare  Aetna / Coventry  Cigna Healthcare
# 0                108.9             223.51            228.72            331.88  \
# 1                 34.9              71.64             73.31            106.38
# 2                 45.6              93.52             95.70            138.87
# 3                108.9             223.51            228.72            331.88
# 4                 49.1             100.82            103.17            149.70
# ...                ...                ...               ...               ...
# 3543            2753.0            5650.91           5782.63           8390.74
# 3544            4025.5            8262.80           8455.41          12269.01
# 3545            3346.7            6869.54           7029.66          10200.22
# 3546            3174.0            6515.04           6666.91           9673.85
# 3547             960.9            1972.41           2018.39           2928.74
#
#       HUMANA MCR  AETNA MCR  UHC MCR  HealthChoice (State Govt.)
# 0          57.83      62.52    68.77                      117.75
# 1          18.54      20.04    22.04                       37.74
# 2          24.20      26.16    28.78                       49.27
# 3          57.83      62.52    68.77                      117.75
# 4          26.09      28.20    31.02                       53.11
# ...          ...        ...      ...                         ...
# 3543     1462.12    1580.67  1738.74                     2976.93
# 3544     2137.93    2311.27  2542.40                     4352.90
# 3545     1777.43    1921.55  2113.70                     3618.92
# 3546     1685.71    1822.39  2004.63                     3432.17
# 3547      510.34     551.72   606.90                     1039.08
#
# [3548 rows x 17 columns]

# %%
df_mid = pd.DataFrame(df_in)
last_updated = df_mid['As of Date'].to_list()[0]
del df_mid['As of Date']
last_updated
# Out:
# 44588.0

# %%
df_mid = df_mid.rename(columns={
    'SVCCD': 'local_code',
    'Description': 'description',
    'CPT': 'hcpcs_cpt',
})

df_mid
# Out:
#       local_code                     description hcpcs_cpt  Gross Charge
# 0     2600636.00  INIT HYDRATION 31 MIN-1 HR m/s  96360.00        521.00  \
# 1     2603636.00    ADD HR HYDRATION >30 MIN m/s  96361.00        167.00
# 2     2603736.00     INTRAMUSCULAR/SUBCU INJ m/s  96372.00        218.00
# 3     2604736.00             INITIAL IV PUSH m/s  96374.00        521.00
# 4     2605736.00  ADDIT IV PUSH/NEW SUBSTANCE ms  96375.00        235.00
# ...          ...                             ...       ...           ...
# 3543        SURG      Cardioversion electric ext  92960.00      13172.28
# 3544        SURG     Airway inhalation treatment  94640.00      19260.61
# 3545        SURG    Colorectal scrn; hi risk ind     G0105      16012.90
# 3546        SURG    Colon ca scrn not hi rsk ind     G0121      15186.57
# 3547        SURG    Inj for sacroiliac jt anesth     G0260       4597.70
#
#       DISCOUNTED CASH PRICE INPATIENT  DISCOUNTED CASH PRICE OUTPATIENT
# 0                              286.55                            182.35  \
# 1                               91.85                             58.45
# 2                              119.90                             76.30
# 3                              286.55                            182.35
# 4                              129.25                             82.25
# ...                               ...                               ...
# 3543                          7244.75                           4610.30
# 3544                         10593.34                           6741.21
# 3545                          8807.10                           5604.52
# 3546                          8352.61                           5315.30
# 3547                          2528.74                           1609.20
#
#       DE-IDENTIFIED MIN  DE-IDENTIFIED MAX  BCBS of Oklahoma
# 0                 57.78             331.93             108.9  \
# 1                 18.52             106.40              34.9
# 2                 24.18             138.89              45.6
# 3                 57.78             331.93             108.9
# 4                 26.06             149.72              49.1
# ...                 ...                ...               ...
# 3543            1460.81            8392.06            2753.0
# 3544            2136.00           12270.93            4025.5
# 3545            1775.83           10201.82            3346.7
# 3546            1684.19            9675.37            3174.0
# 3547             509.89            2929.20             960.9
#
#       United Healthcare  Aetna / Coventry  Cigna Healthcare  HUMANA MCR
# 0                223.51            228.72            331.88       57.83  \
# 1                 71.64             73.31            106.38       18.54
# 2                 93.52             95.70            138.87       24.20
# 3                223.51            228.72            331.88       57.83
# 4                100.82            103.17            149.70       26.09
# ...                 ...               ...               ...         ...
# 3543            5650.91           5782.63           8390.74     1462.12
# 3544            8262.80           8455.41          12269.01     2137.93
# 3545            6869.54           7029.66          10200.22     1777.43
# 3546            6515.04           6666.91           9673.85     1685.71
# 3547            1972.41           2018.39           2928.74      510.34
#
#       AETNA MCR  UHC MCR  HealthChoice (State Govt.)
# 0         62.52    68.77                      117.75
# 1         20.04    22.04                       37.74
# 2         26.16    28.78                       49.27
# 3         62.52    68.77                      117.75
# 4         28.20    31.02                       53.11
# ...         ...      ...                         ...
# 3543    1580.67  1738.74                     2976.93
# 3544    2311.27  2542.40                     4352.90
# 3545    1921.55  2113.70                     3618.92
# 3546    1822.39  2004.63                     3432.17
# 3547     551.72   606.90                     1039.08
#
# [3548 rows x 16 columns]

# %%
from helpers import cleanup_dollar_value     

money_columns = df_mid.columns.to_list()[3:]
remaining_columns = df_mid.columns.to_list()[:3]
df_mid = pd.melt(df_mid, id_vars=remaining_columns, var_name='payer_name', value_name='standard_charge')
df_mid['standard_charge'] = df_mid['standard_charge'].apply(cleanup_dollar_value)
df_mid
# Out:
#        local_code                     description hcpcs_cpt
# 0      2600636.00  INIT HYDRATION 31 MIN-1 HR m/s  96360.00  \
# 1      2603636.00    ADD HR HYDRATION >30 MIN m/s  96361.00
# 2      2603736.00     INTRAMUSCULAR/SUBCU INJ m/s  96372.00
# 3      2604736.00             INITIAL IV PUSH m/s  96374.00
# 4      2605736.00  ADDIT IV PUSH/NEW SUBSTANCE ms  96375.00
# ...           ...                             ...       ...
# 46119        SURG      Cardioversion electric ext  92960.00
# 46120        SURG     Airway inhalation treatment  94640.00
# 46121        SURG    Colorectal scrn; hi risk ind     G0105
# 46122        SURG    Colon ca scrn not hi rsk ind     G0121
# 46123        SURG    Inj for sacroiliac jt anesth     G0260
#
#                        payer_name  standard_charge
# 0                    Gross Charge           521.00
# 1                    Gross Charge           167.00
# 2                    Gross Charge           218.00
# 3                    Gross Charge           521.00
# 4                    Gross Charge           235.00
# ...                           ...              ...
# 46119  HealthChoice (State Govt.)          2976.93
# 46120  HealthChoice (State Govt.)          4352.90
# 46121  HealthChoice (State Govt.)          3618.92
# 46122  HealthChoice (State Govt.)          3432.17
# 46123  HealthChoice (State Govt.)          1039.08
#
# [46124 rows x 5 columns]

# %%
df_mid['hospital_id'] = ccn
df_mid['line_type'] = None
df_mid['rev_code'] = None
df_mid['code'] = None

# %%
df_mid['hcpcs_cpt'] = df_mid['hcpcs_cpt'].astype(str)

df_mid.loc[df_mid['local_code'] == 'DRG', 'ms_drg'] = df_mid[df_mid['local_code'] == 'DRG']['hcpcs_cpt'].str.zfill(3)
df_mid['ms_drg'] = df_mid['ms_drg'].apply(lambda ms_drg: ms_drg.replace(".00", "").zfill(3) if type(ms_drg) == str and ms_drg.endswith(".00") else ms_drg)

# https://www.alliancehealthponcacity.com/Uploads/Public/Documents/charge-masters/204052936_Alliance%20Ponca%20City_standardcharges.csv
df_mid['hcpcs_cpt'] = df_mid['hcpcs_cpt'].apply(lambda cpt: cpt.replace(".00", "") if type(cpt) == str and cpt.endswith(".00") else cpt)
df_mid['hcpcs_cpt'] = df_mid['hcpcs_cpt'].apply(lambda cpt: None if type(cpt) == str and len(cpt) < 5 and cpt.isnumeric() else cpt)
df_mid.loc[df_mid['hcpcs_cpt'] == '0', 'hcpcs_cpt'] = None

df_mid['local_code'] = df_mid['local_code'].fillna('')
df_mid['local_code'] = df_mid['local_code'].apply(
    lambda local_code: local_code.replace(".00", "") if type(local_code) == str and local_code.endswith(".00") else local_code
)
df_mid.loc[~df_mid['local_code'].str.isnumeric(), 'line_type'] = df_mid[~df_mid['local_code'].str.isnumeric()]['local_code']
df_mid.loc[~df_mid['local_code'].str.isnumeric(), 'local_code'] = None
df_mid
# Out:
#       local_code                     description hcpcs_cpt
# 0        2600636  INIT HYDRATION 31 MIN-1 HR m/s     96360  \
# 1        2603636    ADD HR HYDRATION >30 MIN m/s     96361
# 2        2603736     INTRAMUSCULAR/SUBCU INJ m/s     96372
# 3        2604736             INITIAL IV PUSH m/s     96374
# 4        2605736  ADDIT IV PUSH/NEW SUBSTANCE ms     96375
# ...          ...                             ...       ...
# 46119       None      Cardioversion electric ext     92960
# 46120       None     Airway inhalation treatment     94640
# 46121       None    Colorectal scrn; hi risk ind     G0105
# 46122       None    Colon ca scrn not hi rsk ind     G0121
# 46123       None    Inj for sacroiliac jt anesth     G0260
#
#                        payer_name  standard_charge hospital_id line_type
# 0                    Gross Charge           521.00      370006      None  \
# 1                    Gross Charge           167.00      370006      None
# 2                    Gross Charge           218.00      370006      None
# 3                    Gross Charge           521.00      370006      None
# 4                    Gross Charge           235.00      370006      None
# ...                           ...              ...         ...       ...
# 46119  HealthChoice (State Govt.)          2976.93      370006      SURG
# 46120  HealthChoice (State Govt.)          4352.90      370006      SURG
# 46121  HealthChoice (State Govt.)          3618.92      370006      SURG
# 46122  HealthChoice (State Govt.)          3432.17      370006      SURG
# 46123  HealthChoice (State Govt.)          1039.08      370006      SURG
#
#       rev_code  code ms_drg
# 0         None  None    NaN
# 1         None  None    NaN
# 2         None  None    NaN
# 3         None  None    NaN
# 4         None  None    NaN
# ...        ...   ...    ...
# 46119     None  None    NaN
# 46120     None  None    NaN
# 46121     None  None    NaN
# 46122     None  None    NaN
# 46123     None  None    NaN
#
# [46124 rows x 10 columns]

# %%
df_mid.loc[df_mid['hcpcs_cpt'] == 'SURG', 'hcpcs_cpt'] = None
df_mid.loc[df_mid['hcpcs_cpt'] == 'MANUL', 'hcpcs_cpt'] = None
df_mid.loc[df_mid['hcpcs_cpt'] == 'nan', 'hcpcs_cpt'] = None

# %%
df_mid['apr_drg'] = None
df_mid['eapg'] = None
df_mid['modifiers'] = None
df_mid['alt_hcpcs_cpt'] = None
df_mid['thru'] = None
df_mid['apc'] = None
df_mid['icd'] = None
df_mid['ndc'] = None
df_mid['drug_hcpcs_multiplier'] = None
df_mid['drug_quantity'] = None
df_mid['drug_unit_of_measurement'] = None
df_mid['drug_type_of_measurement'] = None
df_mid['billing_class'] = None

df_mid
# Out:
#       local_code                     description hcpcs_cpt
# 0        2600636  INIT HYDRATION 31 MIN-1 HR m/s     96360  \
# 1        2603636    ADD HR HYDRATION >30 MIN m/s     96361
# 2        2603736     INTRAMUSCULAR/SUBCU INJ m/s     96372
# 3        2604736             INITIAL IV PUSH m/s     96374
# 4        2605736  ADDIT IV PUSH/NEW SUBSTANCE ms     96375
# ...          ...                             ...       ...
# 46119       None      Cardioversion electric ext     92960
# 46120       None     Airway inhalation treatment     94640
# 46121       None    Colorectal scrn; hi risk ind     G0105
# 46122       None    Colon ca scrn not hi rsk ind     G0121
# 46123       None    Inj for sacroiliac jt anesth     G0260
#
#                        payer_name  standard_charge hospital_id line_type
# 0                    Gross Charge           521.00      370006      None  \
# 1                    Gross Charge           167.00      370006      None
# 2                    Gross Charge           218.00      370006      None
# 3                    Gross Charge           521.00      370006      None
# 4                    Gross Charge           235.00      370006      None
# ...                           ...              ...         ...       ...
# 46119  HealthChoice (State Govt.)          2976.93      370006      SURG
# 46120  HealthChoice (State Govt.)          4352.90      370006      SURG
# 46121  HealthChoice (State Govt.)          3618.92      370006      SURG
# 46122  HealthChoice (State Govt.)          3432.17      370006      SURG
# 46123  HealthChoice (State Govt.)          1039.08      370006      SURG
#
#       rev_code  code ms_drg  ... alt_hcpcs_cpt  thru   apc   icd   ndc
# 0         None  None    NaN  ...          None  None  None  None  None  \
# 1         None  None    NaN  ...          None  None  None  None  None
# 2         None  None    NaN  ...          None  None  None  None  None
# 3         None  None    NaN  ...          None  None  None  None  None
# 4         None  None    NaN  ...          None  None  None  None  None
# ...        ...   ...    ...  ...           ...   ...   ...   ...   ...
# 46119     None  None    NaN  ...          None  None  None  None  None
# 46120     None  None    NaN  ...          None  None  None  None  None
# 46121     None  None    NaN  ...          None  None  None  None  None
# 46122     None  None    NaN  ...          None  None  None  None  None
# 46123     None  None    NaN  ...          None  None  None  None  None
#
#       drug_hcpcs_multiplier drug_quantity drug_unit_of_measurement
# 0                      None          None                     None  \
# 1                      None          None                     None
# 2                      None          None                     None
# 3                      None          None                     None
# 4                      None          None                     None
# ...                     ...           ...                      ...
# 46119                  None          None                     None
# 46120                  None          None                     None
# 46121                  None          None                     None
# 46122                  None          None                     None
# 46123                  None          None                     None
#
#       drug_type_of_measurement billing_class
# 0                         None          None
# 1                         None          None
# 2                         None          None
# 3                         None          None
# 4                         None          None
# ...                        ...           ...
# 46119                     None          None
# 46120                     None          None
# 46121                     None          None
# 46122                     None          None
# 46123                     None          None
#
# [46124 rows x 23 columns]

# %%
def setting_from_payer_name(payer_name):
    if "INPATIENT" in payer_name:
        return 'inpatient'
    elif "OUTPATIENT" in payer_name:
        return 'outpatient'

    return None

df_mid['setting'] = df_mid['payer_name'].apply(setting_from_payer_name)
df_mid
# Out:
#       local_code                     description hcpcs_cpt
# 0        2600636  INIT HYDRATION 31 MIN-1 HR m/s     96360  \
# 1        2603636    ADD HR HYDRATION >30 MIN m/s     96361
# 2        2603736     INTRAMUSCULAR/SUBCU INJ m/s     96372
# 3        2604736             INITIAL IV PUSH m/s     96374
# 4        2605736  ADDIT IV PUSH/NEW SUBSTANCE ms     96375
# ...          ...                             ...       ...
# 46119       None      Cardioversion electric ext     92960
# 46120       None     Airway inhalation treatment     94640
# 46121       None    Colorectal scrn; hi risk ind     G0105
# 46122       None    Colon ca scrn not hi rsk ind     G0121
# 46123       None    Inj for sacroiliac jt anesth     G0260
#
#                        payer_name  standard_charge hospital_id line_type
# 0                    Gross Charge           521.00      370006      None  \
# 1                    Gross Charge           167.00      370006      None
# 2                    Gross Charge           218.00      370006      None
# 3                    Gross Charge           521.00      370006      None
# 4                    Gross Charge           235.00      370006      None
# ...                           ...              ...         ...       ...
# 46119  HealthChoice (State Govt.)          2976.93      370006      SURG
# 46120  HealthChoice (State Govt.)          4352.90      370006      SURG
# 46121  HealthChoice (State Govt.)          3618.92      370006      SURG
# 46122  HealthChoice (State Govt.)          3432.17      370006      SURG
# 46123  HealthChoice (State Govt.)          1039.08      370006      SURG
#
#       rev_code  code ms_drg  ...  thru   apc   icd   ndc
# 0         None  None    NaN  ...  None  None  None  None  \
# 1         None  None    NaN  ...  None  None  None  None
# 2         None  None    NaN  ...  None  None  None  None
# 3         None  None    NaN  ...  None  None  None  None
# 4         None  None    NaN  ...  None  None  None  None
# ...        ...   ...    ...  ...   ...   ...   ...   ...
# 46119     None  None    NaN  ...  None  None  None  None
# 46120     None  None    NaN  ...  None  None  None  None
# 46121     None  None    NaN  ...  None  None  None  None
# 46122     None  None    NaN  ...  None  None  None  None
# 46123     None  None    NaN  ...  None  None  None  None
#
#       drug_hcpcs_multiplier drug_quantity drug_unit_of_measurement
# 0                      None          None                     None  \
# 1                      None          None                     None
# 2                      None          None                     None
# 3                      None          None                     None
# 4                      None          None                     None
# ...                     ...           ...                      ...
# 46119                  None          None                     None
# 46120                  None          None                     None
# 46121                  None          None                     None
# 46122                  None          None                     None
# 46123                  None          None                     None
#
#       drug_type_of_measurement billing_class setting
# 0                         None          None    None
# 1                         None          None    None
# 2                         None          None    None
# 3                         None          None    None
# 4                         None          None    None
# ...                        ...           ...     ...
# 46119                     None          None    None
# 46120                     None          None    None
# 46121                     None          None    None
# 46122                     None          None    None
# 46123                     None          None    None
#
# [46124 rows x 24 columns]

# %%
def payer_category_from_payer_name(payer_name):
    if payer_name == "Gross Charge":
        return 'gross'
    elif payer_name == "DISCOUNTED CASH PRICE INPATIENT" or payer_name == "DISCOUNTED CASH PRICE OUTPATIENT":
        return 'cash'
    elif payer_name == "DE-IDENTIFIED MIN":
        return 'min'
    elif payer_name == "DE-IDENTIFIED MAX":
        return 'max'

    return 'payer'

df_mid['payer_category'] = df_mid['payer_name'].apply(payer_category_from_payer_name)
df_mid
# Out:
#       local_code                     description hcpcs_cpt
# 0        2600636  INIT HYDRATION 31 MIN-1 HR m/s     96360  \
# 1        2603636    ADD HR HYDRATION >30 MIN m/s     96361
# 2        2603736     INTRAMUSCULAR/SUBCU INJ m/s     96372
# 3        2604736             INITIAL IV PUSH m/s     96374
# 4        2605736  ADDIT IV PUSH/NEW SUBSTANCE ms     96375
# ...          ...                             ...       ...
# 46119       None      Cardioversion electric ext     92960
# 46120       None     Airway inhalation treatment     94640
# 46121       None    Colorectal scrn; hi risk ind     G0105
# 46122       None    Colon ca scrn not hi rsk ind     G0121
# 46123       None    Inj for sacroiliac jt anesth     G0260
#
#                        payer_name  standard_charge hospital_id line_type
# 0                    Gross Charge           521.00      370006      None  \
# 1                    Gross Charge           167.00      370006      None
# 2                    Gross Charge           218.00      370006      None
# 3                    Gross Charge           521.00      370006      None
# 4                    Gross Charge           235.00      370006      None
# ...                           ...              ...         ...       ...
# 46119  HealthChoice (State Govt.)          2976.93      370006      SURG
# 46120  HealthChoice (State Govt.)          4352.90      370006      SURG
# 46121  HealthChoice (State Govt.)          3618.92      370006      SURG
# 46122  HealthChoice (State Govt.)          3432.17      370006      SURG
# 46123  HealthChoice (State Govt.)          1039.08      370006      SURG
#
#       rev_code  code ms_drg  ...   apc   icd   ndc drug_hcpcs_multiplier
# 0         None  None    NaN  ...  None  None  None                  None  \
# 1         None  None    NaN  ...  None  None  None                  None
# 2         None  None    NaN  ...  None  None  None                  None
# 3         None  None    NaN  ...  None  None  None                  None
# 4         None  None    NaN  ...  None  None  None                  None
# ...        ...   ...    ...  ...   ...   ...   ...                   ...
# 46119     None  None    NaN  ...  None  None  None                  None
# 46120     None  None    NaN  ...  None  None  None                  None
# 46121     None  None    NaN  ...  None  None  None                  None
# 46122     None  None    NaN  ...  None  None  None                  None
# 46123     None  None    NaN  ...  None  None  None                  None
#
#       drug_quantity drug_unit_of_measurement drug_type_of_measurement
# 0              None                     None                     None  \
# 1              None                     None                     None
# 2              None                     None                     None
# 3              None                     None                     None
# 4              None                     None                     None
# ...             ...                      ...                      ...
# 46119          None                     None                     None
# 46120          None                     None                     None
# 46121          None                     None                     None
# 46122          None                     None                     None
# 46123          None                     None                     None
#
#       billing_class setting payer_category
# 0              None    None          gross
# 1              None    None          gross
# 2              None    None          gross
# 3              None    None          gross
# 4              None    None          gross
# ...             ...     ...            ...
# 46119          None    None          payer
# 46120          None    None          payer
# 46121          None    None          payer
# 46122          None    None          payer
# 46123          None    None          payer
#
# [46124 rows x 25 columns]

# %%
df_mid['plan_name'] = None
df_mid['standard_charge_percent'] = None
df_mid['contracting_method'] = None
df_mid['additional_generic_notes'] = None
df_mid['additional_payer_specific_notes'] = None

df_mid
# Out:
#       local_code                     description hcpcs_cpt
# 0        2600636  INIT HYDRATION 31 MIN-1 HR m/s     96360  \
# 1        2603636    ADD HR HYDRATION >30 MIN m/s     96361
# 2        2603736     INTRAMUSCULAR/SUBCU INJ m/s     96372
# 3        2604736             INITIAL IV PUSH m/s     96374
# 4        2605736  ADDIT IV PUSH/NEW SUBSTANCE ms     96375
# ...          ...                             ...       ...
# 46119       None      Cardioversion electric ext     92960
# 46120       None     Airway inhalation treatment     94640
# 46121       None    Colorectal scrn; hi risk ind     G0105
# 46122       None    Colon ca scrn not hi rsk ind     G0121
# 46123       None    Inj for sacroiliac jt anesth     G0260
#
#                        payer_name  standard_charge hospital_id line_type
# 0                    Gross Charge           521.00      370006      None  \
# 1                    Gross Charge           167.00      370006      None
# 2                    Gross Charge           218.00      370006      None
# 3                    Gross Charge           521.00      370006      None
# 4                    Gross Charge           235.00      370006      None
# ...                           ...              ...         ...       ...
# 46119  HealthChoice (State Govt.)          2976.93      370006      SURG
# 46120  HealthChoice (State Govt.)          4352.90      370006      SURG
# 46121  HealthChoice (State Govt.)          3618.92      370006      SURG
# 46122  HealthChoice (State Govt.)          3432.17      370006      SURG
# 46123  HealthChoice (State Govt.)          1039.08      370006      SURG
#
#       rev_code  code ms_drg  ... drug_unit_of_measurement
# 0         None  None    NaN  ...                     None  \
# 1         None  None    NaN  ...                     None
# 2         None  None    NaN  ...                     None
# 3         None  None    NaN  ...                     None
# 4         None  None    NaN  ...                     None
# ...        ...   ...    ...  ...                      ...
# 46119     None  None    NaN  ...                     None
# 46120     None  None    NaN  ...                     None
# 46121     None  None    NaN  ...                     None
# 46122     None  None    NaN  ...                     None
# 46123     None  None    NaN  ...                     None
#
#       drug_type_of_measurement billing_class setting payer_category plan_name
# 0                         None          None    None          gross      None  \
# 1                         None          None    None          gross      None
# 2                         None          None    None          gross      None
# 3                         None          None    None          gross      None
# 4                         None          None    None          gross      None
# ...                        ...           ...     ...            ...       ...
# 46119                     None          None    None          payer      None
# 46120                     None          None    None          payer      None
# 46121                     None          None    None          payer      None
# 46122                     None          None    None          payer      None
# 46123                     None          None    None          payer      None
#
#       standard_charge_percent contracting_method additional_generic_notes
# 0                        None               None                     None  \
# 1                        None               None                     None
# 2                        None               None                     None
# 3                        None               None                     None
# 4                        None               None                     None
# ...                       ...                ...                      ...
# 46119                    None               None                     None
# 46120                    None               None                     None
# 46121                    None               None                     None
# 46122                    None               None                     None
# 46123                    None               None                     None
#
#       additional_payer_specific_notes
# 0                                None
# 1                                None
# 2                                None
# 3                                None
# 4                                None
# ...                               ...
# 46119                            None
# 46120                            None
# 46121                            None
# 46122                            None
# 46123                            None
#
# [46124 rows x 30 columns]

# %%
df_mid = df_mid.dropna(subset=['standard_charge'])
df_mid.shape
# Out:
# (46124, 30)

# %%
df_out = pd.DataFrame(df_mid[TARGET_COLUMNS])
df_out
# Out:
#       hospital_id line_type                     description rev_code
# 0          370006      None  INIT HYDRATION 31 MIN-1 HR m/s     None  \
# 1          370006      None    ADD HR HYDRATION >30 MIN m/s     None
# 2          370006      None     INTRAMUSCULAR/SUBCU INJ m/s     None
# 3          370006      None             INITIAL IV PUSH m/s     None
# 4          370006      None  ADDIT IV PUSH/NEW SUBSTANCE ms     None
# ...           ...       ...                             ...      ...
# 46119      370006      SURG      Cardioversion electric ext     None
# 46120      370006      SURG     Airway inhalation treatment     None
# 46121      370006      SURG    Colorectal scrn; hi risk ind     None
# 46122      370006      SURG    Colon ca scrn not hi rsk ind     None
# 46123      370006      SURG    Inj for sacroiliac jt anesth     None
#
#       local_code  code ms_drg apr_drg  eapg hcpcs_cpt  ... billing_class
# 0        2600636  None    NaN    None  None     96360  ...          None  \
# 1        2603636  None    NaN    None  None     96361  ...          None
# 2        2603736  None    NaN    None  None     96372  ...          None
# 3        2604736  None    NaN    None  None     96374  ...          None
# 4        2605736  None    NaN    None  None     96375  ...          None
# ...          ...   ...    ...     ...   ...       ...  ...           ...
# 46119       None  None    NaN    None  None     92960  ...          None
# 46120       None  None    NaN    None  None     94640  ...          None
# 46121       None  None    NaN    None  None     G0105  ...          None
# 46122       None  None    NaN    None  None     G0121  ...          None
# 46123       None  None    NaN    None  None     G0260  ...          None
#
#       setting payer_category                  payer_name plan_name
# 0        None          gross                Gross Charge      None  \
# 1        None          gross                Gross Charge      None
# 2        None          gross                Gross Charge      None
# 3        None          gross                Gross Charge      None
# 4        None          gross                Gross Charge      None
# ...       ...            ...                         ...       ...
# 46119    None          payer  HealthChoice (State Govt.)      None
# 46120    None          payer  HealthChoice (State Govt.)      None
# 46121    None          payer  HealthChoice (State Govt.)      None
# 46122    None          payer  HealthChoice (State Govt.)      None
# 46123    None          payer  HealthChoice (State Govt.)      None
#
#       standard_charge standard_charge_percent contracting_method
# 0              521.00                    None               None  \
# 1              167.00                    None               None
# 2              218.00                    None               None
# 3              521.00                    None               None
# 4              235.00                    None               None
# ...               ...                     ...                ...
# 46119         2976.93                    None               None
# 46120         4352.90                    None               None
# 46121         3618.92                    None               None
# 46122         3432.17                    None               None
# 46123         1039.08                    None               None
#
#       additional_generic_notes additional_payer_specific_notes
# 0                         None                            None
# 1                         None                            None
# 2                         None                            None
# 3                         None                            None
# 4                         None                            None
# ...                        ...                             ...
# 46119                     None                            None
# 46120                     None                            None
# 46121                     None                            None
# 46122                     None                            None
# 46123                     None                            None
#
# [46124 rows x 30 columns]

# %%
df_out.to_csv('rate_' + ccn + '.csv', index=False)
